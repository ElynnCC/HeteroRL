# %%
import copy
import pickle
from datetime import datetime as dtdt

import attrs
import numpy as np

from hetero.config import DTYPE, AlgoConfig, DataGenConfig, GroupingConfig
from hetero.datagen import generate_data_from_config
from hetero.policies import AlternativePolicy
from hetero.tasks import (
    beta_estimate_from,
    beta_estimate_from_e2e_learning,
    beta_estimate_from_nongrouped,
    compute_UV_truths,
    compute_V_estimate,
)

group_reward_coeff = np.array(
    [
        [-2, 2, 2, -2],
        [2, -2, -2, 2],
    ],
    dtype=DTYPE,
)

action_reward_coeff = [-1, 1]

FEATURE_TYPE = "LEGENDRE"
TRANS = "NORMCDF"
NOISE = "STUDENT"

data_config_init = dict(
    num_trajectories=50,
    num_time_steps=20,
    group_reward_coeff_override=group_reward_coeff,
    action_reward_coeff=action_reward_coeff,
    num_burnin_steps=100,
    basis_expansion_method=FEATURE_TYPE,
    transformation_method=TRANS,
    add_intercept_column=True,
    noise_type=NOISE,
    noise_student_degree=4,
)

# First time runner: set COMPUTE_TRUTH = True
# Change the flag to False after generated the truth file.
COMPUTE_TRUTH = False #True
# Change the truth file name if settings are changed.
TRUTH_FILE = f"hetero/data/{FEATURE_TYPE}_{TRANS}_{NOISE}_truth_20230528_2.68_2.89.pkl"
print("truth file name =", TRUTH_FILE)

time_tag = dtdt.now().strftime("%Y%m%d_%H-%M-%S")
tag = f'N={data_config_init["num_trajectories"]}_T={data_config_init["num_time_steps"]}_{time_tag}'
RESULT_FILE = f"hetero/data/{FEATURE_TYPE}_{TRANS}_{NOISE}_result_20230528_2.68_2.89_{tag}.pkl"
print("result file name =", RESULT_FILE)

SAVE_RESULT = True
if not SAVE_RESULT:
    print("Result will NOT be saved, only use this for experimental runs!!!")

NUM_EXPERIMENTS = 100
# Out:
# truth file name = hetero/data/LEGENDRE_NORMCDF_STUDENT_truth_20230528_2.68_2.89.pkl
# result file name = hetero/data/LEGENDRE_NORMCDF_STUDENT_result_20230528_2.68_2.89_N=50_T=20_20230602_19-30-04.pkl

# %% [markdown]
# =====================================================================================================
# # Algorithm
#
# - Set configure below.

# %%
algo_config = AlgoConfig(
    max_num_iters=1,
    gam=2.7,
    lam=2.0,
    rho=2.0,
    should_remove_outlier=True,
    outlier_lower_perc=2,
    outlier_upper_perc=98,
    nu_coeff=1e-5,
    delta_coeff=1e-5,
    use_group_wise_regression_init=True,
)

pi_eval = AlternativePolicy(2)

grouping_config = GroupingConfig()

# %%
if COMPUTE_TRUTH:
    truth_data_config_init = copy.copy(data_config_init)
    truth_data_config_init.pop("num_trajectories")
    us, vs = compute_UV_truths(
        truth_data_config_init,
        algo_config.discount,
        pi_eval,
        num_repeats=100,
        num_trajectories=1000,
    )  # For best results, use num_repeats=10
    u_truth = us.mean(axis=0)
    v_truth = vs.mean(axis=0)

    with open(TRUTH_FILE, "wb") as f:
        pickle.dump(
            dict(
                u_truth=u_truth,
                v_truth=v_truth,
                data_config_dict=truth_data_config_init,
                algo_config_dict=attrs.asdict(algo_config),
            ),
            f,
        )
else:
    with open(TRUTH_FILE, "rb") as f:
        loaded = pickle.load(f)
        u_truth = loaded["u_truth"]
        v_truth = loaded["v_truth"]

# %%
beta_ng_list = []
beta_learned_list = []

for i in range(NUM_EXPERIMENTS):
    data_config = DataGenConfig(seed=7531 * (i + 1), **data_config_init)
    data = generate_data_from_config(data_config)
    beta_ng_list.append(
        beta_estimate_from_nongrouped(data, pi_eval, algo_config.discount)
    )
    beta_learned_list.append(
        beta_estimate_from_e2e_learning(data, algo_config, grouping_config, pi_eval)
    )
# Out:
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.24322975
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.14692249 -2.95176024 -2.77519263  2.85846333  1.68236943  2.54393467
#   -1.1555106  -2.67626254  2.67925176  1.13213849]
#  [-0.96336648  3.0026941   2.55163416 -2.91406425 -1.50798927 -2.88321968
#    1.02354372  3.13186362 -2.94585661 -0.90432525]] and inertia = 250.7698131066054
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.25521845
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.97273351 -3.20679263 -2.65610652  2.97981374  1.7018105   2.61814966
#   -1.15957419 -2.91961894  2.77228986  1.16176774]
#  [-1.06856524  2.80215158  2.72259641 -2.67373027 -1.59073445 -2.89388912
#    1.04195262  2.78037825 -2.727501   -0.79746699]] and inertia = 250.4811992491845
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.25139776
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.00281634 -2.98557841 -3.13111471  2.92609321  1.83180956  2.78664307
#   -1.09153621 -2.82034366  2.72078647  0.96136221]
#  [-0.9909927   2.72829406  2.37247094 -2.93941688 -1.24211361 -3.0802896
#    1.0148496   2.76789218 -2.79441433 -0.71165604]] and inertia = 236.72670022849152
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.2576359
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.87612294 -2.77901376 -2.69162498  2.74120669  1.63486533  2.99942877
#   -1.21425776 -2.86523132  2.79401693  0.87324067]
#  [-1.05840363  3.17681734  2.40592052 -2.87406637 -1.5073263  -2.89130172
#    1.04163084  2.49832025 -2.81914252 -0.5342272 ]] and inertia = 246.93103836205952
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = (0.2570451+0j)
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.31182888 -2.91294457 -2.58545601  2.8619438   1.38132546  2.79961556
#   -1.1206632  -2.79100625  2.85559427  0.83130655]
#  [-0.84449002  2.68609616  2.83657704 -3.03253571 -1.4359819  -3.15143773
#    1.20637249  2.65398335 -2.88556638 -0.64026819]] and inertia = 265.06987596301684
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = (0.26047683+0j)
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.0742914  -3.11988177 -2.66005898  3.09471672  1.44629768  2.76983729
#   -1.11951882 -2.49119106  2.96428812  0.60904753]
#  [-0.9366236   3.05064349  2.7922996  -2.58081679 -1.99724495 -3.00047676
#    0.9744903   2.79753281 -2.66017256 -0.89425636]] and inertia = 233.33552064823414
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.24027324
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.15470681 -2.64620865 -2.70112664  2.96020028  1.29987614  2.99343421
#   -1.01637644 -2.75720073  2.95755931  0.60833915]
#  [-0.97754292  2.80339821  2.89136721 -2.57082875 -1.70213777 -3.06321035
#    1.14888769  2.77115723 -2.58614597 -0.77751589]] and inertia = 245.17984909695588
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.25814715
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.98109074 -2.78970122 -2.52767445  2.80149759  1.42348281  2.88097282
#   -1.16293887 -2.73543893  2.76852534  0.85535675]
#  [-1.02088198  2.79673509  2.60789099 -2.73089241 -1.61841755 -2.75832077
#    1.10572528  2.306767   -2.89870231 -0.61275689]] and inertia = 236.13013752954907
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = (0.25521785+0j)
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.04149394 -2.86660082 -2.88909452  2.89494782  1.61173161  2.76046026
#   -0.95397912 -2.87711077  2.62169587  0.94095369]
#  [-1.02648544  2.65063223  2.75792555 -2.60187456 -1.56682921 -2.94511597
#    1.07559727  3.09244756 -2.6054516  -1.01494978]] and inertia = 237.0623319266343
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = (0.25459665+0j)
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.09285263 -2.74975721 -2.29297079  2.65707825  1.44562767  2.92299672
#   -0.96992617 -2.63181311  2.88515232  0.75166569]
#  [-0.97827685  2.97040253  2.97332013 -2.96428468 -1.77827957 -2.87710624
#    0.98604712  3.07284991 -2.6780689  -1.11000939]] and inertia = 253.37168316221545
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.24150872
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.00406715 -2.78682065 -2.74117486  2.98908037  1.46007802  3.02477102
#   -1.13237151 -2.65109155  2.96001069  0.60061039]
#  [-0.94352094  2.81187386  2.7487247  -2.9833067  -1.4960691  -2.79043066
#    1.10863796  2.87096287 -2.81745158 -0.93094942]] and inertia = 244.10517163217438
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.24215527
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.06693878 -2.79983239 -2.90796809  2.97897585  1.42146451  3.16386427
#   -1.0745481  -2.97978329  2.99038863  0.57763   ]
#  [-1.13781742  3.04366387  2.80158689 -2.77978275 -1.64128075 -2.76614361
#    1.02258567  2.73792021 -2.61743169 -0.94313763]] and inertia = 238.40119257723416
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.2439914
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.20000536 -3.1112643  -2.66876521  2.9719531   1.48093888  2.56879548
#   -1.02456992 -2.57572925  2.7707089   0.8978018 ]
#  [-0.76341808  2.77646979  2.79136145 -2.64750497 -1.68090464 -2.84528077
#    1.14909401  3.04462039 -2.89825197 -0.92157186]] and inertia = 250.86058087839643
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.25695693
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.12718453 -3.04720916 -2.45965004  2.9647712   1.40094401  2.75816551
#   -1.06716655 -2.58171214  2.94044443  0.72218041]
#  [-1.10549224  2.97926077  2.88375939 -2.9350698  -1.81309286 -2.84649015
#    1.0419743   2.61937241 -2.69332304 -0.9149443 ]] and inertia = 257.7502558668618
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.23880799
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.99087444 -2.70941659 -2.68255059  2.59555566  1.57311822  3.0454259
#   -0.94688715 -2.73841705  2.78992682  0.60554372]
#  [-1.06132502  2.78878919  2.96289156 -2.52783709 -1.82063589 -3.00625796
#    0.95850374  2.86168731 -2.84099007 -0.67654595]] and inertia = 240.6431499070938
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = (0.27051264+0j)
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.94591268 -3.13743964 -2.53575151  2.65164475  1.75803363  3.02294523
#   -1.10115781 -2.68983022  2.76567837  0.70411303]
#  [-1.00440975  2.59877382  2.75501468 -2.85592505 -1.49378574 -2.98214335
#    1.00585961  2.61029277 -2.88956996 -0.56778988]] and inertia = 234.3000272452084
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.24797508
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.91505618 -2.92495514 -2.90043011  2.7066645   1.77617858  2.89287279
#   -1.13546027 -2.95667523  2.55744465  1.03774723]
#  [-1.1294993   3.11100835  2.78362886 -2.60851836 -1.81820966 -2.63082723
#    1.04308888  2.7226714  -2.82903708 -0.89027104]] and inertia = 245.5360974445163
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = (0.25790638+0j)
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.94664315 -3.11417317 -3.02120109  2.76599233  2.00823804  2.92667297
#   -1.06202932 -2.68886179  2.98000705  0.66288685]
#  [-0.98371455  2.76757423  2.53142346 -2.91361922 -1.39203081 -3.00821434
#    1.15191916  2.77622669 -2.68318842 -0.8489688 ]] and inertia = 264.23785948062414
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.25517178
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.96148148 -3.15508231 -2.65765887  2.83925237  1.71358997  3.01017731
#   -0.98297593 -2.93710738  2.62238245  0.91172917]
#  [-1.01087727  2.8228388   2.87124932 -2.7936121  -1.67496087 -3.10731285
#    1.08258068  2.80605696 -2.7067393  -0.7696651 ]] and inertia = 270.1681500606261
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.25006852
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.96588825 -2.72523169 -2.81913079  2.73432624  1.69940147  2.97748115
#   -1.08579971 -2.50993442  2.63973427  0.72271794]
#  [-0.93992326  3.06657343  2.88601462 -2.81908595 -1.86587622 -3.09946917
#    1.11936316  2.73632673 -2.82138818 -0.70105465]] and inertia = 267.4677237430366
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.25146878
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.97674476 -2.6780471  -2.64658102  2.82880313  1.51550902  3.04764886
#   -0.8986362  -2.50000647  2.65586677  0.6193305 ]
#  [-1.02086925  2.73143464  2.88735665 -2.76332102 -1.58334833 -2.89454573
#    1.05383278  2.8308227  -2.77267551 -0.81147402]] and inertia = 252.25320291079547
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.25734693
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.08095053 -2.75154266 -2.98943809  2.57591682  1.8025857   3.05199845
#   -1.01135949 -2.80359426  2.49447871  0.87529862]
#  [-1.18728849  3.43599628  2.73518436 -2.90418473 -1.82195064 -2.90536183
#    0.70932023  2.79422614 -2.94609666 -0.60556859]] and inertia = 266.4034138953127
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.25908533
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.9567123  -2.87351799 -2.9559773   2.33846728  2.18420468  2.80466267
#   -1.06134961 -2.79830983  2.81039259  0.93286025]
#  [-0.99197981  2.868807    2.78746435 -2.78520379 -1.6353699  -3.11144593
#    1.13894968  2.97334424 -2.77379281 -0.89779532]] and inertia = 250.47304481099712
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = (0.24937734+0j)
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.92279654 -2.67910578 -2.67295761  2.93427971  1.35035803  2.94813584
#   -0.92470378 -2.51988946  2.97081757  0.38819435]
#  [-1.01054107  2.77229183  2.68810412 -2.91600033 -1.45453502 -3.14566203
#    1.06050455  2.91801931 -2.68025935 -0.87712626]] and inertia = 249.07192669865404
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.24989645
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.06119501 -3.00375994 -2.68416514  2.79360677  1.58239255  2.92778962
#   -0.9389684  -2.89041779  2.70735552  0.81058184]
#  [-1.01714117  2.93465648  2.98106561 -2.54373537 -2.08230385 -3.003201
#    0.96857293  2.82463201 -2.68512063 -0.85717307]] and inertia = 240.03469479064393
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.26217106
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.10619141 -2.76691194 -2.62020727  2.87470126  1.27472746  2.85135359
#   -0.97339328 -2.64602484  3.01653442  0.47548535]
#  [-1.23819254  2.82211876  2.69522007 -2.93039097 -1.37446812 -2.8539319
#    1.19006639  2.6047937  -2.83698764 -0.71005928]] and inertia = 238.5784137434658
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.26805678
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.00861961 -2.72752722 -2.74813779  2.96652997  1.44069097  2.84291142
#   -1.07508258 -2.90418639  2.53891271  1.15518619]
#  [-0.94356202  2.66093537  2.9227404  -2.62451459 -1.8038973  -2.96342316
#    0.95226677  2.71222828 -2.75525644 -0.75300017]] and inertia = 255.65034193083682
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.2652726
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.90733882 -2.87691172 -3.02498451  2.83538439  1.76533209  3.17842672
#   -0.9557535  -2.66059298  2.82623126  0.51976558]
#  [-1.01539552  2.94467764  2.64064792 -2.72360915 -1.65089738 -2.73928898
#    1.08904082  2.85019827 -2.56000762 -1.01859161]] and inertia = 239.4958624980813
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = (0.26382983+0j)
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.94345107 -2.83395414 -2.96099508  2.75729389  1.82805415  3.06636026
#   -0.93794991 -2.92190184  2.62956882  0.88042643]
#  [-0.92335701  3.22572663  2.7020531  -2.97164391 -1.62176023 -3.00445743
#    0.98323534  2.64967926 -2.88288316 -0.4712285 ]] and inertia = 264.91465908733346
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.25708845
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.12393625 -2.66157306 -2.76542139  2.79444831  1.47667416  2.66651752
#   -1.10727032 -2.64706843  2.85185244  0.8576866 ]
#  [-1.04960032  2.96092993  2.65007523 -2.427674   -1.86891885 -2.98885111
#    1.06245777  2.85213584 -2.71302403 -0.85127342]] and inertia = 222.60714944721047
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.25861025
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.03748581 -2.9150885  -3.00125246  2.80663442  1.85078095  2.90238274
#   -1.15868516 -2.93043282  2.73024602  0.97298681]
#  [-1.05136499  2.75821393  2.67586457 -2.66635826 -1.63512189 -2.97204513
#    1.00421552  2.9222578  -2.56293751 -1.08761448]] and inertia = 242.12609984929856
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.24884632
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.97270351 -2.86514655 -2.74397075  2.79161436  1.54462767  2.96893067
#   -0.89525814 -2.77212616  2.74802058  0.63406041]
#  [-0.91344776  2.74282964  3.05035697 -2.76789239 -1.73308977 -2.85107502
#    1.1351923   2.90364406 -2.63185942 -0.97590804]] and inertia = 280.11693814737396
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.2520389
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.07719188 -2.73766723 -2.56343467  2.46393206  1.59293205  3.10769657
#   -1.06886765 -2.53922375  2.78439014  0.47612037]
#  [-1.14664452  2.93345009  2.38000262 -2.78170299 -1.36645928 -2.89391522
#    1.0848232   2.80284935 -2.77741337 -0.7591858 ]] and inertia = 201.86598904940706
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.2557317
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.09595964 -2.66388387 -2.7873696   2.91237481  1.4232682   2.92348495
#   -1.11799504 -2.80986576  2.83877122  0.82468723]
#  [-1.18522186  3.0356674   2.64475586 -3.00234634 -1.38872308 -2.78722995
#    1.15432077  2.78593026 -3.14611454 -0.64610523]] and inertia = 248.96239952078784
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.24319772
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.94677706 -3.40648576 -2.5375897   3.17151598  1.60944095  2.85766252
#   -0.96434519 -2.43667398  2.76760392  0.62968917]
#  [-1.03560524  2.97790213  2.87222207 -2.88087114 -1.66242651 -2.82559589
#    1.18144552  2.68720768 -2.51498191 -0.9483738 ]] and inertia = 242.12115961227892
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.248635
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.12805033 -3.08153843 -2.53281992  3.1557956   1.39222151  3.14403041
#   -0.91536139 -2.54470198  2.77387108  0.52320281]
#  [-0.99589253  2.81917271  2.66734743 -2.77417947 -1.55368323 -2.78003965
#    1.12874132  2.33175334 -2.77003016 -0.65026256]] and inertia = 244.07886008829433
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.2580376
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.94614854 -3.10698854 -2.66181762  3.04893381  1.64112497  2.73111915
#   -0.98283799 -2.71813236  2.78129155  0.83797468]
#  [-1.10445076  2.97605796  2.92545922 -2.72674536 -1.86512052 -2.92761741
#    0.86827401  2.90274744 -2.80599468 -0.84863053]] and inertia = 278.5099913773624
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.25340533
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.17109592 -2.87361577 -2.71271136  2.86380684  1.54411971  2.87210484
#   -1.06342918 -2.71682404  2.72057038  0.98652637]
#  [-1.04407433  2.86955869  2.6835657  -2.36919916 -1.87568097 -2.96527582
#    0.95057431  2.93040534 -2.55779149 -0.97779223]] and inertia = 217.0298757808964
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.25814548
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.93184223 -3.04469268 -2.77444234  2.59583136  1.93623683  2.98132981
#   -0.98477157 -2.59850992  2.82070954  0.63037736]
#  [-1.17340389  2.98223965  2.72594842 -2.75516809 -1.74857489 -2.90198046
#    0.90633257  2.78409206 -2.65820837 -0.91355521]] and inertia = 258.63209575146516
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.24228467
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.18103618 -2.95781198 -3.01035988  2.80288564  1.68938776  3.11229883
#   -0.87473829 -2.98277612  2.80922117  0.6516727 ]
#  [-1.08140969  3.09959713  2.7256448  -2.83881641 -1.74181087 -2.85789421
#    1.12829421  2.73776719 -2.77621417 -0.91737415]] and inertia = 244.41653080967416
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.26383013
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.07831754 -2.8018313  -2.55191621  2.72411859  1.39816037  2.9483531
#   -1.05749662 -2.78475692  2.68791437  0.84674982]
#  [-1.10606613  3.02679569  2.61844548 -2.98946477 -1.43110514 -3.29873924
#    1.00957073  2.83428326 -2.95657725 -0.52190846]] and inertia = 250.28712115108164
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.2528647
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.07068177 -2.76067105 -2.95014512  2.48607961  1.96670455  3.03224307
#   -1.08309977 -2.77578522  2.6767379   0.87514199]
#  [-1.07724004  2.81997361  2.7615402  -2.75301403 -1.6053254  -2.92959599
#    1.13005756  2.96446749 -2.88548616 -0.87905028]] and inertia = 250.16474036028995
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.2595305
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.17200401 -2.88359155 -2.55812395  2.87861366  1.40788608  2.73907576
#   -1.17560377 -2.80991453  2.73533262  0.96659769]
#  [-1.10548013  2.93775095  2.95553502 -2.6137236  -1.91314093 -3.14252288
#    0.91970075  2.97238613 -2.64711415 -0.81475996]] and inertia = 246.14187275719001
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = (0.23770674+0j)
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.97679404 -2.91076585 -3.07113779  2.8231298   2.02749041  3.1339388
#   -1.00619363 -2.82399677  2.86530486  0.70805602]
#  [-0.94349858  2.98405372  3.06687873 -2.65508331 -2.0582081  -2.90856067
#    0.95871005  2.84880241 -2.60904722 -0.93207204]] and inertia = 264.1989395317422
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = (0.2639071+0j)
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.99146637 -2.71810819 -2.80646675  2.67809713  1.49558581  2.92867374
#   -0.94896389 -3.0180811   2.6363784   0.86397848]
#  [-1.07485668  2.87360174  2.59144939 -2.9669597  -1.35319104 -2.82730285
#    1.04057087  3.06521289 -2.70403884 -1.09600377]] and inertia = 246.4117949736775
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = (0.25070062+0j)
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.92408044 -2.7942371  -2.65270761  2.86494567  1.47109577  3.06029412
#   -0.96801753 -2.61799324  2.94042501  0.42248385]
#  [-1.10676723  2.65761242  3.00449574 -2.73698045 -1.68362899 -2.9326923
#    1.10675938  2.79016597 -2.86356184 -0.81339488]] and inertia = 239.4072175608938
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.25812116
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.94398968 -2.85584862 -2.63240808  2.79636486  1.58894007  2.81346509
#   -0.9994587  -3.07359047  2.75340629  1.10266026]
#  [-1.10487848  2.61821538  2.66183934 -2.69551025 -1.43468334 -2.82344639
#    1.06008755  2.72773924 -2.71795585 -0.80222839]] and inertia = 238.781605262899
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.26034528
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.95883964 -3.03982469 -3.11560488  2.81240201  2.04936524  2.86651239
#   -1.19552485 -2.96017536  2.83479488  1.04800193]
#  [-0.981175    3.09606506  2.70678841 -2.80709847 -1.61181801 -3.31677633
#    0.94998663  2.82458282 -3.0287282  -0.35622791]] and inertia = 271.9568354890882
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = (0.24849752+0j)
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.98019248 -2.92570886 -2.91850708  2.78221824  1.75240931  2.85901258
#   -0.9547245  -2.79281413  2.83283148  0.75772345]
#  [-1.07357278  3.09391321  2.57617573 -2.69190778 -1.8264281  -3.00297057
#    0.97422103  2.87277242 -2.49992248 -1.07027019]] and inertia = 253.95525659247525
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.25201574
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.13549539 -3.22613153 -3.11815664  2.97990036  1.85910856  2.89330605
#   -1.01313749 -2.87940277  2.72862781  0.84220809]
#  [-1.01461246  2.8428397   2.5398607  -2.62665005 -1.52607309 -2.88189098
#    1.04327213  2.53955529 -2.82448898 -0.66101603]] and inertia = 243.16675420052576
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.25592494
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.02376943 -2.81768078 -2.84387233  2.52450895  1.5759432   2.90882414
#   -0.94231477 -2.61020081  2.43685155  0.71578854]
#  [-0.95460459  2.80005437  2.78657507 -2.77163924 -1.73933841 -3.12847769
#    0.97298942  2.8838288  -2.71840378 -0.84877355]] and inertia = 249.1400226348509
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.26074672
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.15555398 -2.87711666 -2.62312213  2.60055674  1.58434493  2.96301177
#   -0.99893973 -2.71653716  2.72007729  0.67643781]
#  [-1.12980446  2.82700768  2.4703828  -2.80950646 -1.32522207 -3.00011366
#    1.04593814  2.88549411 -2.6297977  -0.91409794]] and inertia = 242.59542658947103
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = (0.24565063+0j)
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.02596164 -2.88135891 -2.94806016  2.63567717  1.90383547  2.98520565
#   -0.88275157 -2.74130638  2.99549219  0.60754551]
#  [-1.13118159  2.90934546  2.66471591 -2.67493713 -1.62617018 -2.82043148
#    0.93148305  2.57818497 -2.66444433 -0.77483297]] and inertia = 250.92192087845427
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.25999394
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.17147869 -2.93202121 -2.44819765  2.62328007  1.44127591  3.02692365
#   -1.11384387 -2.70446863  2.78536406  0.64462252]
#  [-0.83861822  2.81276659  3.12255896 -2.88812869 -1.78471141 -3.06852443
#    0.99360022  2.66587329 -2.92033309 -0.56534803]] and inertia = 259.7850240958239
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.24709645
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.01290262 -3.22215436 -2.8117551   2.73816554  2.00988351  2.95203522
#   -1.0811244  -2.88584061  2.8291676   0.91475722]
#  [-0.96697104  3.14960881  2.68703152 -2.76692496 -1.74740234 -3.00224359
#    0.97299192  2.53223939 -2.85371529 -0.60204841]] and inertia = 249.9208157498802
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.25332874
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.9014061  -3.2014543  -2.70571341  2.89370773  1.86940908  3.04115362
#   -1.09301416 -2.83764194  2.86600705  0.85070741]
#  [-0.94905004  3.10805642  2.55407513 -2.84684359 -1.66625507 -3.20379412
#    1.12591438  2.56338679 -2.7777227  -0.56945486]] and inertia = 258.09842456376856
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = (0.2616687+0j)
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.06732998 -2.99117754 -2.6846207   3.21749393  1.34123445  2.9352123
#   -0.93649145 -2.79203704  2.89243872  0.61739725]
#  [-1.20294334  2.96974904  2.70190503 -3.17757975 -1.3617562  -2.55923826
#    1.16924033  2.78553166 -2.82911364 -1.05346789]] and inertia = 254.85004328694149
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = (0.25025532+0j)
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.93028368 -2.81230073 -3.01285313  2.82371377  1.84074069  3.10349069
#   -1.05463306 -2.87784756  2.96667234  0.69051613]
#  [-0.82636333  2.87899492  2.6925398  -2.66908882 -1.78153583 -2.90964444
#    0.95476909  2.86323279 -2.99700757 -0.70954418]] and inertia = 254.7954537714229
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.2616306
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.1517917  -2.79124694 -2.74721616  2.89552287  1.41073573  2.80917129
#   -1.10604051 -3.18202554  2.65912582  1.21929395]
#  [-1.14577629  2.74808843  3.02503391 -2.77672876 -1.71862904 -2.93984279
#    0.86700597  3.06687754 -2.72417747 -0.94845873]] and inertia = 257.8028505017169
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = (0.25031978+0j)
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.86347448 -2.8177023  -2.38263428  2.86459556  1.35326571  2.8597205
#   -1.0079577  -2.5143794   2.95878061  0.5283532 ]
#  [-1.0615822   2.91501941  2.64713806 -2.75407967 -1.52370329 -2.78172051
#    1.05322954  2.78486285 -2.93625418 -0.65603003]] and inertia = 231.9498912586914
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.25420773
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.92964359 -2.93371324 -2.62522292  2.69482093  1.76465572  2.7662511
#   -0.96805023 -3.07258113  2.88003823  0.99992558]
#  [-1.01526279  2.88483249  2.99337176 -2.84662224 -1.76332742 -3.05094841
#    1.11301787  2.99506913 -2.79655747 -0.85083401]] and inertia = 265.20676997987005
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.26087222
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.08641775 -2.91198513 -2.39275059  2.93249664  1.36331235  3.01414322
#   -0.89122025 -2.70313294  2.6239971   0.77891861]
#  [-0.94324037  3.16912879  2.85708801 -3.02413118 -1.87480922 -2.88956229
#    0.92923771  2.92780368 -2.76087286 -0.88318124]] and inertia = 248.87635593905668
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = (0.24283078+0j)
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.0255816  -2.93122971 -2.98032438  2.98823464  1.61755481  2.92920406
#   -1.13694615 -2.73653924  2.74448047  0.81618061]
#  [-0.88678126  3.05104175  2.62529588 -3.2098968  -1.39402647 -3.01305433
#    0.98575558  2.73943351 -3.00317732 -0.47867279]] and inertia = 244.59700212426304
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.25553495
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.08635432 -2.80324063 -2.73934873  2.83213203  1.57103618  2.94536751
#   -1.00099923 -3.07377614  2.93565517  0.83970048]
#  [-0.95165323  2.89243514  2.8639522  -2.51376544 -1.87636248 -3.04729831
#    1.09293719  2.64426791 -2.48689096 -0.83203293]] and inertia = 235.4228011277351
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = (0.26003537+0j)
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.96055475 -3.17549158 -2.62142346  2.81846559  1.78300397  2.91739069
#   -0.98164593 -2.67054437  2.86679766  0.7028103 ]
#  [-0.97557333  2.9953935   2.87237072 -2.81161197 -1.80692049 -3.14392671
#    0.98495849  2.89638261 -2.81038263 -0.74215322]] and inertia = 242.3730711001516
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.25336677
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.09691203 -3.00528944 -2.59902136  2.52898567  1.72971556  3.20679696
#   -1.14983233 -2.75539159  2.67313266  0.74936034]
#  [-0.9412107   2.96678293  2.87672233 -2.73005078 -1.8785751  -3.04602705
#    0.9193342   2.50261618 -2.77351741 -0.65320865]] and inertia = 266.31140078938665
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.24992168
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.94858646 -2.83503868 -2.49559521  2.86581153  1.55599723  3.08906822
#   -0.95420951 -2.99727867  2.6660291   0.9178466 ]
#  [-1.01115062  2.7079549   2.65817416 -2.86965681 -1.35500482 -3.17709136
#    1.01419523  2.56615085 -2.71993167 -0.47266908]] and inertia = 259.2131707328939
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.25174853
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.9738666  -3.04444797 -2.67383716  2.43323513  1.99523909  3.18013775
#   -0.95213481 -3.01341665  2.69689485  0.89992537]
#  [-1.13684883  3.00740117  2.67026032 -2.63471381 -1.67478429 -2.71936582
#    0.97252841  2.78759082 -2.79897205 -0.86431644]] and inertia = 243.3763996372916
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = (0.24965717+0j)
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.11006567 -2.73580014 -2.58934328  2.62622573  1.48250919  3.08259555
#   -0.99632579 -2.91984463  2.51765144  0.89291911]
#  [-0.8878784   2.81415077  2.77311477 -2.89263738 -1.60412796 -3.076263
#    1.11193869  2.57332854 -2.38066925 -0.83391485]] and inertia = 243.1645826890155
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = (0.25126308+0j)
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.03236153 -2.68269817 -2.6152458   2.83055546  1.38689042  2.74081536
#   -1.12033828 -2.86367116  2.94051349  0.80600625]
#  [-1.08043695  3.18136623  2.70804376 -2.76337489 -1.74036731 -2.75470078
#    1.01201395  2.78213664 -2.76032935 -0.89589514]] and inertia = 247.15101690134682
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.25324813
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.86572443 -3.0219556  -2.91558473  2.76475727  2.0062129   2.92307112
#   -0.94117319 -2.87346856  2.58041963  0.98937646]
#  [-1.02686435  2.89707455  2.78856082 -2.71618895 -1.79122378 -2.82819385
#    1.03154     2.97749815 -2.70645694 -1.07048444]] and inertia = 237.36720235871238
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.26252097
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.98530769 -2.81712821 -3.07648051  3.09591166  1.61857352  2.81600154
#   -1.16847814 -3.02731896  2.61719035  1.16468387]
#  [-1.03375673  2.83179304  2.9030443  -2.78117262 -1.68861979 -2.76762053
#    0.93144121  3.04293009 -2.85071135 -0.93319713]] and inertia = 259.4622734142068
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.24991748
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.89192007 -3.34375433 -2.85247131  2.95857911  1.87407652  3.07673211
#   -0.80335015 -2.85998206  2.74369596  0.62962895]
#  [-1.05712564  2.82534926  3.12380906 -2.79417187 -1.84809974 -2.65759109
#    1.3104682   2.82991806 -2.63688879 -1.09673761]] and inertia = 267.98120190877296
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.24956733
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.95754814 -2.98250584 -2.62914558  2.56529893  1.82143781  2.98361594
#   -0.80146507 -2.84223523  3.02250439  0.6077274 ]
#  [-1.21266427  2.57106949  2.66567148 -2.71155262 -1.47686281 -3.38388634
#    1.10516891  2.93184806 -2.46071047 -1.01018354]] and inertia = 246.154294770309
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = (0.2606031+0j)
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.12628169 -2.77660864 -2.80902219  2.96614069  1.39757396  3.04780136
#   -0.86619295 -2.79158599  3.01475934  0.42263485]
#  [-1.01106886  2.90471824  2.75687926 -2.7095626  -1.78437652 -3.11430891
#    1.17927267  2.75773832 -2.70235771 -0.77110974]] and inertia = 247.89171775984082
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.2555207
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.99637965 -2.56381564 -2.88146751  2.8588962   1.55912764  3.02167227
#   -1.17268435 -2.89401959  2.81086683  0.87423494]
#  [-1.1826662   2.57186598  2.66021809 -2.51935833 -1.41823065 -2.73818405
#    1.08100545  2.71005286 -2.7623745  -0.8088413 ]] and inertia = 215.21302127948923
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = (0.24869658+0j)
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.90617998 -2.95545329 -2.72618294  2.65709379  1.83506339  3.01714599
#   -0.97826051 -2.67404944  2.61969806  0.76020548]
#  [-0.89176918  2.86089432  2.80169451 -2.75659241 -1.77902333 -2.95602065
#    0.86504179  2.74282007 -2.69537454 -0.8212697 ]] and inertia = 236.9590214862912
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.25400776
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.98395072 -2.79157601 -2.62418876  2.7716512   1.4888693   2.93894152
#   -0.89130577 -2.78597516  2.9242253   0.50192875]
#  [-1.25647496  2.74366263  2.61298689 -2.99288984 -1.38263562 -2.94947972
#    0.99986213  2.86257588 -2.64494906 -1.09352207]] and inertia = 250.87674722189809
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.24229309
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.06014759 -3.09160844 -2.90429144  2.90442802  1.74037714  2.53643956
#   -1.16127634 -2.26705533  3.04045     0.53366413]
#  [-0.90439615  2.91667148  2.85280213 -2.77994797 -1.67939524 -2.98217776
#    0.95907403  2.89248098 -2.63731633 -0.7706945 ]] and inertia = 231.6377983288707
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.24052458
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.06095598 -2.79115049 -3.09949478  2.87973986  1.77412113  2.95147405
#   -1.02034549 -2.87842168  2.63247792  0.98214412]
#  [-1.14684795  2.99780641  2.69150724 -2.82045204 -1.64798911 -2.96479224
#    1.06343692  3.11212017 -3.03296742 -0.86804972]] and inertia = 256.78563383256846
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.25824663
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.9581009  -2.49476319 -2.66672016  2.80956564  1.25423817  3.17033063
#   -1.34766811 -2.55219081  2.82633611  0.44060434]
#  [-1.10027359  3.30913279  2.8325095  -2.58334609 -2.03343065 -3.11858244
#    0.99062291  2.8019503  -2.488662   -0.83968204]] and inertia = 233.1087972093362
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.26946825
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.86861372 -3.18837677 -2.66673807  2.6173468   1.95974451  2.73503802
#   -0.90344778 -2.67924276  2.61308288  0.86694529]
#  [-0.9612296   2.96483613  2.88980353 -2.93112073 -1.7047308  -2.85527081
#    1.07824934  2.83632601 -2.61246595 -1.03440482]] and inertia = 257.0192946479783
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.24291568
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.99805168 -3.10885042 -2.63424707  2.76810157  1.74518782  2.79334812
#   -0.96571295 -2.81997387  2.75320351  0.91692904]
#  [-1.08178463  2.56518529  2.82435669 -2.64393989 -1.65366925 -3.0408835
#    1.22601817  2.94127328 -2.60428264 -1.08190521]] and inertia = 260.32110278585753
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.25451037
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.05227799 -2.68633768 -2.7984201   2.68423616  1.55177392  3.12231877
#   -1.04217837 -2.72305682  2.67158683  0.59374983]
#  [-1.13890998  2.89899197  2.93081353 -2.96298392 -1.69853545 -3.2101358
#    0.98527632  2.83129093 -3.10563254 -0.48808996]] and inertia = 238.93363558008298
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.23543173
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.07788447 -2.95961267 -2.95760514  3.04012683  1.69099754  2.84291712
#   -1.04858463 -2.87361647  2.84742981  0.86399891]
#  [-1.07982534  3.1350833   3.00124911 -2.81135258 -1.89172811 -2.79146549
#    1.01194172  2.69325157 -2.7914777  -0.83615446]] and inertia = 241.98618984966663
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = (0.25298014+0j)
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.05975105 -3.08598215 -2.77687398  2.69982633  1.72583408  3.14683287
#   -1.03069531 -2.6635229   2.60390427  0.7177683 ]
#  [-1.00470237  2.87951577  2.75082598 -3.12236921 -1.50853576 -2.88119397
#    1.18711638  2.89130417 -2.95218659 -0.88754494]] and inertia = 265.1957766870586
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.2607246
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.21965726 -2.75555483 -2.51612665  2.85238523  1.24959039  2.78104345
#   -0.97526508 -2.63557979  2.89848585  0.61825212]
#  [-1.03039051  2.79750239  2.81875659 -2.65667704 -1.68477566 -3.03781562
#    1.20991181  2.72781128 -3.00615717 -0.66387529]] and inertia = 234.32784937860967
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.25672796
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.98198698 -2.91143197 -2.70736307  2.77301503  1.67630399  2.87863222
#   -1.01585095 -2.71088067  2.77093035  0.81971349]
#  [-1.18030579  2.96072399  2.62616781 -2.69103409 -1.61848358 -2.97146156
#    0.92935329  2.4545855  -2.93135816 -0.50216478]] and inertia = 253.8085676099422
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = (0.2568124+0j)
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.88162683 -2.9519968  -2.91079191  2.74196522  1.89476008  2.87617403
#   -0.98313506 -3.12389411  2.75301854  0.9105044 ]
#  [-1.09974988  3.17327588  2.61067664 -2.63134524 -1.73529347 -2.87688029
#    1.1342225   2.99526906 -2.70479662 -0.95281715]] and inertia = 228.42481289845958
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.25769344
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.06426142 -2.87131452 -2.85955145  2.72855624  1.67116407  3.03141376
#   -1.08590325 -3.14470281  2.687021    1.04306577]
#  [-0.97509596  2.73021494  2.67599483 -3.19773503 -1.34747707 -3.07247191
#    0.96237889  2.66839018 -2.9401936  -0.52186637]] and inertia = 246.18143413703638
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.24923451
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.01903824 -3.02177645 -2.77374295  2.79758032  1.81256203  2.89861118
#   -0.96203245 -2.717207    2.87045813  0.70020762]
#  [-0.95405541  2.84628549  2.86434763 -2.64181803 -1.86713133 -2.91855056
#    1.02338871  2.88061579 -2.79420469 -0.83993243]] and inertia = 265.01898924048305
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.26958072
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.11467287 -2.67458989 -2.73094437  2.44912039  1.65798234  2.809934
#   -1.06129346 -2.70901183  2.9338722   0.77331306]
#  [-1.05857764  2.67421697  2.71481476 -2.7640133  -1.47565238 -2.94523272
#    1.14020447  2.91781076 -2.95181291 -0.79334826]] and inertia = 221.25105704121376
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.25180587
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.99761721 -2.88431476 -2.55401491  2.90474811  1.49912058  2.91805593
#   -1.09835851 -2.90310107  2.92860334  0.79841659]
#  [-0.98340175  2.67953012  3.04619032 -2.94843793 -1.49132143 -2.80039474
#    1.16471174  3.01601561 -2.8745784  -0.89993874]] and inertia = 258.8361565769114
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.24906372
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.93300421 -2.67405523 -2.98109367  2.76164467  1.66285266  2.78928392
#   -0.99416132 -2.60631337  2.80211782  0.68356054]
#  [-1.05721849  3.12214834  2.73873525 -2.90066718 -1.72687326 -2.68156964
#    1.11774668  2.85278744 -2.6389904  -1.17125623]] and inertia = 271.25371720537123
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.25701183
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.94851091 -2.89559584 -2.56356493  2.65185404  1.63079238  2.8988104
#   -1.25522201 -2.62066333  2.63831628  0.76957588]
#  [-0.98278698  3.07489624  2.93083862 -2.76641237 -1.8719925  -2.88179931
#    0.97197094  2.51136041 -2.41430225 -0.90753826]] and inertia = 235.85401142807012
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = (0.25569716+0j)
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.01256108 -2.92004488 -2.89219943  2.54076836  1.89908067  3.06228431
#   -0.95343236 -2.7942234   2.73740661  0.67889562]
#  [-1.20349126  3.25260492  3.03918189 -2.72203427 -2.07758542 -2.7115214
#    0.86840173  2.81353876 -2.80042834 -0.89015008]] and inertia = 255.07792981159972
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = (0.24025945+0j)
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 0.71528746 -2.93820223 -2.81247658  2.58615301  1.8566883   3.00908478
#   -0.95736143 -2.78159013  2.76817243  0.56663926]
#  [-1.27673168  2.84033475  2.82370632 -2.78816608 -1.47730852 -3.10871
#    1.16639333  2.94389305 -2.62194451 -0.81194685]] and inertia = 250.68193023265997
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.25401723
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.13059595 -2.60218068 -2.86303573  2.92209194  1.41766261  2.99239263
#   -0.94843665 -2.92821525  2.64952562  0.85921863]
#  [-0.91985204  2.75231946  2.68337208 -2.65490671 -1.59022237 -3.11297788
#    0.91801393  2.69007958 -2.66235575 -0.67446567]] and inertia = 253.50357971106328
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.25079218
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.1603752  -3.00891737 -2.88047897  2.98557547  1.64332993  2.78649361
#   -0.89397437 -2.86657004  2.62344925  1.0459099 ]
#  [-0.88429476  2.85291991  2.68071018 -2.84566417 -1.60141644 -3.10280832
#    1.12216391  2.6680276  -2.76268576 -0.66969242]] and inertia = 243.37113221780777
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# new_labels.length=2000 matches number of records
# beta_solver, min eigen of left matrix = 0.25226626
# MCPImpl: num_above=2500, num_below=2450
# kmeans center = [[ 1.03545337 -3.04358093 -2.77452105  2.85916784  1.63836044  2.9824449
#   -1.04549307 -2.5836372   2.48923545  0.80227661]
#  [-0.97073565  2.97405873  2.68266124 -2.8414464  -1.61296427 -3.11656226
#    1.20551018  2.85427346 -2.69900719 -0.87633861]] and inertia = 232.4449962293804
# Label mismatch = 0
# new_labels.length=100 matches num_unique_labels
# new_labels.length=2000 matches number of records

# %%
beta_learned_list[0].betas
# Out:
# [array([-1.10325295,  2.99754758,  2.58230748, -3.02438533, -1.41873896,
#         -2.77774583,  1.06721488,  3.04395721, -3.04658301, -0.87861699]),
#  array([ 1.20829972, -2.94552576, -3.02892341,  2.81618039,  1.78166875,
#          2.51148362, -1.21754294, -2.91799362,  2.78961736,  1.22356028])]

# %%
mu_learned_list = []
sigma_learned_list = []
z_score_learned_list = []
mu_ng_list = []
sigma_ng_list = []
z_score_ng_list = []

for beta_learned, beta_ng in zip(beta_learned_list, beta_ng_list):
    v_mus, v_sigmas = compute_V_estimate(u_truth, beta_learned)
    z_score_learned = [
        (mu - truth) / sigma for mu, truth, sigma in zip(v_mus, v_truth, v_sigmas)
    ]
    mu_learned_list.append(v_mus)
    sigma_learned_list.append(v_sigmas)
    z_score_learned_list.append(z_score_learned)

    ngv_mus, ngv_sigmas = compute_V_estimate(u_truth, beta_ng)
    z_score_ng = [
        (mu - truth) / sigma
        for mu, truth, sigma in zip(
            ngv_mus * len(v_truth), v_truth, ngv_sigmas * len(v_truth)
        )
    ]
    mu_ng_list.append(ngv_mus)
    sigma_ng_list.append(ngv_sigmas)
    z_score_ng_list.append(z_score_ng)

# %% [markdown]
# # Reports that average over two groups

# %%
z_score_learned = np.array(z_score_learned_list)
z_score_ng = np.array(z_score_ng_list)
Z_THRESHOLD = 1.96
learned_in_threshold = np.abs(z_score_learned) < Z_THRESHOLD
ng_in_threshold = np.abs(z_score_ng) < Z_THRESHOLD
learned_in_threshold_perc = learned_in_threshold.sum() / learned_in_threshold.size
ng_in_threshold_perc = ng_in_threshold.sum() / ng_in_threshold.size
print(
    "learned_in_threshold_perc=",
    learned_in_threshold_perc,
    ", ng_in_threshold_perc=",
    ng_in_threshold_perc,
)
if SAVE_RESULT:
    with open(RESULT_FILE, "wb") as f:
        pickle.dump(
            dict(
                mu_learned_list=mu_learned_list,
                sigma_learned_list=sigma_learned_list,
                z_score_learned=z_score_learned,
                mu_ng_list=mu_ng_list,
                sigma_ng_list=sigma_ng_list,
                z_score_ng=z_score_ng,
                beta_learned_list=beta_learned_list,
                beta_ng_list=beta_ng_list,
            ),
            f,
        )
# Out:
# learned_in_threshold_perc= 0.975 , ng_in_threshold_perc= 0.0

# %%
ac_acl = 2*Z_THRESHOLD*np.mean(sigma_learned_list)
ac_mse = np.mean( (mu_learned_list - v_truth)**2 )

mv_acl = 2*Z_THRESHOLD*np.mean(sigma_ng_list)
mv_mse = np.mean( (mu_ng_list - v_truth)**2 )

# %%
print("ACPE results: (average over groups)")
print(f"ACL: {ac_acl}") 
print(f"MSE: {ac_mse}")
print(f"ECP: {learned_in_threshold_perc}")


print("MVPE results: (average over groups)")
print(f"ACL: {mv_acl}") 
print(f"MSE: {mv_mse}")
print(f"ECP: {ng_in_threshold_perc}")
# Out:
# ACPE results: (average over groups)
# ACL: 0.2309703886472189
# MSE: 0.0026643771763127464
# ECP: 0.975
# MVPE results: (average over groups)
# ACL: 0.28797216589895486
# MSE: 1.5541961331179344
# ECP: 0.0

# %% [markdown]
# # Reports that seperate two groups

# %%
z_score_learned = np.array(z_score_learned_list)
z_score_ng = np.array(z_score_ng_list)
Z_THRESHOLD = 1.96
learned_in_threshold = np.abs(z_score_learned) < Z_THRESHOLD
ng_in_threshold = np.abs(z_score_ng) < Z_THRESHOLD

learned_in_threshold_perc = np.sum(learned_in_threshold, axis=0) / learned_in_threshold.shape[0]
ng_in_threshold_perc = np.sum(ng_in_threshold, axis=0) / ng_in_threshold.shape[0]

print(
    "learned_in_threshold_perc=",
    learned_in_threshold_perc,
    ", ng_in_threshold_perc=",
    ng_in_threshold_perc,
)

if SAVE_RESULT:
    with open(RESULT_FILE, "wb") as f:
        pickle.dump(
            dict(
                mu_learned_list=mu_learned_list,
                sigma_learned_list=sigma_learned_list,
                z_score_learned=z_score_learned,
                mu_ng_list=mu_ng_list,
                sigma_ng_list=sigma_ng_list,
                z_score_ng=z_score_ng,
                beta_learned_list=beta_learned_list,
                beta_ng_list=beta_ng_list,
            ),
            f,
        )
# Out:
# learned_in_threshold_perc= [0.97 0.98] , ng_in_threshold_perc= [0. 0.]

# %%
ac_acl = 2*Z_THRESHOLD*np.mean(sigma_learned_list, axis=0)
ac_mse = np.mean((mu_learned_list - v_truth)**2, axis=0)

mv_acl = 2*Z_THRESHOLD*np.mean(sigma_ng_list, axis=0)
mv_mse = np.mean( (mu_ng_list - v_truth)**2, axis=0 )

# %%
print("ACPE results: Group1, Group 2")
print(f"MSE: {ac_mse}")
print(f"ACL: {ac_acl}") 
print(f"ECP: {learned_in_threshold_perc}")

print("===")
print("MVPE results: ")
print(f"MSE: {mv_mse}")
print(f"ACL: {mv_acl}") 
print(f"ECP: {ng_in_threshold_perc}")
# Out:
# ACPE results: Group1, Group 2
# MSE: [0.00302398 0.00230478]
# ACL: [0.23160256 0.23033822]
# ECP: [0.97 0.98]
# ===
# MVPE results:
# MSE: [1.5257716  1.58262066]
# ACL: [0.28797217]
# ECP: [0. 0.]
