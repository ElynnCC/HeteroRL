# %%
import copy
import pickle
from datetime import datetime as dtdt

import attrs
import numpy as np

from hetero.config import DTYPE, AlgoConfig, DataGenConfig, GroupingConfig
from hetero.datagen import generate_data_from_config
from hetero.policies import AlternativePolicy
from hetero.tasks import (
    beta_estimate_from,
    beta_estimate_from_e2e_learning,
    beta_estimate_from_nongrouped,
    compute_UV_truths,
    compute_V_estimate,
)

group_reward_coeff = np.array(
    [
        [-2, 2, 2, -2],
        [2, -2, -2, 2],
    ],
    dtype=DTYPE,
)

action_reward_coeff = [-1, 1]

FEATURE_TYPE = "LEGENDRE"
TRANS = "NORMCDF"
NOISE = "STUDENT"

data_config_init = dict(
    num_trajectories=100,
    num_time_steps=40,
    group_reward_coeff_override=group_reward_coeff,
    action_reward_coeff=action_reward_coeff,
    num_burnin_steps=100,
    basis_expansion_method=FEATURE_TYPE,
    transformation_method=TRANS,
    add_intercept_column=True,
    noise_type=NOISE,
    noise_student_degree=4,
)

# First time runner: set COMPUTE_TRUTH = True
# Change the flag to False after generated the truth file.
COMPUTE_TRUTH = False #True
# Change the truth file name if settings are changed.
TRUTH_FILE = f"hetero/data/{FEATURE_TYPE}_{TRANS}_{NOISE}_truth_20230528_2.68_2.89.pkl"
print("truth file name =", TRUTH_FILE)

time_tag = dtdt.now().strftime("%Y%m%d_%H-%M-%S")
tag = f'N={data_config_init["num_trajectories"]}_T={data_config_init["num_time_steps"]}_{time_tag}'
RESULT_FILE = f"hetero/data/{FEATURE_TYPE}_{TRANS}_{NOISE}_result_20230528_2.68_2.89_{tag}.pkl"
print("result file name =", RESULT_FILE)

SAVE_RESULT = True
if not SAVE_RESULT:
    print("Result will NOT be saved, only use this for experimental runs!!!")

NUM_EXPERIMENTS = 100
# Out:
# truth file name = hetero/data/LEGENDRE_NORMCDF_STUDENT_truth_20230528_2.68_2.89.pkl
# result file name = hetero/data/LEGENDRE_NORMCDF_STUDENT_result_20230528_2.68_2.89_N=100_T=40_20230602_20-51-59.pkl

# %% [markdown]
# =====================================================================================================
# # Algorithm
#
# - Set configure below.

# %%
algo_config = AlgoConfig(
    max_num_iters=1,
    gam=2.7,
    lam=2.0,
    rho=2.0,
    should_remove_outlier=True,
    outlier_lower_perc=2,
    outlier_upper_perc=98,
    nu_coeff=1e-5,
    delta_coeff=1e-5,
    use_group_wise_regression_init=True,
)

pi_eval = AlternativePolicy(2)

grouping_config = GroupingConfig()

# %%
if COMPUTE_TRUTH:
    truth_data_config_init = copy.copy(data_config_init)
    truth_data_config_init.pop("num_trajectories")
    us, vs = compute_UV_truths(
        truth_data_config_init,
        algo_config.discount,
        pi_eval,
        num_repeats=100,
        num_trajectories=1000,
    )  # For best results, use num_repeats=10
    u_truth = us.mean(axis=0)
    v_truth = vs.mean(axis=0)

    with open(TRUTH_FILE, "wb") as f:
        pickle.dump(
            dict(
                u_truth=u_truth,
                v_truth=v_truth,
                data_config_dict=truth_data_config_init,
                algo_config_dict=attrs.asdict(algo_config),
            ),
            f,
        )
else:
    with open(TRUTH_FILE, "rb") as f:
        loaded = pickle.load(f)
        u_truth = loaded["u_truth"]
        v_truth = loaded["v_truth"]

# %%
beta_ng_list = []
beta_learned_list = []

for i in range(NUM_EXPERIMENTS):
    data_config = DataGenConfig(seed=7531 * (i + 1), **data_config_init)
    data = generate_data_from_config(data_config)
    beta_ng_list.append(
        beta_estimate_from_nongrouped(data, pi_eval, algo_config.discount)
    )
    beta_learned_list.append(
        beta_estimate_from_e2e_learning(data, algo_config, grouping_config, pi_eval)
    )
# Out:
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = (0.09711564+0j)
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.11698307 -2.79210784 -2.72765136  2.91444181  1.49520674  2.8087918
#   -1.0812657  -2.77855847  2.86131932  0.895992  ]
#  [-1.10582598  2.93220131  2.92613584 -2.82294296 -1.76469278 -2.8838273
#    1.07637123  2.89561457 -2.91087771 -0.88317579]] and inertia = 127.46361837353281
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = (0.10115076+0j)
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.18266917 -2.8783947  -2.84336967  2.7921839   1.62559649  2.93838724
#   -1.05198432 -2.80890877  2.84624804  0.77057125]
#  [-1.04314016  2.88884104  2.80271885 -2.80015611 -1.66031876 -3.04709217
#    1.12443903  2.6914928  -2.72426852 -0.77449288]] and inertia = 123.56395520192687
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.09961643
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.12647495 -2.90916039 -2.67794057  2.81796932  1.55955843  2.88087103
#   -1.08831303 -2.86132867  2.92146758  0.83390357]
#  [-1.09747159  2.94946684  2.83960235 -2.72159393 -1.7825015  -2.85553931
#    1.07924611  2.84525792 -2.73358561 -1.00044646]] and inertia = 127.11762858543838
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.098953865
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.02507873 -3.08705164 -2.8241758   2.89931278  1.77336176  2.97328319
#   -1.08497386 -3.10976287  2.87093228  0.9810603 ]
#  [-1.102967    2.94681184  2.83132815 -2.88291482 -1.6339397  -2.88000717
#    1.15417291  2.92041642 -2.84620656 -0.94270894]] and inertia = 123.42313143578889
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = (0.09813526+0j)
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.13189543 -2.8671918  -2.83297248  2.85626769  1.57238788  2.91260653
#   -1.04767641 -2.82337693  2.87446441  0.76519515]
#  [-1.18003744  3.05626741  2.85770082 -2.8214591  -1.76087726 -2.96650504
#    1.07733521  3.02247807 -2.75434589 -1.02910699]] and inertia = 130.22754975345015
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.09835956
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.02766251 -2.90155035 -2.8579964   2.84253501  1.68599715  2.89589447
#   -1.07637089 -2.75984849  2.7245768   0.85732301]
#  [-1.0388997   2.86908731  2.80056584 -2.75386824 -1.6738944  -2.9459553
#    1.16671707  2.86267925 -2.65073955 -0.97261913]] and inertia = 125.08973976320726
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.10114371
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.08596758 -2.9260858  -2.6927733   2.62175449  1.73770688  2.92800888
#   -1.09146095 -2.71541472  2.80198636  0.80540465]
#  [-1.06842589  3.00469008  2.84127446 -2.64928205 -1.88798439 -2.83222981
#    1.03035467  2.75430965 -2.80725965 -0.88370908]] and inertia = 121.92624871597359
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.09637449
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.12486497 -2.85095986 -2.79826177  2.71305302  1.64674465  2.92054345
#   -1.08528865 -2.93591244  2.71358474  0.96408463]
#  [-1.16749852  2.82803715  2.9465872  -2.90050229 -1.63135923 -2.8072248
#    1.08542157  2.89095225 -2.98427149 -0.86799224]] and inertia = 130.22902739055473
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.10160999
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.09250981 -2.80551121 -2.74935886  2.81040458  1.58553627  2.73106762
#   -1.16529005 -2.7163609   2.74769864  0.96199601]
#  [-1.0480386   2.90878228  2.85622796 -2.86112273 -1.65585498 -2.76820278
#    1.03567047  2.85194929 -2.72028718 -0.95895467]] and inertia = 121.07437461965021
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = (0.09959383+0j)
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.17933168 -2.97815245 -2.62941656  2.91320672  1.47778237  2.87799202
#   -1.10251857 -2.6274877   2.73157633  0.83706329]
#  [-1.06817848  2.9692475   2.77247152 -2.87377161 -1.60289558 -2.79981632
#    1.10336712  2.83466736 -2.70269333 -0.95887935]] and inertia = 125.0795840096859
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.09941865
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.04449952 -2.78423018 -2.59236433  2.85157403  1.38991742  2.87488877
#   -1.05412956 -2.88292948  2.78012526  0.88085701]
#  [-1.10065712  2.78392287  2.69971692 -2.85841494 -1.4821599  -3.01120189
#    1.14198884  2.82424496 -2.92185743 -0.72534514]] and inertia = 127.86821099669625
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.09930448
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.05656146 -2.79571743 -2.73303505  2.95960609  1.44386415  2.82086191
#   -1.11997153 -2.78250218  2.8479668   0.83002696]
#  [-1.09876231  2.92761002  2.69405365 -2.87109917 -1.54768866 -2.86832012
#    1.03253509  2.89096117 -2.79675225 -0.85428167]] and inertia = 127.35408119943196
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.096127644
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.09618911 -2.96908015 -2.81616438  2.82451089  1.64573069  2.88579273
#   -1.11752997 -2.85639897  2.76363454  0.91096078]
#  [-1.04193727  2.98567554  2.86187701 -2.63683976 -1.85986847 -2.99410562
#    1.04623357  2.92532419 -2.74493506 -0.88594135]] and inertia = 127.42764729215465
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = (0.09795331+0j)
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.07426482 -3.05021761 -3.00961264  2.84800804  1.80146338  2.9471888
#   -1.05146659 -2.88411397  2.79500457  0.83682807]
#  [-1.07745476  2.95274153  2.85907607 -2.7847755  -1.67188656 -2.89872867
#    1.19750312  2.89704984 -2.76325227 -0.90470608]] and inertia = 125.44222518025371
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.09666582
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.07190705 -2.90144019 -2.90736079  2.73249242  1.75396533  2.81022177
#   -1.16555572 -2.78183331  2.7838928   0.90748668]
#  [-1.03744223  2.96221788  2.81072877 -2.82934274 -1.68564277 -2.95439813
#    1.0386462   2.85910559 -2.77511522 -0.81815355]] and inertia = 124.29825872214349
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.101031326
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.05784857 -2.95766623 -2.91924374  2.80499705  1.7481658   2.86902876
#   -1.07101509 -2.99794302  2.82754867  0.9365681 ]
#  [-1.06708524  2.89902901  2.74340391 -2.81140015 -1.57172923 -2.98444505
#    1.06383667  2.7832074  -2.74821905 -0.79122415]] and inertia = 126.78015787814894
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.097936966
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.06353676 -2.96670276 -2.73374169  2.71281235  1.73724104  2.87173418
#   -0.98956782 -2.79290312  2.78770408  0.82004387]
#  [-1.18342228  2.85209439  2.80393123 -2.86575367 -1.52376972 -3.01272082
#    1.06992765  2.95203761 -2.80703908 -0.85283228]] and inertia = 124.12469350377121
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.09798281
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.03386392 -2.76459626 -2.67039457  2.91050736  1.4706551   2.93444463
#   -1.02509947 -2.78566906  2.70673817  0.85759281]
#  [-1.05379485  2.99370119  2.77124201 -2.79476671 -1.68934361 -2.86074673
#    1.1261549   2.90411376 -2.76163631 -0.93207633]] and inertia = 114.92237837188446
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = (0.100047134+0j)
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.08407077 -2.9363014  -2.99425777  2.85285837  1.74505442  2.8544302
#   -1.08036206 -3.0104424   2.73170536  0.98709631]
#  [-1.10243178  3.03937853  2.86904072 -2.86040415 -1.72570313 -2.82731728
#    1.03351286  2.79649555 -2.91448781 -0.79540226]] and inertia = 128.69651540029716
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.09904663
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.11296605 -2.87449212 -2.8671494   2.79065196  1.65628087  2.74647161
#   -1.04995529 -2.88324235  2.81763937  0.93495109]
#  [-1.12755594  2.95427043  2.78658292 -2.81896769 -1.5665189  -2.8258136
#    1.11727833  2.80245768 -2.85550446 -0.80580324]] and inertia = 130.0544884649426
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = (0.09823505+0j)
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.04031737 -2.94575037 -2.89248864  2.86682407  1.6523191   2.75807077
#   -1.10766671 -2.82865303  2.90791676  0.79434159]
#  [-1.17000665  2.95502772  2.79469871 -3.02388161 -1.5189511  -2.81459827
#    1.13319372  2.97010234 -2.98708288 -0.91123897]] and inertia = 122.40112228072155
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.098169275
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.06785277 -2.99662848 -2.72565771  2.86002905  1.61174524  2.96353582
#   -1.08232026 -2.84340141  2.95631855  0.66237007]
#  [-1.0943957   2.8320125   2.80339376 -2.81361983 -1.63376018 -2.87009302
#    1.08203807  2.76237659 -2.8130116  -0.85887228]] and inertia = 123.82236995417315
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.10086211
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.06817128 -2.8801622  -2.84562501  2.76124957  1.74284886  2.85979454
#   -1.06794125 -2.85002136  2.75232228  0.94473569]
#  [-1.05883997  2.87261288  2.78332564 -2.81939215 -1.62466784 -2.77869589
#    1.17918952  2.81413544 -2.8887744  -0.8703425 ]] and inertia = 124.3140538723071
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.09731646
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.17158529 -2.93847669 -2.729132    3.00688147  1.4805762   2.87125411
#   -1.15247012 -2.7416893   2.90770053  0.75708834]
#  [-1.07022716  2.99788571  2.92667224 -2.82431751 -1.76905288 -2.82250486
#    0.96767364  2.92998792 -2.83932545 -0.88297635]] and inertia = 122.59800402320741
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = (0.09775343+0j)
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 0.99059662 -2.88644065 -2.75946032  2.94627379  1.62968346  2.84705765
#   -1.1049723  -2.74219411  3.02987794  0.72688593]
#  [-1.00781202  2.88668513  2.84009613 -3.09203561 -1.50939796 -2.88854481
#    1.10709209  2.80093028 -2.92432199 -0.75528073]] and inertia = 126.02549612731009
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.099461496
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.14849238 -2.85125626 -2.79048408  2.74376688  1.63336041  2.84412158
#   -1.13685162 -2.865792    2.83423305  0.90019913]
#  [-1.07231562  3.09392597  2.88140153 -2.80359378 -1.81166021 -2.853362
#    1.03980196  2.84307223 -2.80767032 -0.87938088]] and inertia = 122.37799639689547
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.097558826
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.18021007 -2.89073888 -2.87277192  2.83214648  1.6374479   2.78898908
#   -1.10504492 -2.85346023  2.83351164  0.95220336]
#  [-1.11299978  2.98033262  2.79876878 -3.04033163 -1.61118642 -2.87714231
#    1.03560522  2.89112032 -2.72638584 -0.99038818]] and inertia = 129.00001948067668
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.10058613
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.15423287 -2.86654797 -2.88358409  2.90101856  1.58378688  2.89456408
#   -1.17670018 -2.90661323  2.86043987  0.91299735]
#  [-1.20962165  2.88291116  2.83700719 -3.01828481 -1.47685249 -2.81427642
#    1.10604149  2.87394029 -3.03676385 -0.76242515]] and inertia = 126.26543282211702
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.09955815
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.16179749 -2.8981307  -2.78778069  2.91269264  1.56267945  2.91085465
#   -1.16160528 -2.78013182  3.03796994  0.7234113 ]
#  [-1.0498408   2.8255356   2.78678888 -2.82177252 -1.60757239 -2.89850504
#    1.05504154  2.63622664 -2.90281522 -0.65308771]] and inertia = 121.56043359558502
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.098167166
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.1021424  -2.86063233 -2.85960051  2.81368081  1.62215958  2.66367351
#   -1.09109003 -2.73695351  2.74095829  0.97517478]
#  [-1.16483392  2.83611876  2.9515175  -2.82985374 -1.618415   -2.81412536
#    1.06783699  2.82587631 -2.93917648 -0.79824519]] and inertia = 128.00102670990879
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = (0.096554115+0j)
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.08634155 -2.96470973 -2.81364984  2.82170258  1.66893735  2.84515473
#   -1.07266278 -2.74732942  2.8728282   0.77104413]
#  [-1.00478482  2.92252313  2.83067227 -2.88006556 -1.61622015 -2.94465434
#    1.12189822  2.82576006 -2.73370974 -0.86042208]] and inertia = 127.09597178430965
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.09955738
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.08436757 -2.93063014 -2.89069009  2.91793669  1.67863119  2.8828921
#   -1.01476104 -2.85639909  2.83629413  0.85894844]
#  [-1.05613297  2.84108869  2.83430747 -2.91449548 -1.57291364 -2.8553819
#    1.08018435  2.81303093 -2.88731655 -0.78382265]] and inertia = 126.67785150247954
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = (0.10118213+0j)
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.08004006 -2.86717817 -2.85124941  2.84738435  1.66564927  2.96541541
#   -1.09256912 -2.79714326  2.76750875  0.82581854]
#  [-1.10813648  2.90934242  2.91570739 -2.94935336 -1.68980908 -2.88699703
#    1.10350793  2.79339177 -2.81090225 -0.85297817]] and inertia = 119.32819842530186
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.1002432
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.12544523 -2.87762873 -2.74936587  2.78366784  1.60901009  2.90541164
#   -1.15213956 -2.67829072  2.80037908  0.79696817]
#  [-1.21510853  2.85375926  2.81463459 -2.83133317 -1.60497091 -2.79304269
#    1.07763385  2.91342787 -2.88623197 -0.99315102]] and inertia = 126.7088594572419
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.09679038
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.07910113 -3.04118113 -2.71741616  2.79962958  1.64552064  2.86400625
#   -1.09187102 -2.81617225  2.82295865  0.82488448]
#  [-1.18558264  2.82411438  2.88854936 -2.85995565 -1.59568164 -2.81314268
#    1.07761489  2.79584809 -2.81165433 -0.89538433]] and inertia = 123.15341836953806
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.09855996
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 0.96843774 -2.96056576 -2.85176336  2.85180538  1.76666445  2.99581249
#   -1.07783918 -2.76330772  2.84681874  0.75274391]
#  [-1.06600422  2.91633322  2.74212707 -2.86112049 -1.59908144 -2.82389153
#    1.08673068  2.81688947 -2.83323073 -0.8863878 ]] and inertia = 123.28876543609152
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.098689504
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.05166275 -2.86461764 -2.73496781  2.79587471  1.58147473  2.83625183
#   -1.10135164 -2.66322868  2.81517545  0.74462707]
#  [-1.03210797  2.97581721  2.79624178 -2.95393192 -1.63499844 -2.92553127
#    1.01747929  2.74012163 -2.88515843 -0.75482662]] and inertia = 124.53632635105731
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = (0.10187719+0j)
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.13365441 -2.90889904 -2.79095258  2.86713109  1.62890905  2.92202993
#   -1.01165563 -2.95080827  2.86781735  0.847293  ]
#  [-1.14500815  2.86959636  2.93115378 -2.77240848 -1.75976326 -2.82976949
#    0.9564985   2.97681524 -2.82223245 -0.98911198]] and inertia = 125.29422046139537
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.09834853
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.05410984 -2.86792878 -2.80976211  2.85590948  1.67280361  3.06162339
#   -1.07970491 -2.74682892  2.8603191   0.7283519 ]
#  [-1.11398034  2.92283527  2.78161929 -2.77621722 -1.61944583 -2.87518003
#    1.22718158  2.76421326 -2.75026085 -0.92163049]] and inertia = 131.5339049280422
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.09892353
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.04818156 -2.94479205 -2.88904907  2.90812058  1.61732432  2.8805982
#   -1.02521086 -2.8338454   2.91252414  0.74923294]
#  [-1.07157275  2.84167638  2.88468346 -2.87726256 -1.58645193 -2.95776617
#    1.05280285  2.96832244 -2.77098189 -0.91711685]] and inertia = 133.89615495677535
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.099531256
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.03754653 -2.82557929 -2.83300739  2.87291397  1.6019984   2.90676485
#   -1.12938012 -2.88502497  2.89469577  0.84810624]
#  [-1.10683821  2.89972591  2.74717491 -2.76241938 -1.68709229 -2.89061554
#    0.99117957  2.76685856 -2.71376698 -0.90398082]] and inertia = 122.37471054606081
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = (0.099525474+0j)
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.0485503  -2.98557009 -2.8104631   2.99045758  1.59521871  2.89520496
#   -1.14142701 -2.80077678  2.95009811  0.77442989]
#  [-1.10297404  2.98393174  2.65921058 -2.77837142 -1.58895298 -2.95442242
#    1.09115283  2.81838244 -2.86302716 -0.76833715]] and inertia = 122.82693554380457
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = (0.099904604+0j)
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 0.99799673 -2.88392933 -2.91870004  2.62441645  1.84510529  2.96511727
#   -1.11406527 -2.85543278  2.64461238  0.91415915]
#  [-1.04695109  3.05832005  2.86542351 -2.78351424 -1.79556728 -2.88094047
#    1.06216055  2.99861659 -2.71748818 -0.98760024]] and inertia = 117.7918355606328
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.09874569
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.08592578 -2.96538041 -2.84052086  2.83597446  1.65882012  2.83133877
#   -1.11491681 -2.7261524   2.86950446  0.79436511]
#  [-1.08887775  2.92906679  2.77230861 -3.03949523 -1.53603487 -2.8798112
#    1.0993194   2.88550353 -2.87753162 -0.89400037]] and inertia = 125.67010977741408
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.0995007
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.11947586 -2.90710771 -2.81241148  2.82035323  1.68210862  2.94313816
#   -1.02642212 -2.8902606   2.74684266  0.92289951]
#  [-0.96513496  3.00060526  2.75075436 -2.82988937 -1.72216754 -2.9346329
#    1.0787688   2.87195077 -2.90634135 -0.78292189]] and inertia = 121.43468879002052
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.100663826
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.20986072 -2.99868839 -2.73758875  2.77007948  1.60922278  2.80988089
#   -1.05950293 -2.80167609  2.79354604  0.90291114]
#  [-1.12179787  3.03894249  2.94423007 -2.79284171 -1.75100003 -2.84793647
#    1.11848724  2.99446829 -2.81528833 -0.92296412]] and inertia = 126.10479036663499
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = (0.0964817+0j)
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.0424928  -2.91109713 -2.82956978  2.69528527  1.7886982   2.8353545
#   -1.08571181 -2.85175809  2.69899608  0.96489552]
#  [-1.07380787  2.91919155  2.71102865 -2.83976734 -1.5943291  -2.81156864
#    1.03604921  2.75223173 -2.68589449 -0.90791461]] and inertia = 118.0003642135198
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.09657232
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.08689077 -2.95400589 -2.71964006  2.67352524  1.68560995  2.96400434
#   -0.99289115 -2.76385616  2.80569573  0.71919447]
#  [-1.10428362  2.8640888   2.82949334 -2.70092587 -1.72208295 -2.89530693
#    1.03580957  2.83212373 -2.77816868 -0.87636054]] and inertia = 118.52434595922762
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.09941643
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.10761116 -2.88580377 -2.82788262  2.8956061   1.58847223  2.91359377
#   -1.06186167 -2.87302901  2.7994449   0.84837319]
#  [-1.16293312  2.99142946  2.86059961 -2.78955616 -1.73151478 -2.89220036
#    1.1033942   2.90444654 -2.73878697 -0.99261197]] and inertia = 124.68178353659098
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.09601976
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.05307212 -2.89353262 -2.88580078  2.91144021  1.6439533   2.99642506
#   -1.0130603  -2.64022705  2.95631023  0.54769423]
#  [-1.07328135  2.98446093  2.74768928 -2.8478429  -1.59640141 -3.05747629
#    1.07900235  2.91039536 -2.84601891 -0.74404203]] and inertia = 127.05971835458263
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.097847655
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.03997113 -2.89095428 -2.97867465  2.81448257  1.77049965  2.76698511
#   -1.04800842 -3.03546893  2.74733704  1.07144276]
#  [-1.02798771  2.8693883   2.92018527 -2.8831596  -1.67542616 -2.91517174
#    1.09906774  2.89667585 -2.81935003 -0.88429209]] and inertia = 124.34488270743297
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.09828472
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.04214215 -2.84537659 -2.79003722  2.8102811   1.68408336  2.9968517
#   -1.15116457 -3.08903223  2.76453872  1.00395177]
#  [-1.09904479  2.9264004   2.96588264 -2.73915953 -1.85676585 -2.84495061
#    1.06272323  2.97781801 -2.73831504 -1.03092874]] and inertia = 118.7248480987883
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.09810946
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.02856931 -2.90586641 -2.98395941  3.00131454  1.70400575  2.93683769
#   -1.15115814 -2.89426617  2.76695075  0.95441754]
#  [-1.10162388  2.95280092  2.92700922 -2.9849179  -1.56688069 -2.85498981
#    1.14009248  2.83106427 -2.95457337 -0.77716039]] and inertia = 132.12924556375555
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.09944725
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.10854392 -2.83053689 -2.77845271  2.79483104  1.60797005  2.74566074
#   -1.15110778 -2.79668954  2.84600559  0.94490011]
#  [-1.10684819  2.87808024  2.90390592 -2.79914905 -1.67846423 -2.76257681
#    1.16147761  2.89611659 -2.79232114 -0.99142613]] and inertia = 122.72129912415338
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.09843881
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.08530677 -2.94865043 -2.854458    2.73387662  1.79975868  2.9448223
#   -1.0478875  -2.679846    2.63636776  0.89089595]
#  [-1.10014249  2.97285297  2.82232937 -2.59066186 -1.80211076 -3.00634258
#    1.02509264  2.8351766  -2.73582231 -0.82134991]] and inertia = 122.51105654771584
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.09880071
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.19381286 -2.85987786 -2.85311267  2.76842011  1.6584892   2.72492721
#   -1.13483763 -2.74746239  2.84220761  0.88098724]
#  [-1.02151962  2.92073395  2.93152781 -2.84492191 -1.70595777 -2.98306222
#    1.0637254   2.85148603 -2.80424905 -0.76369167]] and inertia = 118.22228336203042
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.0978289
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.0269685  -2.89919934 -2.70427414  2.80913672  1.616236    2.92152454
#   -1.07216993 -2.8466983   2.80282705  0.86227502]
#  [-1.07796748  2.93755819  2.80765499 -2.77958621 -1.68679643 -2.86433805
#    1.05416257  2.80258181 -2.90506864 -0.76924065]] and inertia = 122.09302589034422
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.09834202
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.11777919 -2.97491288 -2.74957671  2.87671784  1.65278091  2.9575036
#   -1.16546723 -2.78032155  2.83731782  0.87262883]
#  [-1.09935851  2.83547419  2.87377205 -2.8665116  -1.65118446 -3.02292891
#    1.11784774  2.8476189  -2.7316734  -0.89344939]] and inertia = 128.02392921908188
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = (0.099423476+0j)
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.08855206 -2.90474476 -2.75456537  2.79692856  1.63989338  2.8220694
#   -1.10005937 -2.79712004  2.90705746  0.86349452]
#  [-1.09259375  2.7980207   2.89550851 -2.86935037 -1.66176382 -2.92975417
#    1.10443889  2.79157817 -2.78903727 -0.87127224]] and inertia = 121.83704836459398
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = (0.09989025+0j)
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.07955551 -2.76776618 -2.91231982  2.7918087   1.65207446  2.7728372
#   -1.0474675  -2.81500681  2.77660569  0.91664718]
#  [-1.09761515  2.92964622  2.85611872 -2.90032731 -1.64476636 -2.91595378
#    1.04782312  2.87291356 -2.78047401 -0.86687515]] and inertia = 125.31030637350162
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.09911681
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.04043239 -3.01314536 -2.87244025  2.79767634  1.80214064  2.90248545
#   -1.05335232 -2.83256615  2.83900978  0.81453609]
#  [-1.05487757  2.92867285  2.7955676  -2.9841581  -1.55062066 -2.99809166
#    1.04453129  2.81229447 -2.87986484 -0.78583449]] and inertia = 132.4189687531733
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.0986158
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.08935058 -2.94611071 -2.82805587  2.85855463  1.65156102  2.70554875
#   -1.07123512 -2.8716497   2.78700305  0.98804284]
#  [-1.13879554  2.70538057  2.82540494 -2.78097914 -1.60419548 -2.93370356
#    1.10948433  2.87440236 -2.84079076 -0.88720443]] and inertia = 124.54994906614043
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = (0.09870588+0j)
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.12864439 -3.04741625 -2.84938074  2.72468715  1.78924482  2.90717517
#   -1.10280885 -2.80078512  2.70922505  0.92467941]
#  [-1.12450497  2.99862758  2.73987811 -2.84232613 -1.63800545 -2.86111814
#    1.11685736  2.87989925 -2.86785372 -0.86454187]] and inertia = 117.01232417555303
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.099102475
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.08479701 -2.83133743 -2.87622914  2.88933721  1.63098779  3.06821604
#   -1.14842275 -2.97410045  2.73543861  0.92195369]
#  [-1.06494723  2.93361697  2.85820232 -2.85055788 -1.62297591 -2.98545685
#    1.01222808  2.97485972 -2.807608   -0.8569378 ]] and inertia = 124.26928164435304
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.098759696
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.02649551 -2.86907043 -2.77860102  2.8076379   1.58247109  2.8689094
#   -1.14934703 -2.79234151  2.75360912  0.86463458]
#  [-1.12740867  2.95712294  2.83263047 -2.66270379 -1.76863492 -2.93254144
#    1.07897877  2.81848218 -2.76648183 -0.86213527]] and inertia = 127.58126077750667
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = (0.09869386+0j)
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.06150313 -2.96681061 -2.96440488  2.85674072  1.76326875  2.9834984
#   -1.12197771 -2.83419996  2.89314164  0.79011199]
#  [-1.04707044  2.94343467  2.78457954 -2.85441062 -1.68453134 -2.87711231
#    1.06143504  2.84779675 -2.89098572 -0.8174701 ]] and inertia = 127.57651864000209
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.097210094
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.05722904 -3.02014256 -2.77678852  2.75911863  1.77331653  2.87783199
#   -1.08091817 -2.80440023  2.73752041  0.90493365]
#  [-1.13717245  2.95531545  2.7827356  -2.68090578 -1.71741746 -2.81334404
#    1.17204518  2.7785305  -2.90926198 -0.86581151]] and inertia = 122.8514605995662
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.09871807
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.08532689 -2.96673011 -2.79768529  2.88772735  1.64583898  2.84433012
#   -1.12724017 -2.73540046  2.81237842  0.85723184]
#  [-1.13604518  2.86675991  2.7682185  -2.78323022 -1.59062001 -2.8718005
#    1.16149825  2.88615403 -2.78848783 -0.93583893]] and inertia = 125.52550271897259
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.09907756
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.06956313 -2.93209613 -2.81353745  2.86691099  1.66628109  2.77619279
#   -1.14273359 -2.83029165  2.86438403  0.93020825]
#  [-1.11006841  2.97423807  2.73670627 -2.78560825 -1.64532201 -2.80770439
#    1.11371907  2.71521557 -2.74854712 -0.87984723]] and inertia = 120.83454658076099
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = (0.09805814+0j)
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.0375495  -2.92788642 -2.84948575  2.71639945  1.75676527  2.86368137
#   -1.0483906  -2.86952419  2.7797026   0.92814496]
#  [-1.06348393  2.91038424  2.71061753 -2.74999568 -1.65854465 -2.98672701
#    1.0693336   2.67399598 -2.85767504 -0.71353909]] and inertia = 127.54760215449458
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.101050265
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.06038222 -2.77107185 -2.84101148  2.84048606  1.60702488  2.88773464
#   -1.06015668 -2.83054048  2.77314212  0.86746647]
#  [-1.03551701  2.84974515  2.81567515 -2.80228874 -1.60226907 -2.82264382
#    1.1675557   2.68543947 -2.8730099  -0.78748432]] and inertia = 119.78689855884787
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = (0.09796093+0j)
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.00664884 -2.84071257 -2.82725965  2.7362224   1.69492879  3.04057526
#   -1.10215197 -2.83616697  2.89514844  0.73190581]
#  [-1.05994649  2.96635081  2.77002128 -2.94095652 -1.66282106 -2.93219363
#    1.10290738  2.86971613 -2.7807984  -0.917074  ]] and inertia = 127.34930113006794
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.09758067
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.11079806 -2.76695042 -2.90408329  2.79650818  1.61906518  2.90947187
#   -1.10279175 -2.82278424  2.76901891  0.86939036]
#  [-1.1236728   2.91151975  3.0146234  -2.73241541 -1.78998202 -2.83192857
#    1.10683519  2.87196829 -2.82142754 -0.87966301]] and inertia = 122.83340205567944
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.09970809
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.08190885 -2.78976648 -2.8106472   2.89581963  1.61074412  3.01315826
#   -1.05024396 -2.91100239  2.88460477  0.80271731]
#  [-1.15713611  2.88596559  2.80294957 -2.84776847 -1.61299728 -2.91138188
#    1.14118901  2.83158619 -2.79688537 -0.89596503]] and inertia = 120.5720877271109
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = (0.10055073+0j)
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.12414098 -2.94263748 -2.84524829  2.68811422  1.79169868  2.89973509
#   -1.06700601 -2.77963827  2.89473436  0.81526484]
#  [-1.07252832  2.79054804  2.85973897 -2.8355094  -1.60545943 -2.83354394
#    1.0602913   2.82135633 -2.77543877 -0.87104624]] and inertia = 117.70992400015967
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.100233614
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.17697739 -2.92693417 -2.81953563  2.7321724   1.67289971  2.75376246
#   -1.11569243 -2.91590373  2.75177457  1.0391561 ]
#  [-1.0154247   2.98458135  2.85573985 -2.78269202 -1.81155989 -2.94674835
#    1.12453619  2.81065773 -2.82677744 -0.83073998]] and inertia = 129.1049746594686
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.10037185
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.09073714 -2.9569562  -2.72850012  2.91532747  1.60381149  2.88818956
#   -1.09411377 -2.77500581  2.84538264  0.83107487]
#  [-1.19846201  2.98514982  2.72607386 -2.85799707 -1.60307611 -2.84399602
#    1.09503187  2.82734734 -2.84000357 -0.91820664]] and inertia = 123.5962992336175
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.09813172
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.01208416 -2.98297342 -2.66645046  2.78007564  1.6883082   2.97602632
#   -1.04053813 -2.75431161  2.80133344  0.78544538]
#  [-1.10567122  3.01955314  2.85033749 -2.7710193  -1.76932775 -2.8942366
#    1.07536446  2.83108193 -2.82924463 -0.85258416]] and inertia = 123.42252527632562
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.099843025
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.09255435 -2.92597388 -2.77376742  2.77229906  1.71542322  2.79427657
#   -1.11811489 -2.79413161  2.82801883  0.93291396]
#  [-1.17348839  2.84722616  2.80760318 -2.80135966 -1.57766806 -2.87435963
#    1.115224    2.75910944 -2.77025353 -0.82358062]] and inertia = 120.69270679051068
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.099466704
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.03527043 -3.0134328  -2.73862117  2.77739727  1.72835881  2.88643624
#   -1.02854332 -2.86768056  2.79508693  0.85149584]
#  [-1.11876149  2.91189613  2.70109762 -2.77874317 -1.55184338 -2.84032131
#    1.05089177  2.82386144 -2.73303256 -0.85094355]] and inertia = 115.27011643513521
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = (0.09927629+0j)
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.08536328 -2.91161854 -2.76474645  2.90207118  1.60253545  2.88026377
#   -1.06224171 -2.83318521  2.90635337  0.81570249]
#  [-1.09870885  2.90903237  2.71391496 -2.78290203 -1.61108305 -2.94698299
#    1.0268701   2.79474813 -2.64566935 -0.90703234]] and inertia = 124.01772821132263
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.0987042
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.07144475 -2.86705206 -2.92525497  2.84304041  1.65087882  2.90208888
#   -1.07225415 -2.88671753  2.904448    0.79173582]
#  [-1.10151751  2.7996614   2.85769209 -2.95812105 -1.50651495 -2.86994379
#    1.08372879  2.90293739 -2.81025874 -0.88658121]] and inertia = 127.30649287693545
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.097652294
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.07398551 -2.77266003 -2.88385554  2.88133828  1.63916094  2.84894683
#   -1.09686281 -2.76392126  2.70738646  0.94504213]
#  [-1.1137196   2.94298161  2.8789977  -2.79791401 -1.63361183 -2.93661739
#    1.11772061  2.83910183 -2.79340446 -0.84680435]] and inertia = 130.55061590420104
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.0995373
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.03822621 -2.9399276  -2.93373552  2.88151177  1.6932688   2.82595842
#   -1.09277831 -2.85963048  2.9276414   0.83536931]
#  [-1.13435541  2.88688079  2.81539189 -2.85362936 -1.61084824 -2.90448296
#    1.02480668  2.87865215 -2.80664838 -0.84766289]] and inertia = 131.3778556901243
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.097010225
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 0.96611431 -2.88444783 -2.80762642  2.82262893  1.63909274  2.950183
#   -1.03269262 -2.65019533  2.99281603  0.49930964]
#  [-1.03142165  2.95799692  2.72214326 -2.83104367 -1.60388534 -2.91134723
#    1.02060629  2.79467461 -2.85375728 -0.73848844]] and inertia = 126.86237318956466
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.09918017
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.05750265 -2.84521203 -2.82681463  2.65818487  1.7251681   2.90368647
#   -1.15273292 -2.99433235  2.77703359  0.99320806]
#  [-1.14780285  2.84761719  2.87054757 -2.82235391 -1.60593592 -2.81805164
#    1.04619232  2.88442199 -2.72824324 -0.9614202 ]] and inertia = 118.81876070566801
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.10041199
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.06069792 -2.9419293  -2.80124252  2.79612945  1.7057729   2.89493309
#   -1.12229235 -2.82962838  2.78956406  0.92743675]
#  [-1.11712052  2.99517967  2.91147942 -2.86054805 -1.71494951 -2.83149722
#    1.05542811  2.75531678 -2.85439063 -0.79430156]] and inertia = 124.87957733194162
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.09610167
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.02632531 -2.79010822 -2.780821    2.72704288  1.63883793  2.84936246
#   -1.13693355 -2.86101526  2.84820293  0.87606786]
#  [-1.06833086  2.91627032  2.85911676 -2.91686065 -1.5967941  -2.93090143
#    1.05357737  3.00964291 -2.91320361 -0.83569573]] and inertia = 125.87621710807531
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.10089391
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.02404069 -2.92713884 -2.92459737  2.85551707  1.72206144  2.92731792
#   -1.08972853 -2.76579427  2.81532502  0.76858462]
#  [-1.05754984  3.01217388  2.77746788 -2.79215866 -1.74858813 -2.85831766
#    1.03695312  2.88931775 -2.72260967 -0.99674023]] and inertia = 123.73866306930563
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = (0.097485475+0j)
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.02490345 -2.98007011 -2.8916701   2.82329238  1.77251586  2.90014231
#   -1.1010056  -2.8539488   2.8764329   0.85692604]
#  [-1.10922239  2.91789087  2.90513079 -2.7435254  -1.75347111 -2.89076413
#    0.96718233  2.91102789 -2.79471647 -0.88426393]] and inertia = 124.47451638109536
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.098715656
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.04182549 -2.99764816 -2.91724005  2.80701476  1.75494553  2.82609476
#   -1.15997989 -2.88885677  2.73162429  0.95535271]
#  [-1.17402703  2.93481959  2.74747843 -2.7662692  -1.63096306 -2.9292476
#    1.06661709  2.77318612 -2.82885508 -0.79690117]] and inertia = 123.95231025407145
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.09935473
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.08169113 -2.88096321 -2.81835236  2.80649639  1.63072082  2.85599982
#   -1.04116237 -2.87362182  2.74881466  0.94169783]
#  [-1.11732844  2.84881533  2.75941482 -2.75009133 -1.59519618 -2.8423289
#    1.11610577  2.81822947 -2.8048744  -0.90355915]] and inertia = 133.12925620167272
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.09704146
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.06017522 -2.84367511 -2.85824373  2.70910932  1.73297973  2.94251656
#   -1.17331214 -2.86252752  2.90984785  0.8066172 ]
#  [-1.07383102  3.04841061  2.96089107 -3.01659064 -1.7012142  -3.08329472
#    1.04160631  2.93856303 -2.87446812 -0.76639621]] and inertia = 127.2032822544076
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = (0.09846685+0j)
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.18426374 -2.89823774 -2.74471677  2.71186165  1.66086793  2.8790905
#   -1.08573948 -2.92353451  2.73792433  1.01719447]
#  [-1.1521214   3.00952556  2.91122872 -2.74822355 -1.81497337 -2.86325996
#    1.03593332  3.0289791  -2.85011907 -0.97055603]] and inertia = 123.30601181826616
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.09932521
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.06880772 -2.98501952 -2.80609776  2.78207914  1.71449709  2.96709428
#   -1.13698137 -2.7869717   2.63446038  0.90781601]
#  [-1.1173708   2.99584195  2.77531573 -2.93689084 -1.57466368 -2.89952164
#    1.0915584   2.81663652 -2.81905694 -0.83813939]] and inertia = 129.81183086621087
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.09922253
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.17386703 -2.99966573 -2.96734918  2.79757106  1.82749208  2.87836712
#   -1.06088886 -2.87149822  2.6565249   1.00903615]
#  [-1.01308259  2.96218678  2.87200063 -2.82313433 -1.70514417 -2.80073587
#    1.07818663  2.90229965 -2.80189381 -0.94151386]] and inertia = 125.58086164900493
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.09909252
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.06791072 -2.98843764 -2.83524598  2.74240363  1.77786686  2.94421663
#   -1.09236485 -2.86589977  2.82391063  0.87248413]
#  [-1.06124682  2.86854697  2.75170729 -2.84237465 -1.55687829 -2.85089639
#    1.07907156  2.83775964 -2.87008548 -0.80169237]] and inertia = 128.20343372297805
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.10112577
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.07653354 -2.85189069 -2.85719134  2.77554559  1.68575932  2.79805311
#   -1.21309814 -2.88789345  2.89158951  0.93383114]
#  [-1.09378817  2.94163922  2.77025217 -2.80882708 -1.63135272 -2.76958273
#    1.01610811  2.86521424 -2.7771887  -0.92812193]] and inertia = 121.18772185992842
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = (0.097606264+0j)
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.13124376 -2.92346596 -2.80591364  2.81482705  1.60283395  2.92326883
#   -1.0946556  -2.92447653  2.78546581  0.90033735]
#  [-1.08693264  2.70957733  2.86938727 -2.74070616 -1.59921257 -2.86246986
#    1.1477102   2.94199128 -2.71416775 -1.01833536]] and inertia = 127.39894352748628
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# new_labels.length=8000 matches number of records
# beta_solver, min eigen of left matrix = 0.10005048
# MCPImpl: num_above=10000, num_below=9900
# kmeans center = [[ 1.08759779 -2.89621454 -2.90046804  2.82651433  1.72635637  2.88603031
#   -1.10426558 -3.00895365  2.78216742  1.00739776]
#  [-1.10112615  3.14188571  2.90576187 -2.905895   -1.78154795 -3.06190197
#    1.06972211  2.97686585 -2.82162261 -0.84794464]] and inertia = 126.18761010853676
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=8000 matches number of records

# %%
beta_learned_list[0].betas
# Out:
# [array([-1.13168126,  2.88023033,  2.95894047, -2.91015014, -1.68966461,
#         -2.89715212,  1.10132794,  2.92539368, -2.93005162, -0.8917558 ]),
#  array([ 1.11786714, -2.83703551, -2.73071427,  2.8841388 ,  1.54645023,
#          2.79443523, -1.09286539, -2.76965158,  2.91968194,  0.86873661])]

# %%
mu_learned_list = []
sigma_learned_list = []
z_score_learned_list = []
mu_ng_list = []
sigma_ng_list = []
z_score_ng_list = []

for beta_learned, beta_ng in zip(beta_learned_list, beta_ng_list):
    v_mus, v_sigmas = compute_V_estimate(u_truth, beta_learned)
    z_score_learned = [
        (mu - truth) / sigma for mu, truth, sigma in zip(v_mus, v_truth, v_sigmas)
    ]
    mu_learned_list.append(v_mus)
    sigma_learned_list.append(v_sigmas)
    z_score_learned_list.append(z_score_learned)

    ngv_mus, ngv_sigmas = compute_V_estimate(u_truth, beta_ng)
    z_score_ng = [
        (mu - truth) / sigma
        for mu, truth, sigma in zip(
            ngv_mus * len(v_truth), v_truth, ngv_sigmas * len(v_truth)
        )
    ]
    mu_ng_list.append(ngv_mus)
    sigma_ng_list.append(ngv_sigmas)
    z_score_ng_list.append(z_score_ng)

# %%
z_score_learned
# Out:
# [-0.8117784976997229, -0.20937281619415204]

# %%
v_mus, v_truth, v_sigmas
# Out:
# ([-1.266620966415501, 1.2445002899201323],
#  array([-1.2428372,  1.2507738], dtype=float32),
#  [0.029298356454185, 0.029963286029091773])

# %% [markdown]
# # Reports that average over two groups

# %%
z_score_learned = np.array(z_score_learned_list)
z_score_ng = np.array(z_score_ng_list)
Z_THRESHOLD = 1.96
learned_in_threshold = np.abs(z_score_learned) < Z_THRESHOLD
ng_in_threshold = np.abs(z_score_ng) < Z_THRESHOLD
learned_in_threshold_perc = learned_in_threshold.sum() / learned_in_threshold.size
ng_in_threshold_perc = ng_in_threshold.sum() / ng_in_threshold.size
print(
    "learned_in_threshold_perc=",
    learned_in_threshold_perc,
    ", ng_in_threshold_perc=",
    ng_in_threshold_perc,
)
if SAVE_RESULT:
    with open(RESULT_FILE, "wb") as f:
        pickle.dump(
            dict(
                mu_learned_list=mu_learned_list,
                sigma_learned_list=sigma_learned_list,
                z_score_learned=z_score_learned,
                mu_ng_list=mu_ng_list,
                sigma_ng_list=sigma_ng_list,
                z_score_ng=z_score_ng,
                beta_learned_list=beta_learned_list,
                beta_ng_list=beta_ng_list,
            ),
            f,
        )
# Out:
# learned_in_threshold_perc= 0.97 , ng_in_threshold_perc= 0.0

# %%
ac_acl = 2*Z_THRESHOLD*np.mean(sigma_learned_list)
ac_mse = np.mean( (mu_learned_list - v_truth)**2 )

mv_acl = 2*Z_THRESHOLD*np.mean(sigma_ng_list)
mv_mse = np.mean( (mu_ng_list - v_truth)**2 )

# %%
print("ACPE results: (average over groups)")
print(f"ACL: {ac_acl}") 
print(f"MSE: {ac_mse}")
print(f"ECP: {learned_in_threshold_perc}")


print("MVPE results: (average over groups)")
print(f"ACL: {mv_acl}") 
print(f"MSE: {mv_mse}")
print(f"ECP: {ng_in_threshold_perc}")
# Out:
# ACPE results: (average over groups)
# ACL: 0.11517639197522714
# MSE: 0.0007594814179812259
# ECP: 0.97
# MVPE results: (average over groups)
# ACL: 0.14371708455888213
# MSE: 1.5564858876388887
# ECP: 0.0

# %% [markdown]
# # Reports that seperate two groups

# %%
z_score_learned = np.array(z_score_learned_list)
z_score_ng = np.array(z_score_ng_list)
Z_THRESHOLD = 1.96
learned_in_threshold = np.abs(z_score_learned) < Z_THRESHOLD
ng_in_threshold = np.abs(z_score_ng) < Z_THRESHOLD

learned_in_threshold_perc = np.sum(learned_in_threshold, axis=0) / learned_in_threshold.shape[0]
ng_in_threshold_perc = np.sum(ng_in_threshold, axis=0) / ng_in_threshold.shape[0]

print(
    "learned_in_threshold_perc=",
    learned_in_threshold_perc,
    ", ng_in_threshold_perc=",
    ng_in_threshold_perc,
)

if SAVE_RESULT:
    with open(RESULT_FILE, "wb") as f:
        pickle.dump(
            dict(
                mu_learned_list=mu_learned_list,
                sigma_learned_list=sigma_learned_list,
                z_score_learned=z_score_learned,
                mu_ng_list=mu_ng_list,
                sigma_ng_list=sigma_ng_list,
                z_score_ng=z_score_ng,
                beta_learned_list=beta_learned_list,
                beta_ng_list=beta_ng_list,
            ),
            f,
        )
# Out:
# learned_in_threshold_perc= [0.94 1.  ] , ng_in_threshold_perc= [0. 0.]

# %%
ac_acl = 2*Z_THRESHOLD*np.mean(sigma_learned_list, axis=0)
ac_mse = np.mean((mu_learned_list - v_truth)**2, axis=0)

mv_acl = 2*Z_THRESHOLD*np.mean(sigma_ng_list, axis=0)
mv_mse = np.mean( (mu_ng_list - v_truth)**2, axis=0 )

# %%
print("ACPE results: Group1, Group 2")
print(f"MSE: {ac_mse}")
print(f"ACL: {ac_acl}") 
print(f"ECP: {learned_in_threshold_perc}")

print("===")
print("MVPE results: ")
print(f"MSE: {mv_mse}")
print(f"ACL: {mv_acl}") 
print(f"ECP: {ng_in_threshold_perc}")
# Out:
# ACPE results: Group1, Group 2
# MSE: [0.00090265 0.00061632]
# ACL: [0.11530798 0.11504481]
# ECP: [0.94 1.  ]
# ===
# MVPE results:
# MSE: [1.53640846 1.57656331]
# ACL: [0.14371708]
# ECP: [0. 0.]
