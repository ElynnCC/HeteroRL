# %% [markdown]
# # Generate Synthetic Data from Real Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle

# %%
RAW_DATA = pd.read_pickle("rl_samples.pkl")

# %%
print(RAW_DATA.shape)
print(RAW_DATA.columns)
# Out:
# (278598, 68)
# Index(['bloc', 'icustayid', 'charttime', 'gender', 'age', 'elixhauser',
#        're_admission', 'died_in_hosp', 'died_within_48h_of_out_time',
#        'mortality_90d', 'delay_end_of_record_and_discharge_or_death',
#        'Weight_kg', 'GCS', 'HR', 'SysBP', 'MeanBP', 'DiaBP', 'RR', 'SpO2',
#        'Temp_C', 'FiO2_1', 'Potassium', 'Sodium', 'Chloride', 'Glucose', 'BUN',
#        'Creatinine', 'Magnesium', 'Calcium', 'Ionised_Ca', 'CO2_mEqL', 'SGOT',
#        'SGPT', 'Total_bili', 'Albumin', 'Hb', 'WBC_count', 'Platelets_count',
#        'PTT', 'PT', 'INR', 'Arterial_pH', 'paO2', 'paCO2', 'Arterial_BE',
#        'Arterial_lactate', 'HCO3', 'mechvent', 'Shock_Index', 'PaO2_FiO2',
#        'median_dose_vaso', 'max_dose_vaso', 'input_total', 'input_4hourly',
#        'output_total', 'output_4hourly', 'cumulated_balance', 'SOFA', 'SIRS',
#        'act_iv', 'act_vaso', 'action', 'step', 'state', 'next_state',
#        'trajectory', 'done', 'reward'],
# ...

# %% [markdown]
# # Generate Pseudo data

# %%
mu = 0      # mean
sigma = 1   # standard deviation

PSEUDO_RAW_DATA = pd.DataFrame(sigma * np.random.randn(*RAW_DATA.shape) + mu, index=RAW_DATA.index, columns=RAW_DATA.columns)

# %%
PSEUDO_RAW_DATA_PART = PSEUDO_RAW_DATA.iloc[:500, :]

# %%
with open("pseudo_rl_samples.pkl", "wb") as file:
    pickle.dump(PSEUDO_RAW_DATA, file)

# %%
PSEUDO_RAW_DATA.head()
# Out:
#        bloc  icustayid  charttime    gender       age  elixhauser  \
# 0  0.592055  -0.595004   0.124026 -0.902661 -1.443656    0.014116
# 1  0.319379   1.167217   1.859858  0.367209 -1.065071   -1.387737
# 2  1.782966  -0.324005  -0.628978  0.884599 -2.238947    0.227626
# 3  1.605181  -0.412292   1.457571  0.392495 -0.900146    0.053776
# 4  0.173621  -1.119868   0.257240  0.695506  1.370300   -0.918024
#
#    re_admission  died_in_hosp  died_within_48h_of_out_time  mortality_90d  \
# 0      0.359219     -0.721017                     1.261561      -0.864005
# 1      1.329555      1.584774                     0.235156       1.268940
# 2      1.019078      1.042928                    -0.716868      -0.423582
# 3      0.678660     -1.112072                    -0.623831       1.942569
# 4     -1.582564      1.129386                     1.342319       0.511012
#
#    ...      SIRS    act_iv  act_vaso    action      step     state  \
# ...
