# %%
import copy
import pickle
from datetime import datetime as dtdt

import attrs
import numpy as np

from hetero.config import DTYPE, AlgoConfig, DataGenConfig, GroupingConfig
from hetero.datagen import generate_data_from_config
from hetero.policies import AlternativePolicy
from hetero.tasks import (
    beta_estimate_from,
    beta_estimate_from_e2e_learning,
    beta_estimate_from_nongrouped,
    compute_UV_truths,
    compute_V_estimate,
)

group_reward_coeff = np.array(
    [
        [-2, 2, 2, -2],
        [2, -2, -2, 2],
    ],
    dtype=DTYPE,
)

action_reward_coeff = [-1, 1]

FEATURE_TYPE = "LEGENDRE"
TRANS = "NORMCDF"
NOISE = "STUDENT"

data_config_init = dict(
    num_trajectories=100,
    num_time_steps=20,
    group_reward_coeff_override=group_reward_coeff,
    action_reward_coeff=action_reward_coeff,
    num_burnin_steps=100,
    basis_expansion_method=FEATURE_TYPE,
    transformation_method=TRANS,
    add_intercept_column=True,
    noise_type=NOISE,
    noise_student_degree=4,
)

# First time runner: set COMPUTE_TRUTH = True
# Change the flag to False after generated the truth file.
COMPUTE_TRUTH = False #True
# Change the truth file name if settings are changed.
TRUTH_FILE = f"hetero/data/{FEATURE_TYPE}_{TRANS}_{NOISE}_truth_20230528_2.68_2.89.pkl"
print("truth file name =", TRUTH_FILE)

time_tag = dtdt.now().strftime("%Y%m%d_%H-%M-%S")
tag = f'N={data_config_init["num_trajectories"]}_T={data_config_init["num_time_steps"]}_{time_tag}'
RESULT_FILE = f"hetero/data/{FEATURE_TYPE}_{TRANS}_{NOISE}_result_20230528_2.68_2.89_{tag}.pkl"
print("result file name =", RESULT_FILE)

SAVE_RESULT = True
if not SAVE_RESULT:
    print("Result will NOT be saved, only use this for experimental runs!!!")

NUM_EXPERIMENTS = 100
# Out:
# truth file name = hetero/data/LEGENDRE_NORMCDF_STUDENT_truth_20230528_2.68_2.89.pkl
# result file name = hetero/data/LEGENDRE_NORMCDF_STUDENT_result_20230528_2.68_2.89_N=100_T=20_20230602_19-37-10.pkl

# %% [markdown]
# =====================================================================================================
# # Algorithm
#
# - Set configure below.

# %%
algo_config = AlgoConfig(
    max_num_iters=2,
    gam=2.7,
    lam=2.0,
    rho=2.0,
    should_remove_outlier=True,
    outlier_lower_perc=2,
    outlier_upper_perc=98,
    nu_coeff=1e-5,
    delta_coeff=1e-5,
    use_group_wise_regression_init=True,
)

pi_eval = AlternativePolicy(2)

grouping_config = GroupingConfig()

# %%
if COMPUTE_TRUTH:
    truth_data_config_init = copy.copy(data_config_init)
    truth_data_config_init.pop("num_trajectories")
    us, vs = compute_UV_truths(
        truth_data_config_init,
        algo_config.discount,
        pi_eval,
        num_repeats=100,
        num_trajectories=1000,
    )  # For best results, use num_repeats=10
    u_truth = us.mean(axis=0)
    v_truth = vs.mean(axis=0)

    with open(TRUTH_FILE, "wb") as f:
        pickle.dump(
            dict(
                u_truth=u_truth,
                v_truth=v_truth,
                data_config_dict=truth_data_config_init,
                algo_config_dict=attrs.asdict(algo_config),
            ),
            f,
        )
else:
    with open(TRUTH_FILE, "rb") as f:
        loaded = pickle.load(f)
        u_truth = loaded["u_truth"]
        v_truth = loaded["v_truth"]

# %%
beta_ng_list = []
beta_learned_list = []

for i in range(NUM_EXPERIMENTS):
    data_config = DataGenConfig(seed=7531 * (i + 1), **data_config_init)
    data = generate_data_from_config(data_config)
    beta_ng_list.append(
        beta_estimate_from_nongrouped(data, pi_eval, algo_config.discount)
    )
    beta_learned_list.append(
        beta_estimate_from_e2e_learning(data, algo_config, grouping_config, pi_eval)
    )
# Out:
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15831704
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15831704
# MCPImpl: num_above=13898, num_below=6002
# kmeans center = [[ 1.18708021 -2.90183154 -2.64112197  2.95300157  1.44757148  2.76931768
#   -1.22485987 -2.59704889  2.9426306   0.76873594]
#  [-1.21432977  2.77521468  2.75303926 -2.78811103 -1.60641951 -2.80714134
#    1.23143624  2.65530498 -2.73401882 -1.05245369]] and inertia = 3978.160303125423
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = (0.1576327+0j)
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = (0.1576327+0j)
# MCPImpl: num_above=14354, num_below=5546
# kmeans center = [[ 1.21451811 -3.26359356 -2.87843947  2.65824551  1.92724617  2.78374527
#   -1.13568158 -2.91770828  2.58698328  1.02758449]
#  [-0.99777529  2.45219433  2.80367542 -2.87137484 -1.46282087 -3.10163614
#    1.13808795  2.34656823 -2.70872081 -0.62023235]] and inertia = 4136.5116435486325
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = (0.15301706+0j)
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = (0.15301706+0j)
# MCPImpl: num_above=14367, num_below=5533
# kmeans center = [[ 1.07655518 -2.89783156 -2.70563648  2.84742606  1.54484261  3.07182095
#   -1.23304485 -2.89319173  2.89059868  0.78392272]
#  [-1.06458384  2.64486806  2.47571122 -2.53928679 -1.40863348 -2.84242436
#    1.0210399   2.55639461 -2.56269913 -0.75876145]] and inertia = 4208.683258567673
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15787072
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15787072
# MCPImpl: num_above=14940, num_below=4960
# kmeans center = [[ 1.00128843 -2.9376874  -2.91935596  2.26031423  2.07522868  2.75967306
#   -1.20665262 -2.96162837  2.69813446  1.12086922]
#  [-1.19567464  2.88769367  2.8329517  -2.7792192  -1.59405686 -2.7819737
#    1.16166207  2.57423289 -2.66122607 -0.78619768]] and inertia = 4513.847135723356
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = (0.15730625+0j)
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = (0.15730625+0j)
# MCPImpl: num_above=14583, num_below=5317
# kmeans center = [[ 1.33426479 -2.83450286 -2.50292137  2.90301942  1.30050011  3.08523082
#   -1.02474102 -2.65386922  2.98223683  0.53385659]
#  [-1.24104859  2.80426266  2.93188865 -2.70977669 -1.73525868 -2.80296577
#    1.24939944  2.68682921 -2.71151974 -0.91743689]] and inertia = 4330.646780303973
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = (0.15180993+0j)
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = (0.15180993+0j)
# MCPImpl: num_above=15071, num_below=4829
# kmeans center = [[ 1.36424368 -2.87806891 -2.53635962  2.91644662  1.29570431  2.90178888
#   -1.31499969 -2.59300351  2.62680801  0.88513214]
#  [-1.08655673  2.96071407  2.90192723 -2.65237514 -1.91833023 -2.83147154
#    1.10635692  2.89646576 -2.84037839 -0.91937321]] and inertia = 4633.925333624667
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = (0.15633368+0j)
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = (0.15633368+0j)
# MCPImpl: num_above=14489, num_below=5411
# kmeans center = [[ 1.27098744 -2.86504806 -2.70905018  2.77718254  1.51617958  2.78641543
#   -1.2470298  -2.83861215  3.01651147  0.99046568]
#  [-1.0508009   2.84997535  2.86214488 -2.49900643 -1.86119135 -2.92177055
#    1.07935334  3.05028641 -2.58558757 -1.13134956]] and inertia = 4316.962150360212
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15486518
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15486518
# MCPImpl: num_above=14377, num_below=5523
# kmeans center = [[ 1.15425992 -2.96246294 -2.64788562  2.5841807   1.73228461  2.73468238
#   -1.30542862 -2.6317494   2.5349997   1.10510017]
#  [-1.15876043  3.01359727  2.84802109 -2.77369553 -1.71561366 -2.90969279
#    1.00134202  2.91057778 -2.90159507 -0.7511053 ]] and inertia = 4168.334404107625
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15905653
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15905653
# MCPImpl: num_above=14626, num_below=5274
# kmeans center = [[ 1.12560447 -2.88243822 -2.5974692   2.56675134  1.62258179  2.73206196
#   -1.16456092 -2.6506989   2.88039229  0.8310021 ]
#  [-1.1785378   2.64722212  2.71181803 -2.90828937 -1.21532031 -2.72933484
#    1.16184753  2.67896215 -2.74082326 -0.77632011]] and inertia = 4322.801005472893
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15703966
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15703966
# MCPImpl: num_above=14672, num_below=5228
# kmeans center = [[ 1.01186815 -2.87567664 -2.60230672  2.82550245  1.51599048  2.77416589
#   -1.07880123 -2.55424376  2.78718052  0.72390423]
#  [-1.23404724  2.69463332  2.87657993 -2.78766514 -1.4486838  -2.73812321
#    1.23834837  3.08887069 -2.70936583 -1.17677047]] and inertia = 4380.251413755714
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = (0.15487061+0j)
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = (0.15487061+0j)
# MCPImpl: num_above=14366, num_below=5534
# kmeans center = [[ 1.09038255 -2.62474324 -2.80657712  2.7312646   1.5973051   2.65326929
#   -1.1373565  -2.79328604  2.77924674  0.96984731]
#  [-1.19231113  3.06233048  2.87991606 -2.79287711 -1.6370828  -2.8859809
#    1.0266855   2.6831757  -2.90204457 -0.59543473]] and inertia = 4256.71481751529
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15685152
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15685152
# MCPImpl: num_above=14082, num_below=5818
# kmeans center = [[ 1.00773638 -2.7824373  -2.68281807  2.92480574  1.50866362  3.03894818
#   -1.04185874 -2.66575485  2.74166837  0.75165184]
#  [-1.08602795  2.70331509  2.48559186 -2.42967412 -1.62357446 -2.69386841
#    1.13569261  2.69494113 -2.68679331 -0.95396959]] and inertia = 4034.096934241866
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.1501897
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.1501897
# MCPImpl: num_above=14253, num_below=5647
# kmeans center = [[ 1.16393395 -2.81791091 -2.8274689   2.53516908  1.77862165  2.63525165
#   -1.0227578  -2.89812073  3.07264251  0.87668134]
#  [-1.10374923  2.87747602  2.69643498 -3.04702946 -1.39167812 -2.949561
#    1.13951485  2.61336424 -2.66560568 -0.79649938]] and inertia = 4129.57992092343
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15161552
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15161552
# MCPImpl: num_above=14750, num_below=5150
# kmeans center = [[ 1.20145287 -2.70666877 -2.83691841  2.62729887  1.53799112  2.91567758
#   -0.97061593 -2.70710236  2.43223559  0.80151413]
#  [-1.08360868  3.12216817  2.72412951 -2.72435762 -1.71959108 -2.90148707
#    1.23761779  2.74670114 -2.831924   -0.74175248]] and inertia = 4391.642228718485
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15286674
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15286674
# MCPImpl: num_above=14426, num_below=5474
# kmeans center = [[ 1.05125916 -3.05515888 -2.89502413  2.93534936  1.71386617  2.90048723
#   -1.13423326 -2.77462847  2.98499365  0.68594534]
#  [-1.14191635  2.62675689  2.60448779 -2.76205835 -1.29047699 -2.61183606
#    1.08079038  3.06554054 -2.59723861 -1.18637491]] and inertia = 4225.150266546088
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.16152494
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.16152494
# MCPImpl: num_above=14503, num_below=5397
# kmeans center = [[ 1.18639806 -2.62661999 -2.94768709  2.85635417  1.58078037  2.76351785
#   -1.25851568 -2.97695525  2.90216609  1.058021  ]
#  [-1.06281648  2.96209898  2.68771524 -2.75824854 -1.63186123 -2.8248206
#    0.93179194  2.66846413 -2.57517201 -0.78113342]] and inertia = 4232.121569204998
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15531133
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15531133
# MCPImpl: num_above=14528, num_below=5372
# kmeans center = [[ 1.3097559  -2.62410832 -2.78863431  2.54756023  1.48567445  2.70046835
#   -1.21084338 -2.60295907  2.31621172  1.21870069]
#  [-1.09759706  2.98811828  2.83094889 -2.89294741 -1.60985114 -3.35931437
#    1.27972946  3.06833212 -3.02298381 -0.67172145]] and inertia = 4300.503320162543
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = (0.15132366+0j)
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = (0.15132366+0j)
# MCPImpl: num_above=14411, num_below=5489
# kmeans center = [[ 1.11195636 -2.5606582  -2.47470971  2.78321458  1.2318762   2.65993756
#   -1.25323655 -2.27901325  2.65171542  0.80306968]
#  [-1.0965063   2.77178668  2.90694559 -2.64350032 -1.65806878 -2.97891772
#    1.10746236  3.03057781 -2.70447751 -0.90760943]] and inertia = 4249.859856352641
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15817863
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15817863
# MCPImpl: num_above=14151, num_below=5749
# kmeans center = [[ 1.0454814  -2.85846002 -2.86991469  2.52240749  1.80679329  2.88754029
#   -1.28218423 -2.65976928  2.67098812  0.89999463]
#  [-1.31019368  2.82701314  2.82280205 -3.07823926 -1.51250782 -2.8503739
#    1.21467006  3.06143511 -2.84108765 -1.18153257]] and inertia = 4004.4291246570046
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.16004112
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.16004112
# MCPImpl: num_above=14586, num_below=5314
# kmeans center = [[ 1.14420419 -3.43988955 -2.70484042  2.4876501   1.97805154  2.89750053
#   -1.2680932  -2.65402272  2.90539064  0.72507225]
#  [-1.04857497  2.42709886  2.9694918  -2.88094442 -1.50443482 -2.6406272
#    1.0769123   2.68865085 -2.92958307 -0.80849561]] and inertia = 4332.633633430269
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15505666
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15505666
# MCPImpl: num_above=14407, num_below=5493
# kmeans center = [[ 1.03018952 -2.85088199 -2.79325342  2.64150117  1.60857548  2.69539348
#   -1.17177833 -2.84789176  2.74158201  0.93737779]
#  [-1.11733719  2.78385154  2.76264842 -2.74239596 -1.58403369 -2.82123925
#    1.03385147  2.57380394 -2.7688377  -0.79293379]] and inertia = 4193.4107037725025
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15838674
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15838674
# MCPImpl: num_above=14576, num_below=5324
# kmeans center = [[ 1.12626794 -2.85219246 -2.83042776  2.73407779  1.6379052   2.89588891
#   -1.10239502 -2.84327864  2.42351148  0.96618227]
#  [-1.20872582  2.62483684  2.56622054 -2.65414515 -1.36705002 -2.5742396
#    1.29029306  2.61642509 -2.91081894 -0.8599405 ]] and inertia = 4353.576359037817
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15351309
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15351309
# MCPImpl: num_above=14169, num_below=5731
# kmeans center = [[ 1.00990289 -2.60315414 -2.61259331  2.49733965  1.65948987  2.90901197
#   -1.0865946  -2.75060443  2.73970509  0.85423989]
#  [-1.29076483  2.81224062  2.79926149 -2.84654585 -1.47858801 -2.91760288
#    1.22001751  2.90953259 -2.81589023 -0.92889256]] and inertia = 4045.486996129641
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = (0.1551924+0j)
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = (0.1551924+0j)
# MCPImpl: num_above=14518, num_below=5382
# kmeans center = [[ 1.13166002 -2.72485809 -2.79225583  3.04791753  1.3762638   2.93505419
#   -1.30267689 -2.56479038  3.05553309  0.73601013]
#  [-1.17431471  2.70209123  2.50733672 -2.6234469  -1.36251256 -2.57268834
#    0.9656773   2.78165106 -2.86036674 -0.8460954 ]] and inertia = 4303.129635876233
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = (0.15777941+0j)
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = (0.15777941+0j)
# MCPImpl: num_above=14057, num_below=5843
# kmeans center = [[ 1.07964241 -2.77340436 -2.84939454  2.70807175  1.62924931  2.40632551
#   -1.21407129 -2.78963796  2.67387281  1.17597796]
#  [-1.04890888  2.99526345  2.76951248 -2.54990347 -1.85422899 -3.07660717
#    0.97552712  2.60791494 -2.91283918 -0.51303311]] and inertia = 3993.9419490724003
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = (0.15318839+0j)
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = (0.15318839+0j)
# MCPImpl: num_above=14933, num_below=4967
# kmeans center = [[ 1.21199729 -2.66129988 -3.082656    2.62984162  1.6990197   2.98028691
#   -1.18497282 -2.87420724  2.85394605  0.82464528]
#  [-1.14169988  2.89795696  2.55131567 -2.73127716 -1.5017185  -2.86620342
#    1.10886752  2.88761932 -2.73309224 -0.7867363 ]] and inertia = 4477.6167638563
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15994266
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15994266
# MCPImpl: num_above=14761, num_below=5139
# kmeans center = [[ 1.1235189  -2.89860035 -2.57855371  2.4966293   1.67929698  2.58894471
#   -1.11469034 -2.90677631  2.84672825  0.95831844]
#  [-1.23314239  2.72702862  2.96558407 -2.98930574 -1.38192312 -2.87110706
#    1.0666283   2.69070889 -2.82090705 -0.6868958 ]] and inertia = 4388.779961806837
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15388726
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15388726
# MCPImpl: num_above=14333, num_below=5567
# kmeans center = [[ 1.26263316 -2.7213261  -2.71157996  2.68258419  1.63005558  2.53966605
#   -1.01233597 -2.73837269  2.81014684  0.98027984]
#  [-1.07049182  2.91778087  2.85508172 -2.72842089 -1.76392009 -2.99605914
#    1.19880785  2.67005829 -3.01477745 -0.61005087]] and inertia = 4169.089147062819
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15520418
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15520418
# MCPImpl: num_above=14475, num_below=5425
# kmeans center = [[ 1.19783512 -2.70822053 -2.67967706  3.09621408  1.2115689   2.95084925
#   -1.3212254  -2.42514942  2.97605518  0.52353883]
#  [-1.10690934  2.74915116  2.76882783 -2.50092096 -1.69383964 -2.73522986
#    1.03278664  2.94181042 -2.5819677  -1.01572749]] and inertia = 4198.093379036748
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15451944
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15451944
# MCPImpl: num_above=13906, num_below=5994
# kmeans center = [[ 1.05815288 -2.6224692  -2.56889266  2.83328969  1.46585017  2.89271024
#   -1.21259177 -2.40599471  2.6995948   0.77097252]
#  [-1.2162515   2.82583782  2.82798361 -2.49052984 -1.75297584 -2.70724978
#    0.98221967  2.71241521 -2.84389508 -0.85435258]] and inertia = 3954.5977953758356
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.1564755
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.1564755
# MCPImpl: num_above=14618, num_below=5282
# kmeans center = [[ 1.228309   -2.75994369 -2.9639262   2.60928753  1.7272519   2.6598223
#   -0.97848167 -2.81492911  2.51725762  1.04886623]
#  [-1.14910058  3.00484858  2.67833333 -2.87788615 -1.50699995 -2.87529774
#    1.20170657  2.74203272 -2.77445728 -0.83388604]] and inertia = 4367.0369960792195
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.1633024
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.1633024
# MCPImpl: num_above=14312, num_below=5588
# kmeans center = [[ 1.17870432 -2.54343    -2.86168514  2.4964019   1.72921583  2.65725999
#   -1.0994664  -2.60662255  2.81079217  0.82277656]
#  [-0.96531736  2.92297216  2.58174053 -2.70757872 -1.63382001 -2.74862007
#    1.16830003  2.81659048 -2.57628154 -1.018091  ]] and inertia = 4164.545854216787
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.16186017
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.16186017
# MCPImpl: num_above=14459, num_below=5441
# kmeans center = [[ 1.32176865 -3.05186522 -2.52172826  2.90288936  1.49424406  2.72748479
#   -1.136354   -2.60860069  3.00025146  0.79697372]
#  [-1.08925371  2.90778527  2.81982461 -2.89767696 -1.63729499 -2.95768303
#    1.05770915  2.6181404  -2.84501537 -0.73637299]] and inertia = 4185.537498113798
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15874316
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15874316
# MCPImpl: num_above=14801, num_below=5099
# kmeans center = [[ 1.30578078 -3.10055419 -2.57106202  2.52431847  1.66732585  2.82915229
#   -1.00076211 -2.4059945   2.69659727  0.67438525]
#  [-1.10936534  2.55457506  3.03586997 -2.79653602 -1.73239617 -2.75731271
#    1.25734483  2.95573858 -2.90076773 -1.22971328]] and inertia = 4396.872218640003
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = (0.15351456+0j)
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = (0.15351456+0j)
# MCPImpl: num_above=14277, num_below=5623
# kmeans center = [[ 1.22334563 -2.69746494 -2.76273325  2.73713943  1.49779597  2.70996922
#   -1.00449513 -2.57700887  2.99163243  0.6362896 ]
#  [-0.9679643   2.6965283   3.00049688 -2.79769517 -1.62462191 -2.78679546
#    1.26832583  2.91096071 -2.76169596 -1.02384108]] and inertia = 4160.185299492068
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15777484
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15777484
# MCPImpl: num_above=14450, num_below=5450
# kmeans center = [[ 1.10697061 -2.93256014 -2.63823605  2.67042126  1.68678901  2.8028955
#   -1.25121942 -2.84642565  2.59694218  1.08107318]
#  [-1.36446563  2.66838026  3.06606396 -2.66224227 -1.74111088 -2.9633709
#    1.0940529   2.81751517 -2.6672718  -0.90995454]] and inertia = 4244.107173724602
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15828243
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15828243
# MCPImpl: num_above=14173, num_below=5727
# kmeans center = [[ 1.19851939 -2.83069257 -2.9323872   2.43677753  1.82381295  2.75724159
#   -1.18772025 -2.95028863  2.33613524  1.22253489]
#  [-1.05895705  2.86219335  2.76491973 -2.5410271  -1.69223532 -2.90724784
#    1.1061974   2.69733858 -2.42345561 -0.92689504]] and inertia = 4037.0927762446054
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.16032295
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.16032295
# MCPImpl: num_above=14649, num_below=5251
# kmeans center = [[ 1.21829333 -2.58174956 -3.19790287  2.57658826  1.83503357  2.77040178
#   -1.11520519 -2.64712468  2.5034915   0.93956247]
#  [-1.03229928  3.17337781  2.27226021 -2.53806879 -1.70641361 -2.76901754
#    1.17444002  2.72305354 -2.89394438 -0.85249572]] and inertia = 4389.423999408105
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = (0.15608834+0j)
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = (0.15608834+0j)
# MCPImpl: num_above=14405, num_below=5495
# kmeans center = [[ 1.2270182  -2.90379386 -2.85764797  2.81182901  1.61605453  2.62071776
#   -1.21993656 -2.76338876  2.78080025  0.92795616]
#  [-1.14645679  2.80120552  2.71470474 -2.80871914 -1.31665658 -2.79852903
#    0.98917201  2.76977343 -2.79262478 -0.74972436]] and inertia = 4159.861853649163
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.1574292
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.1574292
# MCPImpl: num_above=14339, num_below=5561
# kmeans center = [[ 1.19179642 -2.90079571 -2.75954802  2.80031127  1.39544095  2.87905497
#   -1.0497222  -2.41421053  3.04289376  0.33500347]
#  [-1.30325907  2.70867388  2.57263233 -2.55677489 -1.49368634 -2.64639707
#    1.14702917  2.83893644 -2.75186799 -1.11348403]] and inertia = 4132.689115499861
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.1550225
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.1550225
# MCPImpl: num_above=14198, num_below=5702
# kmeans center = [[ 1.06159321 -2.89823113 -2.57071233  2.66817151  1.53631629  2.89493553
#   -1.2143177  -2.40101155  2.64617478  0.73055698]
#  [-0.98735059  2.53485186  2.6917149  -2.64933303 -1.61875165 -2.65598081
#    0.90618196  2.74516032 -2.56441709 -1.05782848]] and inertia = 4088.3392230766904
# Label mismatch = 1
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.16170108
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.16170108
# MCPImpl: num_above=14915, num_below=4985
# kmeans center = [[ 1.15853938 -2.7115871  -2.88551144  2.7813665   1.55653807  2.83088829
#   -1.16934174 -2.81281294  2.8858415   0.84921589]
#  [-1.17517101  2.86339976  2.65250557 -2.64352121 -1.52713608 -2.72278612
#    1.07775777  2.88890206 -2.68838832 -0.97517217]] and inertia = 4463.582922857775
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.1571314
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.1571314
# MCPImpl: num_above=14178, num_below=5722
# kmeans center = [[ 1.07647363 -2.79561936 -2.76366797  2.75009531  1.57301865  2.93272979
#   -1.2850585  -2.62865303  2.79454397  0.81057675]
#  [-1.0848656   2.99266181  2.97674477 -2.81685464 -1.79893229 -2.57423041
#    1.09482542  2.73813269 -2.92673729 -0.80515787]] and inertia = 4077.772986950339
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15570791
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15570791
# MCPImpl: num_above=14491, num_below=5409
# kmeans center = [[ 1.17970271 -2.78375261 -2.84675425  2.70582933  1.57847986  2.82296369
#   -1.23393751 -2.84880387  2.59763414  1.00257204]
#  [-1.00384317  2.98784777  3.03282982 -2.92036068 -1.82066229 -3.00428104
#    0.9937569   2.78858124 -2.69403763 -0.85487765]] and inertia = 4261.362369796668
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15567693
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15567693
# MCPImpl: num_above=14649, num_below=5251
# kmeans center = [[ 1.12991445 -2.67296753 -2.66321474  2.82425607  1.52569196  2.91567748
#   -1.29500417 -2.83195228  3.10432928  0.87251223]
#  [-1.10807864  3.02074539  2.92647473 -2.50304124 -1.79596269 -2.81731089
#    1.08219402  2.89073044 -2.34255223 -1.08820025]] and inertia = 4376.668817371787
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15971865
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15971865
# MCPImpl: num_above=14583, num_below=5317
# kmeans center = [[ 1.16586329 -2.6293502  -2.97997118  2.69579925  1.59332024  2.57990786
#   -1.14908007 -3.15162991  2.64873292  1.20113843]
#  [-1.04595222  2.94232676  2.59984838 -2.48559247 -1.70533187 -2.94216591
#    1.14170731  2.5866865  -2.68147478 -0.66877476]] and inertia = 4348.932295380372
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15689965
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15689965
# MCPImpl: num_above=14374, num_below=5526
# kmeans center = [[ 0.9706298  -2.75514256 -2.52331681  2.60936451  1.43749883  2.82736394
#   -1.25264356 -2.68191929  2.78333303  0.85571038]
#  [-1.17777937  2.94616637  2.95209289 -2.85191816 -1.60105101 -2.9473352
#    0.9821245   2.73548968 -2.66282934 -0.8313764 ]] and inertia = 4198.260638784688
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.154668
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.154668
# MCPImpl: num_above=14126, num_below=5774
# kmeans center = [[ 1.23700222 -2.45556666 -2.25697173  2.47333869  1.29473681  2.83456071
#   -1.21762275 -2.48258971  2.52854509  0.854987  ]
#  [-1.120286    2.99427184  3.02764599 -2.73831272 -1.84825033 -2.80804933
#    1.12397713  3.04649027 -2.7154051  -1.11178084]] and inertia = 4050.074811701302
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.16165566
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.16165566
# MCPImpl: num_above=14478, num_below=5422
# kmeans center = [[ 1.16770832 -2.77682434 -2.81310542  2.65512216  1.55131272  2.69732953
#   -1.10328846 -2.81402137  2.50288766  1.02024244]
#  [-1.181579    2.7725284   2.67779862 -2.55271422 -1.5348131  -2.84931821
#    1.22091498  2.83167529 -2.84658188 -0.83629275]] and inertia = 4224.528710558672
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = (0.15712547+0j)
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = (0.15712547+0j)
# MCPImpl: num_above=14578, num_below=5322
# kmeans center = [[ 1.10513798 -2.98424522 -2.78063541  2.85201106  1.51606514  3.04993722
#   -0.91744869 -2.86767354  2.7344716   0.63363435]
#  [-1.22782305  2.80129982  2.82607162 -2.64177783 -1.66117293 -2.90748527
#    1.25811293  2.64226451 -2.74049126 -0.89143003]] and inertia = 4238.615130800863
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.1609421
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.1609421
# MCPImpl: num_above=15387, num_below=4513
# kmeans center = [[ 1.04623155 -2.88666697 -2.70657074  2.93258268  1.46735205  2.74281735
#   -1.16987411 -2.87050752  3.01152187  0.76265211]
#  [-1.17016758  2.82840936  3.10050775 -2.55303532 -1.85475852 -2.94921565
#    1.23387436  2.87683276 -2.63882286 -0.9814859 ]] and inertia = 4751.5900509759285
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = (0.1531534+0j)
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = (0.1531534+0j)
# MCPImpl: num_above=14083, num_below=5817
# kmeans center = [[ 1.19981208 -2.61102572 -2.70406839  2.7016896   1.40824547  2.63205431
#   -1.24094821 -2.78515223  2.62304828  1.11422393]
#  [-1.21248365  2.98755342  2.71557869 -2.58101324 -1.69812818 -2.99046942
#    0.98127224  2.79503582 -2.84757344 -0.72787233]] and inertia = 4008.2332769218165
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15331826
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15331826
# MCPImpl: num_above=14974, num_below=4926
# kmeans center = [[ 1.13369301 -2.93783961 -3.17855001  2.53992444  2.00464528  2.84947939
#   -1.29988789 -2.9065143   2.74262748  1.02251392]
#  [-1.11637152  2.85121656  2.5890494  -2.95557311 -1.47529528 -2.51969209
#    1.30895652  2.36292776 -2.84660682 -0.91768359]] and inertia = 4591.095668272783
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.1557038
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.1557038
# MCPImpl: num_above=14809, num_below=5091
# kmeans center = [[ 1.03716073 -2.85623034 -2.89065307  2.67822417  1.78324615  2.5678861
#   -1.0592697  -2.78183517  2.94383479  0.93799815]
#  [-1.34060751  2.54483501  2.83159326 -2.82268177 -1.29980849 -2.82987317
#    1.15421724  2.98068638 -2.64741784 -1.05895496]] and inertia = 4370.2997329019545
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15733819
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15733819
# MCPImpl: num_above=14319, num_below=5581
# kmeans center = [[ 1.18538709 -2.855997   -2.78415529  2.69527023  1.60628075  2.98694871
#   -1.12999394 -2.49488783  2.75020927  0.64680351]
#  [-1.1835923   2.87083401  2.48508908 -2.71749909 -1.44052354 -3.07024861
#    1.13818107  2.89531172 -2.67358833 -0.91658611]] and inertia = 4155.685991617449
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15521623
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15521623
# MCPImpl: num_above=14518, num_below=5382
# kmeans center = [[ 1.13274582 -2.6225661  -2.42488367  2.68381304  1.47234885  2.59510442
#   -1.17094534 -2.59243928  2.50313856  1.20312521]
#  [-1.05938624  3.08882886  2.71415083 -2.9286108  -1.62427999 -2.87392963
#    1.03839057  2.63485    -2.89122127 -0.64249968]] and inertia = 4231.129160533554
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = (0.15722485+0j)
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = (0.15722485+0j)
# MCPImpl: num_above=14842, num_below=5058
# kmeans center = [[ 1.18062938 -2.85723817 -2.62321137  2.7337082   1.53065404  2.91629135
#   -1.1644676  -2.66792988  2.61939783  0.80997738]
#  [-0.95206227  3.14731204  2.7112568  -3.09327709 -1.54289166 -2.89612809
#    1.12200648  2.53090704 -2.76308695 -0.66087726]] and inertia = 4475.060419300071
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15764675
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15764675
# MCPImpl: num_above=14334, num_below=5566
# kmeans center = [[ 1.29277646 -3.12697891 -2.92795423  2.74850874  1.79298347  2.81508479
#   -1.11608628 -2.70344051  2.52014006  0.97053582]
#  [-1.0277489   2.55416268  2.63443794 -2.79069484 -1.38627243 -2.69177428
#    1.23284937  2.83978961 -3.14061017 -0.80799406]] and inertia = 4085.7520753700287
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.1573731
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.1573731
# MCPImpl: num_above=14274, num_below=5626
# kmeans center = [[ 1.12116401 -2.86447369 -2.62890957  2.67462888  1.53355167  2.84720171
#   -1.1209286  -2.51542574  2.89620976  0.59704627]
#  [-1.24121868  2.7409106   3.04492779 -2.7410469  -1.58206928 -2.55871273
#    1.2387613   2.76416034 -2.93250433 -0.97475344]] and inertia = 4092.4603561407353
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.14885947
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.14885947
# MCPImpl: num_above=15089, num_below=4811
# kmeans center = [[ 1.17706433 -2.83086204 -2.87034281  2.62608415  1.77920151  2.93802296
#   -1.07068293 -2.8808843   2.63475596  0.88426782]
#  [-1.08435082  3.03085799  2.77334508 -2.81191577 -1.73169062 -2.64459529
#    1.27390289  2.60991017 -2.88658628 -0.89828812]] and inertia = 4618.238569288
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15726395
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15726395
# MCPImpl: num_above=14551, num_below=5349
# kmeans center = [[ 1.08579636 -2.83747333 -2.98818751  2.43060064  1.81299601  3.00537464
#   -1.36956641 -2.65764295  2.6320613   0.83891734]
#  [-1.36309497  2.90846472  3.03551819 -3.00705509 -1.44571002 -2.82445601
#    0.98472967  2.98326711 -2.97626938 -0.69042   ]] and inertia = 4258.402361787837
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15662919
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15662919
# MCPImpl: num_above=14794, num_below=5106
# kmeans center = [[ 1.16090049 -2.47787009 -2.82962878  2.85382223  1.35845101  2.73569507
#   -1.19977885 -2.87300864  2.74841132  1.00034763]
#  [-1.17773712  3.01572885  2.77203022 -2.8416646  -1.5194483  -2.95976223
#    1.11260174  2.7450486  -2.84842124 -0.59296334]] and inertia = 4470.82244495976
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.16028911
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.16028911
# MCPImpl: num_above=14383, num_below=5517
# kmeans center = [[ 1.14039756 -3.01752483 -2.85432819  2.63365925  1.71226475  2.35452673
#   -1.14787497 -2.89148829  2.84996828  1.08753087]
#  [-1.05254925  2.59995008  2.69969342 -2.64743533 -1.59474243 -3.16497044
#    1.26818476  2.39337107 -2.44667467 -0.74979742]] and inertia = 4141.214044423753
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = (0.15964782+0j)
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = (0.15964782+0j)
# MCPImpl: num_above=14757, num_below=5143
# kmeans center = [[ 1.11636503 -2.87082709 -2.73267361  2.46954462  1.79000057  2.83276549
#   -1.21923554 -3.20042812  2.73005183  1.22288628]
#  [-0.98942553  2.8595586   2.80566479 -2.78174669 -1.68221778 -3.06620517
#    1.14282449  2.60044563 -2.69026709 -0.78649077]] and inertia = 4400.606980460154
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.16256776
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.16256776
# MCPImpl: num_above=14432, num_below=5468
# kmeans center = [[ 1.19702263 -2.76418552 -2.65686788  2.9939415   1.37378336  2.75143805
#   -0.92930091 -2.65501882  2.57846672  0.84394566]
#  [-1.27235034  3.01662496  2.8114527  -2.72358053 -1.64405503 -2.81855249
#    1.30198531  2.78165974 -2.688167   -0.99249873]] and inertia = 4144.901312942899
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.16048923
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.16048923
# MCPImpl: num_above=14566, num_below=5334
# kmeans center = [[ 1.07919725 -2.91254358 -2.79440532  2.62769201  1.64140491  2.96352692
#   -1.01130995 -2.6810283   2.63091937  0.67302094]
#  [-1.12413664  2.73667982  3.0547536  -2.73792879 -1.7323399  -2.68369274
#    1.34208006  2.82415397 -2.68242177 -1.04896583]] and inertia = 4237.977255941683
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = (0.15055123+0j)
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = (0.15055123+0j)
# MCPImpl: num_above=15553, num_below=4347
# kmeans center = [[ 1.12408904 -2.84633903 -2.42322353  2.69930713  1.55806299  2.7750071
#   -1.12875775 -2.81795237  2.66990078  1.02145992]
#  [-1.04783119  2.77484303  3.05529702 -2.89589806 -1.67923175 -3.15812749
#    1.2120188   2.92569801 -2.87364305 -0.81012343]] and inertia = 4935.748374177556
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.16203284
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.16203284
# MCPImpl: num_above=14661, num_below=5239
# kmeans center = [[ 1.1871309  -2.87581452 -2.89102965  2.54494518  1.79694716  2.7199106
#   -1.24357724 -2.54375338  2.89832927  0.87924245]
#  [-1.07617856  2.76590758  2.54989811 -2.92489246 -1.349893   -2.94238426
#    1.05041675  2.81731804 -2.68199665 -0.83332669]] and inertia = 4277.791199243347
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = (0.15819189+0j)
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = (0.15819189+0j)
# MCPImpl: num_above=14634, num_below=5266
# kmeans center = [[ 1.07488295 -3.13617861 -2.72567943  2.38957099  1.97592897  2.67966265
#   -1.03496622 -2.7681453   2.62065423  0.93947725]
# ...
# beta_solver, min eigen of left matrix = 0.15691467
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15691467
# MCPImpl: num_above=14772, num_below=5128
# kmeans center = [[ 1.17063286 -2.98372166 -2.83184711  2.86187195  1.58990804  2.81365742
#   -1.24581682 -2.77350462  2.92136764  0.89415513]
#  [-1.17028036  2.86104605  2.78529462 -2.56619971 -1.66189495 -3.03309023
#    0.98265752  2.63654208 -2.74287496 -0.62928405]] and inertia = 4350.84910074165
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = (0.15811399+0j)
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = (0.15811399+0j)
# MCPImpl: num_above=14328, num_below=5572
# kmeans center = [[ 1.25852292 -2.56159273 -2.79795831  2.66282361  1.43129863  2.72991708
#   -1.27774181 -2.63491248  2.65792955  0.89416273]
#  [-1.0540635   3.07281874  2.52397154 -2.53963255 -1.68894177 -2.72855817
#    1.13816411  2.8408265  -2.8943444  -0.83942139]] and inertia = 4216.407099376283
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = (0.1568499+0j)
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = (0.1568499+0j)
# MCPImpl: num_above=14208, num_below=5692
# kmeans center = [[ 1.05008651 -2.91117484 -2.4392381   2.63442016  1.55223138  2.75106658
#   -1.00222102 -2.31281727  3.03351973  0.45933659]
#  [-1.2354397   2.60861635  2.83928622 -2.69354903 -1.484961   -2.88067913
#    1.29389826  2.99755522 -2.63100551 -1.0201051 ]] and inertia = 4039.9764706374576
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15690401
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15690401
# MCPImpl: num_above=14691, num_below=5209
# kmeans center = [[ 1.12248899 -2.80956358 -2.64141927  2.6946129   1.59696487  2.796484
#   -1.20804419 -2.94891397  2.64320667  1.11925869]
#  [-1.23988813  2.90760019  2.60680376 -2.53570709 -1.60397087 -2.84031608
#    1.14965915  2.19077824 -2.89932435 -0.4971146 ]] and inertia = 4369.447128085098
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.16119482
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.16119482
# MCPImpl: num_above=14478, num_below=5422
# kmeans center = [[ 1.16490659 -2.69716853 -2.88659861  2.82831493  1.51425478  2.80628769
#   -1.17283031 -3.02012113  2.75831485  1.06012409]
#  [-1.23991073  2.87784679  2.78006855 -2.49342574 -1.75208283 -2.72306112
#    1.29882496  2.31690855 -2.87104949 -0.68592927]] and inertia = 4291.679019473534
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15540059
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15540059
# MCPImpl: num_above=14810, num_below=5090
# kmeans center = [[ 1.31618657 -2.79007044 -2.79300807  2.73992785  1.70456687  2.72736635
#   -1.03711146 -2.61982927  2.70888739  0.94835091]
#  [-0.91903571  2.95667966  2.89069854 -2.71827788 -1.70818846 -2.88616896
#    1.24020123  2.73237327 -2.73704287 -0.80906775]] and inertia = 4403.091007106799
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.1652441
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.1652441
# MCPImpl: num_above=14735, num_below=5165
# kmeans center = [[ 1.09285976 -2.95420411 -2.58592671  3.04061052  1.59538151  2.80343367
#   -1.02038846 -2.43458943  2.9635804   0.60249682]
#  [-1.22982836  2.70056617  2.92152828 -2.68340926 -1.57060642 -2.79924654
#    1.28884111  2.84043956 -2.86380485 -0.93825193]] and inertia = 4357.276670471001
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.1602924
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.1602924
# MCPImpl: num_above=14418, num_below=5482
# kmeans center = [[ 1.24073963 -3.09506208 -2.68116829  2.85078695  1.46315503  2.77252868
#   -1.18416926 -2.7753248   2.57748689  0.94595502]
#  [-0.97291994  2.63940198  2.83573289 -2.80861692 -1.40026285 -2.88755781
#    1.03359759  2.68215053 -2.8245253  -0.52929147]] and inertia = 4210.959356477089
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = (0.15808435+0j)
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = (0.15808435+0j)
# MCPImpl: num_above=14439, num_below=5461
# kmeans center = [[ 1.16346748 -2.96593011 -2.5703849   2.38869973  1.61142495  2.50298128
#   -1.20982927 -2.93890172  2.5895329   1.19636416]
#  [-1.12513851  2.79599578  2.85966628 -2.86644149 -1.47486422 -3.00271711
#    1.10589873  2.45778245 -2.93197225 -0.40216822]] and inertia = 4296.27971583314
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.1626583
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.1626583
# MCPImpl: num_above=14602, num_below=5298
# kmeans center = [[ 1.11565976 -2.71169777 -2.48141958  2.81765726  1.44593918  2.64006444
#   -1.26498486 -2.61184397  2.53329826  1.22939157]
#  [-1.19438462  2.94283771  2.7855078  -2.81773944 -1.60232066 -2.94738941
#    1.06955406  2.82844652 -2.91973974 -0.81066746]] and inertia = 4247.209174160996
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15590975
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15590975
# MCPImpl: num_above=14375, num_below=5525
# kmeans center = [[ 1.11071809 -2.8889942  -2.76661743  2.78884682  1.57667084  2.79709271
#   -1.08628304 -2.9204341   2.80565864  0.91333591]
#  [-1.15014365  2.92039031  2.59279124 -2.61847779 -1.5745801  -2.62597973
#    1.07800729  2.79073819 -2.68373969 -0.97563034]] and inertia = 4173.638650845292
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15407757
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15407757
# MCPImpl: num_above=14410, num_below=5490
# kmeans center = [[ 1.25173658 -2.68995562 -2.92178301  2.649282    1.58381724  2.81077636
#   -1.18826622 -2.88724042  2.73831223  1.12573182]
#  [-1.06016744  2.79932054  2.58930523 -2.68424568 -1.54740626 -2.63364362
#    1.16522997  2.63844523 -2.60060752 -1.00131161]] and inertia = 4175.105691887946
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15183672
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15183672
# MCPImpl: num_above=14647, num_below=5253
# kmeans center = [[ 1.21411347 -2.64716243 -2.59852139  2.545181    1.43232599  2.92763554
#   -1.17533406 -3.00290703  2.8801887   0.83690119]
#  [-0.94981749  2.94956095  2.83727827 -2.89026655 -1.7355542  -2.63149595
#    1.05666379  2.60862291 -2.81699447 -0.88099323]] and inertia = 4323.155594796086
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = (0.16317357+0j)
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = (0.16317357+0j)
# MCPImpl: num_above=14642, num_below=5258
# kmeans center = [[ 1.03202903 -2.78255132 -2.67788394  3.00399743  1.34948419  2.73345591
#   -1.21241031 -2.95511033  2.80738242  1.02599186]
#  [-1.23845739  2.78639034  2.89079138 -2.572728   -1.78131912 -2.89032656
#    1.14218379  2.38651832 -2.75823946 -0.67522506]] and inertia = 4455.33117704477
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15617567
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15617567
# MCPImpl: num_above=14897, num_below=5003
# kmeans center = [[ 1.1184305  -2.86159012 -2.57109316  2.64740792  1.4747626   2.88245455
#   -1.00607041 -2.97244711  2.70432084  0.81209705]
#  [-1.22958821  2.49650416  2.54605049 -2.81221816 -1.24501794 -2.62323421
#    1.33602488  2.71944455 -3.01736324 -0.92162802]] and inertia = 4504.250691538489
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15716302
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15716302
# MCPImpl: num_above=14587, num_below=5313
# kmeans center = [[ 0.87319925 -2.63810122 -2.8672069   2.57889839  1.78636561  2.86899438
#   -1.19196765 -2.65902897  2.84976251  0.76263674]
#  [-1.25778269  3.116221    2.77104424 -2.93039017 -1.52034963 -2.90890894
#    0.93440094  2.82422551 -2.63120281 -0.79154646]] and inertia = 4380.693150077605
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15546441
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15546441
# MCPImpl: num_above=14162, num_below=5738
# kmeans center = [[ 1.02467036 -2.9877459  -2.93966563  2.47767516  2.09390757  3.07587395
#   -1.07879466 -2.98340253  2.56039205  1.02776027]
#  [-1.3320559   2.54681466  2.59053194 -2.74202394 -1.36364382 -2.40311317
#    1.00442806  2.38927317 -2.76655897 -0.89570202]] and inertia = 4124.32434744827
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15890624
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15890624
# MCPImpl: num_above=14471, num_below=5429
# kmeans center = [[ 1.07250362 -2.7537208  -2.82415456  3.181945    1.3082166   2.80682732
#   -1.21577978 -2.62392123  2.85375951  0.72436392]
#  [-1.17981203  3.130762    2.83223608 -2.40512699 -1.87671447 -2.8600143
#    1.06468052  2.74493332 -2.64497528 -0.87397454]] and inertia = 4241.002107430944
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15720768
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15720768
# MCPImpl: num_above=14287, num_below=5613
# kmeans center = [[ 1.08039767 -2.97142574 -2.76002846  2.87767151  1.56959829  2.89691324
#   -1.19035916 -2.88744067  2.990895    0.81450123]
#  [-1.05869162  2.71826969  2.7129786  -2.45909159 -1.71310428 -2.54481511
#    0.94593658  2.34234411 -2.62903131 -0.75244873]] and inertia = 4107.928736459467
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.16357933
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.16357933
# MCPImpl: num_above=14379, num_below=5521
# kmeans center = [[ 0.93310645 -2.92448854 -2.65624913  2.83672869  1.58529553  2.78441
#   -1.10616868 -2.36350326  2.58351522  0.76675231]
#  [-1.13236777  3.03534772  2.71228349 -2.69631462 -1.68463086 -2.9317929
#    1.13609188  2.76121048 -2.78696381 -0.77983589]] and inertia = 4233.492047639062
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15733325
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15733325
# MCPImpl: num_above=14617, num_below=5283
# kmeans center = [[ 1.11043009 -2.666711   -2.62760426  2.87132058  1.42233657  2.86158097
#   -1.25455343 -2.89337363  2.77049486  0.95825086]
#  [-1.15357522  2.72845125  3.1599273  -2.68220294 -1.72947292 -2.81445421
#    0.99202577  2.66212366 -2.77151941 -0.75513004]] and inertia = 4306.464130454453
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.15657395
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.15657395
# MCPImpl: num_above=14448, num_below=5452
# kmeans center = [[ 1.3072582  -2.98571509 -2.35593862  2.74406025  1.42215676  2.77688925
#   -1.12680852 -2.42886807  2.88799282  0.63186083]
#  [-0.95934876  2.76866445  2.98068374 -2.83345585 -1.64600584 -2.83617461
#    1.09555445  2.85096564 -2.66864593 -0.95324988]] and inertia = 4266.479565834048
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# new_labels.length=4000 matches number of records
# beta_solver, min eigen of left matrix = 0.16106895
# MCPImpl: num_above=10000, num_below=9900
# beta_solver, min eigen of left matrix = 0.16106895
# MCPImpl: num_above=14113, num_below=5787
# kmeans center = [[ 1.01284916 -2.92826298 -2.63814153  2.57719308  1.71405761  3.04928588
#   -1.08035177 -2.49202297  2.44972783  0.86662846]
#  [-1.42803247  2.71905217  3.04183415 -2.91592296 -1.49980923 -2.62798538
#    1.11244282  2.92027862 -2.77812525 -1.0813655 ]] and inertia = 3991.7932510452456
# Label mismatch = 0
# new_labels.length=200 matches num_unique_labels
# new_labels.length=4000 matches number of records

# %%
beta_learned_list[0].betas
# Out:
# [array([-1.13541424,  2.84603798,  2.85190309, -2.92513476, -1.59776357,
#         -2.87165767,  1.1358938 ,  2.76265427, -2.88373604, -0.8898509 ]),
#  array([ 1.17887679, -2.95271453, -2.76481393,  2.99874504,  1.49515949,
#          2.80739732, -1.15199582, -2.70936204,  2.84731498,  0.81818536])]

# %%
mu_learned_list = []
sigma_learned_list = []
z_score_learned_list = []
mu_ng_list = []
sigma_ng_list = []
z_score_ng_list = []

for beta_learned, beta_ng in zip(beta_learned_list, beta_ng_list):
    v_mus, v_sigmas = compute_V_estimate(u_truth, beta_learned)
    z_score_learned = [
        (mu - truth) / sigma for mu, truth, sigma in zip(v_mus, v_truth, v_sigmas)
    ]
    mu_learned_list.append(v_mus)
    sigma_learned_list.append(v_sigmas)
    z_score_learned_list.append(z_score_learned)

    ngv_mus, ngv_sigmas = compute_V_estimate(u_truth, beta_ng)
    z_score_ng = [
        (mu - truth) / sigma
        for mu, truth, sigma in zip(
            ngv_mus * len(v_truth), v_truth, ngv_sigmas * len(v_truth)
        )
    ]
    mu_ng_list.append(ngv_mus)
    sigma_ng_list.append(ngv_sigmas)
    z_score_ng_list.append(z_score_ng)

# %% [markdown]
# # Reports that average over two groups

# %%
z_score_learned = np.array(z_score_learned_list)
z_score_ng = np.array(z_score_ng_list)
Z_THRESHOLD = 1.96
learned_in_threshold = np.abs(z_score_learned) < Z_THRESHOLD
ng_in_threshold = np.abs(z_score_ng) < Z_THRESHOLD
learned_in_threshold_perc = learned_in_threshold.sum() / learned_in_threshold.size
ng_in_threshold_perc = ng_in_threshold.sum() / ng_in_threshold.size
print(
    "learned_in_threshold_perc=",
    learned_in_threshold_perc,
    ", ng_in_threshold_perc=",
    ng_in_threshold_perc,
)
if SAVE_RESULT:
    with open(RESULT_FILE, "wb") as f:
        pickle.dump(
            dict(
                mu_learned_list=mu_learned_list,
                sigma_learned_list=sigma_learned_list,
                z_score_learned=z_score_learned,
                mu_ng_list=mu_ng_list,
                sigma_ng_list=sigma_ng_list,
                z_score_ng=z_score_ng,
                beta_learned_list=beta_learned_list,
                beta_ng_list=beta_ng_list,
            ),
            f,
        )
# Out:
# learned_in_threshold_perc= 0.96 , ng_in_threshold_perc= 0.0

# %%
ac_acl = 2*Z_THRESHOLD*np.mean(sigma_learned_list)
ac_mse = np.mean( (mu_learned_list - v_truth)**2 )

mv_acl = 2*Z_THRESHOLD*np.mean(sigma_ng_list)
mv_mse = np.mean( (mu_ng_list - v_truth)**2 )

# %%
print("ACPE results: (average over groups)")
print(f"ACL: {ac_acl}") 
print(f"MSE: {ac_mse}")
print(f"ECP: {learned_in_threshold_perc}")


print("MVPE results: (average over groups)")
print(f"ACL: {mv_acl}") 
print(f"MSE: {mv_mse}")
print(f"ECP: {ng_in_threshold_perc}")
# Out:
# ACPE results: (average over groups)
# ACL: 0.1630770841088718
# MSE: 0.001545880952244807
# ECP: 0.96
# MVPE results: (average over groups)
# ACL: 0.20352345303736818
# MSE: 1.5521851104754842
# ECP: 0.0

# %% [markdown]
# # Reports that seperate two groups

# %%
z_score_learned = np.array(z_score_learned_list)
z_score_ng = np.array(z_score_ng_list)
Z_THRESHOLD = 1.96
learned_in_threshold = np.abs(z_score_learned) < Z_THRESHOLD
ng_in_threshold = np.abs(z_score_ng) < Z_THRESHOLD

learned_in_threshold_perc = np.sum(learned_in_threshold, axis=0) / learned_in_threshold.shape[0]
ng_in_threshold_perc = np.sum(ng_in_threshold, axis=0) / ng_in_threshold.shape[0]

print(
    "learned_in_threshold_perc=",
    learned_in_threshold_perc,
    ", ng_in_threshold_perc=",
    ng_in_threshold_perc,
)

if SAVE_RESULT:
    with open(RESULT_FILE, "wb") as f:
        pickle.dump(
            dict(
                mu_learned_list=mu_learned_list,
                sigma_learned_list=sigma_learned_list,
                z_score_learned=z_score_learned,
                mu_ng_list=mu_ng_list,
                sigma_ng_list=sigma_ng_list,
                z_score_ng=z_score_ng,
                beta_learned_list=beta_learned_list,
                beta_ng_list=beta_ng_list,
            ),
            f,
        )
# Out:
# learned_in_threshold_perc= [0.96 0.96] , ng_in_threshold_perc= [0. 0.]

# %%
ac_acl = 2*Z_THRESHOLD*np.mean(sigma_learned_list, axis=0)
ac_mse = np.mean((mu_learned_list - v_truth)**2, axis=0)

mv_acl = 2*Z_THRESHOLD*np.mean(sigma_ng_list, axis=0)
mv_mse = np.mean( (mu_ng_list - v_truth)**2, axis=0 )

# %%
print("ACPE results: Group1, Group 2")
print(f"MSE: {ac_mse}")
print(f"ACL: {ac_acl}") 
print(f"ECP: {learned_in_threshold_perc}")

print("===")
print("MVPE results: ")
print(f"MSE: {mv_mse}")
print(f"ACL: {mv_acl}") 
print(f"ECP: {ng_in_threshold_perc}")
# Out:
# ACPE results: Group1, Group 2
# MSE: [0.00153565 0.00155611]
# ACL: [0.16310101 0.16305316]
# ECP: [0.96 0.96]
# ===
# MVPE results:
# MSE: [1.5385389  1.56583132]
# ACL: [0.20352345]
# ECP: [0. 0.]
