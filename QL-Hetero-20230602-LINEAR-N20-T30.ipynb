# %%
import copy
import pickle
from datetime import datetime as dtdt

import attrs
import numpy as np

from hetero.config import DTYPE, AlgoConfig, DataGenConfig, GroupingConfig
from hetero.datagen import generate_data_from_config
from hetero.policies import AlternativePolicy
from hetero.tasks import (
    beta_estimate_from,
    beta_estimate_from_e2e_learning,
    beta_estimate_from_nongrouped,
    compute_UV_truths,
    compute_V_estimate,
)

group_reward_coeff = np.array(
    [
        [-2.68, 2.68],
        [2.68, -2.68],
    ],
    dtype=DTYPE,
)

action_reward_coeff = [-2.89, 2.89]

data_config_init = dict(
    num_trajectories=20,
    num_time_steps=30,
    group_reward_coeff_override=group_reward_coeff,
    action_reward_coeff=action_reward_coeff,
    num_burnin_steps=100,
    basis_expansion_method="NONE",
    add_intercept_column=True,
)

FEATURE_TYPE = "NONE"

# First time runner: set COMPUTE_TRUTH = True
# Change the flag to False after generated the truth file.
COMPUTE_TRUTH = False
# Change the truth file name if settings are changed.
TRUTH_FILE = f"hetero/data/{FEATURE_TYPE}_truth_20230528_2.68_2.89.pkl"
print("truth file name =", TRUTH_FILE)

time_tag = dtdt.now().strftime("%Y%m%d_%H-%M-%S")
tag = f'N={data_config_init["num_trajectories"]}_T={data_config_init["num_time_steps"]}_{time_tag}'
RESULT_FILE = f"hetero/data/{FEATURE_TYPE}_result_20230528_2.68_2.89_{tag}.pkl"
print("result file name =", RESULT_FILE)

SAVE_RESULT = True
if not SAVE_RESULT:
    print("Result will NOT be saved, only use this for experimental runs!!!")

NUM_EXPERIMENTS = 100
# Out:
# truth file name = hetero/data/NONE_truth_20230528_2.68_2.89.pkl
# result file name = hetero/data/NONE_result_20230528_2.68_2.89_N=20_T=30_20230602_11-50-39.pkl

# %% [markdown]
# =====================================================================================================
# # Algorithm
#
# - Set configure below.

# %%
algo_config = AlgoConfig(
    max_num_iters=10,
    gam=2.7,
    lam=1.6,
    rho=2.0,
    should_remove_outlier=True,
    outlier_lower_perc=2,
    outlier_upper_perc=98,
    nu_coeff=1e-5,
    delta_coeff=1e-5,
    use_group_wise_regression_init=True,
)

pi_eval = AlternativePolicy(2)

grouping_config = GroupingConfig()

# %%
if COMPUTE_TRUTH:
    truth_data_config_init = copy.copy(data_config_init)
    truth_data_config_init.pop("num_trajectories")
    us, vs = compute_UV_truths(
        truth_data_config_init,
        algo_config.discount,
        pi_eval,
        num_repeats=10,
        num_trajectories=1000,
    )  # For best results, use num_repeats=10
    u_truth = us.mean(axis=0)
    v_truth = vs.mean(axis=0)

    with open(TRUTH_FILE, "wb") as f:
        pickle.dump(
            dict(
                u_truth=u_truth,
                v_truth=v_truth,
                data_config_dict=truth_data_config_init,
                algo_config_dict=attrs.asdict(algo_config),
            ),
            f,
        )
else:
    with open(TRUTH_FILE, "rb") as f:
        loaded = pickle.load(f)
        u_truth = loaded["u_truth"]
        v_truth = loaded["v_truth"]

# %%
beta_ng_list = []
beta_learned_list = []

for i in range(NUM_EXPERIMENTS):
    data_config = DataGenConfig(seed=7531 * (i + 1), **data_config_init)
    data = generate_data_from_config(data_config)
    beta_ng_list.append(
        beta_estimate_from_nongrouped(data, pi_eval, algo_config.discount)
    )
    beta_learned_list.append(
        beta_estimate_from_e2e_learning(data, algo_config, grouping_config, pi_eval)
    )
# Out:
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = (0.938776+0j)
# MCPImpl: num_above=400, num_below=380
# beta_solver, min eigen of left matrix = (0.938776+0j)
# MCPImpl: num_above=416, num_below=364
# beta_solver, min eigen of left matrix = (0.938776+0j)
# MCPImpl: num_above=402, num_below=378
# beta_solver, min eigen of left matrix = (0.938776+0j)
# MCPImpl: num_above=416, num_below=364
# beta_solver, min eigen of left matrix = (0.938776+0j)
# MCPImpl: num_above=403, num_below=377
# beta_solver, min eigen of left matrix = (0.938776+0j)
# MCPImpl: num_above=416, num_below=364
# beta_solver, min eigen of left matrix = (0.938776+0j)
# MCPImpl: num_above=403, num_below=377
# beta_solver, min eigen of left matrix = (0.938776+0j)
# MCPImpl: num_above=416, num_below=364
# beta_solver, min eigen of left matrix = (0.938776+0j)
# MCPImpl: num_above=403, num_below=377
# beta_solver, min eigen of left matrix = (0.938776+0j)
# MCPImpl: num_above=416, num_below=364
# kmeans center = [[-1.45437278  3.67625361 -2.54931731 -3.86802621  1.61611951 -5.2485513 ]
#  [ 1.61598851 -3.86609798  2.33356521  3.43037505 -1.43397834  5.06522749]] and inertia = 80.41660116600056
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = (0.9422527+0j)
# MCPImpl: num_above=409, num_below=371
# beta_solver, min eigen of left matrix = (0.9422527+0j)
# MCPImpl: num_above=444, num_below=336
# beta_solver, min eigen of left matrix = (0.9422527+0j)
# MCPImpl: num_above=415, num_below=365
# beta_solver, min eigen of left matrix = (0.9422527+0j)
# MCPImpl: num_above=445, num_below=335
# beta_solver, min eigen of left matrix = (0.9422527+0j)
# MCPImpl: num_above=416, num_below=364
# beta_solver, min eigen of left matrix = (0.9422527+0j)
# MCPImpl: num_above=444, num_below=336
# beta_solver, min eigen of left matrix = (0.9422527+0j)
# MCPImpl: num_above=415, num_below=365
# beta_solver, min eigen of left matrix = (0.9422527+0j)
# MCPImpl: num_above=444, num_below=336
# beta_solver, min eigen of left matrix = (0.9422527+0j)
# MCPImpl: num_above=416, num_below=364
# beta_solver, min eigen of left matrix = (0.9422527+0j)
# MCPImpl: num_above=444, num_below=336
# kmeans center = [[-1.36923503  3.88251983 -2.14195941 -3.93572028  1.54379143 -5.11133591]
#  [ 1.48319549 -3.80715854  1.94342633  3.74640021 -1.28206099  5.06934775]] and inertia = 97.76627265497476
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = (0.9457268+0j)
# MCPImpl: num_above=400, num_below=380
# beta_solver, min eigen of left matrix = (0.9457268+0j)
# MCPImpl: num_above=411, num_below=369
# beta_solver, min eigen of left matrix = (0.9457268+0j)
# MCPImpl: num_above=401, num_below=379
# beta_solver, min eigen of left matrix = (0.9457268+0j)
# MCPImpl: num_above=411, num_below=369
# beta_solver, min eigen of left matrix = (0.9457268+0j)
# MCPImpl: num_above=400, num_below=380
# beta_solver, min eigen of left matrix = (0.9457268+0j)
# MCPImpl: num_above=411, num_below=369
# beta_solver, min eigen of left matrix = (0.9457268+0j)
# MCPImpl: num_above=400, num_below=380
# beta_solver, min eigen of left matrix = (0.9457268+0j)
# MCPImpl: num_above=411, num_below=369
# beta_solver, min eigen of left matrix = (0.9457268+0j)
# MCPImpl: num_above=401, num_below=379
# beta_solver, min eigen of left matrix = (0.9457268+0j)
# MCPImpl: num_above=411, num_below=369
# kmeans center = [[-1.45706664  3.63445132 -2.1462249  -3.87659746  1.53990423 -4.97412554]
#  [ 1.45549215 -3.77439692  2.28149382  3.54710029 -1.53474679  5.23206478]] and inertia = 72.64824227982663
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = (0.92659265+0j)
# MCPImpl: num_above=406, num_below=374
# beta_solver, min eigen of left matrix = (0.92659265+0j)
# MCPImpl: num_above=425, num_below=355
# beta_solver, min eigen of left matrix = (0.92659265+0j)
# MCPImpl: num_above=408, num_below=372
# beta_solver, min eigen of left matrix = (0.92659265+0j)
# MCPImpl: num_above=425, num_below=355
# beta_solver, min eigen of left matrix = (0.92659265+0j)
# MCPImpl: num_above=407, num_below=373
# beta_solver, min eigen of left matrix = (0.92659265+0j)
# MCPImpl: num_above=425, num_below=355
# beta_solver, min eigen of left matrix = (0.92659265+0j)
# MCPImpl: num_above=408, num_below=372
# beta_solver, min eigen of left matrix = (0.92659265+0j)
# MCPImpl: num_above=425, num_below=355
# beta_solver, min eigen of left matrix = (0.92659265+0j)
# MCPImpl: num_above=407, num_below=373
# beta_solver, min eigen of left matrix = (0.92659265+0j)
# MCPImpl: num_above=425, num_below=355
# kmeans center = [[-1.53455478  3.84925921 -2.05665111 -3.62188526  1.52878386 -5.11230456]
#  [ 1.49042798 -3.8355812   2.30438379  3.58319357 -1.51954682  4.89645404]] and inertia = 85.13511799596735
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = (0.9427723-0.0026357023j)
# MCPImpl: num_above=404, num_below=376
# beta_solver, min eigen of left matrix = (0.9427723-0.0026357023j)
# MCPImpl: num_above=433, num_below=347
# beta_solver, min eigen of left matrix = (0.9427723-0.0026357023j)
# MCPImpl: num_above=410, num_below=370
# beta_solver, min eigen of left matrix = (0.9427723-0.0026357023j)
# MCPImpl: num_above=433, num_below=347
# beta_solver, min eigen of left matrix = (0.9427723-0.0026357023j)
# MCPImpl: num_above=413, num_below=367
# beta_solver, min eigen of left matrix = (0.9427723-0.0026357023j)
# MCPImpl: num_above=433, num_below=347
# beta_solver, min eigen of left matrix = (0.9427723-0.0026357023j)
# MCPImpl: num_above=412, num_below=368
# beta_solver, min eigen of left matrix = (0.9427723-0.0026357023j)
# MCPImpl: num_above=433, num_below=347
# beta_solver, min eigen of left matrix = (0.9427723-0.0026357023j)
# MCPImpl: num_above=414, num_below=366
# beta_solver, min eigen of left matrix = (0.9427723-0.0026357023j)
# MCPImpl: num_above=433, num_below=347
# kmeans center = [[-1.48815048  3.91640058 -2.10293025 -3.92137755  1.59272708 -4.96634435]
#  [ 1.25132241 -3.63443476  2.03898295  3.82952391 -1.72399512  5.15268713]] and inertia = 100.8251387497333
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = (0.94489056+0j)
# MCPImpl: num_above=401, num_below=379
# beta_solver, min eigen of left matrix = (0.94489056+0j)
# MCPImpl: num_above=412, num_below=368
# beta_solver, min eigen of left matrix = (0.94489056+0j)
# MCPImpl: num_above=403, num_below=377
# beta_solver, min eigen of left matrix = (0.94489056+0j)
# MCPImpl: num_above=412, num_below=368
# beta_solver, min eigen of left matrix = (0.94489056+0j)
# MCPImpl: num_above=403, num_below=377
# beta_solver, min eigen of left matrix = (0.94489056+0j)
# MCPImpl: num_above=412, num_below=368
# beta_solver, min eigen of left matrix = (0.94489056+0j)
# MCPImpl: num_above=406, num_below=374
# beta_solver, min eigen of left matrix = (0.94489056+0j)
# MCPImpl: num_above=412, num_below=368
# beta_solver, min eigen of left matrix = (0.94489056+0j)
# MCPImpl: num_above=405, num_below=375
# beta_solver, min eigen of left matrix = (0.94489056+0j)
# MCPImpl: num_above=412, num_below=368
# kmeans center = [[-1.44651913  3.51553376 -2.16534483 -3.84154538  1.47760155 -4.95159645]
#  [ 1.52250156 -3.81797496  2.24342345  4.03293786 -1.66825128  4.93391691]] and inertia = 73.00164991687701
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = (0.94556266-0.0013921246j)
# MCPImpl: num_above=402, num_below=378
# beta_solver, min eigen of left matrix = (0.94556266-0.0013921246j)
# MCPImpl: num_above=423, num_below=357
# beta_solver, min eigen of left matrix = (0.94556266-0.0013921246j)
# MCPImpl: num_above=411, num_below=369
# beta_solver, min eigen of left matrix = (0.94556266-0.0013921246j)
# MCPImpl: num_above=422, num_below=358
# beta_solver, min eigen of left matrix = (0.94556266-0.0013921246j)
# MCPImpl: num_above=410, num_below=370
# beta_solver, min eigen of left matrix = (0.94556266-0.0013921246j)
# MCPImpl: num_above=422, num_below=358
# beta_solver, min eigen of left matrix = (0.94556266-0.0013921246j)
# MCPImpl: num_above=411, num_below=369
# beta_solver, min eigen of left matrix = (0.94556266-0.0013921246j)
# MCPImpl: num_above=422, num_below=358
# beta_solver, min eigen of left matrix = (0.94556266-0.0013921246j)
# MCPImpl: num_above=412, num_below=368
# beta_solver, min eigen of left matrix = (0.94556266-0.0013921246j)
# MCPImpl: num_above=422, num_below=358
# kmeans center = [[-1.43969647  3.62144383 -1.95641708 -3.91238058  1.44940491 -4.92622492]
#  [ 1.63413085 -3.53822159  1.83872371  4.05011482 -1.80424491  5.13876724]] and inertia = 95.55896197390419
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = (0.937287+0j)
# MCPImpl: num_above=403, num_below=377
# beta_solver, min eigen of left matrix = (0.937287+0j)
# MCPImpl: num_above=412, num_below=368
# beta_solver, min eigen of left matrix = (0.937287+0j)
# MCPImpl: num_above=408, num_below=372
# beta_solver, min eigen of left matrix = (0.937287+0j)
# MCPImpl: num_above=413, num_below=367
# beta_solver, min eigen of left matrix = (0.937287+0j)
# MCPImpl: num_above=407, num_below=373
# beta_solver, min eigen of left matrix = (0.937287+0j)
# MCPImpl: num_above=414, num_below=366
# beta_solver, min eigen of left matrix = (0.937287+0j)
# MCPImpl: num_above=406, num_below=374
# beta_solver, min eigen of left matrix = (0.937287+0j)
# MCPImpl: num_above=414, num_below=366
# beta_solver, min eigen of left matrix = (0.937287+0j)
# MCPImpl: num_above=407, num_below=373
# beta_solver, min eigen of left matrix = (0.937287+0j)
# MCPImpl: num_above=413, num_below=367
# kmeans center = [[-1.47223283  3.89583337 -2.24313522 -3.49445556  1.48247544 -5.11628733]
#  [ 1.69942749 -3.89114816  1.8015672   3.79222758 -1.61004647  4.88839613]] and inertia = 84.16506135361564
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = (0.9443+0j)
# MCPImpl: num_above=401, num_below=379
# beta_solver, min eigen of left matrix = (0.9443+0j)
# MCPImpl: num_above=409, num_below=371
# beta_solver, min eigen of left matrix = (0.9443+0j)
# MCPImpl: num_above=403, num_below=377
# beta_solver, min eigen of left matrix = (0.9443+0j)
# MCPImpl: num_above=409, num_below=371
# beta_solver, min eigen of left matrix = (0.9443+0j)
# MCPImpl: num_above=403, num_below=377
# beta_solver, min eigen of left matrix = (0.9443+0j)
# MCPImpl: num_above=409, num_below=371
# beta_solver, min eigen of left matrix = (0.9443+0j)
# MCPImpl: num_above=403, num_below=377
# beta_solver, min eigen of left matrix = (0.9443+0j)
# MCPImpl: num_above=409, num_below=371
# beta_solver, min eigen of left matrix = (0.9443+0j)
# MCPImpl: num_above=403, num_below=377
# beta_solver, min eigen of left matrix = (0.9443+0j)
# MCPImpl: num_above=409, num_below=371
# kmeans center = [[-1.77346401  3.69049061 -2.36358181 -3.73078075  1.59561751 -5.20475568]
#  [ 1.60431374 -3.69546413  2.13838774  3.80879908 -1.58622504  5.06866592]] and inertia = 69.14213992905647
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = (0.93737435+0j)
# MCPImpl: num_above=417, num_below=363
# beta_solver, min eigen of left matrix = (0.93737435+0j)
# MCPImpl: num_above=464, num_below=316
# beta_solver, min eigen of left matrix = (0.93737435+0j)
# MCPImpl: num_above=423, num_below=357
# beta_solver, min eigen of left matrix = (0.93737435+0j)
# MCPImpl: num_above=466, num_below=314
# beta_solver, min eigen of left matrix = (0.93737435+0j)
# MCPImpl: num_above=425, num_below=355
# beta_solver, min eigen of left matrix = (0.93737435+0j)
# MCPImpl: num_above=466, num_below=314
# beta_solver, min eigen of left matrix = (0.93737435+0j)
# MCPImpl: num_above=426, num_below=354
# beta_solver, min eigen of left matrix = (0.93737435+0j)
# MCPImpl: num_above=468, num_below=312
# beta_solver, min eigen of left matrix = (0.93737435+0j)
# MCPImpl: num_above=428, num_below=352
# beta_solver, min eigen of left matrix = (0.93737435+0j)
# MCPImpl: num_above=468, num_below=312
# kmeans center = [[-1.60923722  3.99534673 -2.15636597 -3.68052383  1.55548687 -5.03938703]
#  [ 1.75353816 -3.92733717  2.31597769  3.72662431 -1.5471197   5.31427481]] and inertia = 132.75426301526335
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = 0.9406959
# MCPImpl: num_above=402, num_below=378
# beta_solver, min eigen of left matrix = 0.9406959
# MCPImpl: num_above=428, num_below=352
# beta_solver, min eigen of left matrix = 0.9406959
# MCPImpl: num_above=406, num_below=374
# beta_solver, min eigen of left matrix = 0.9406959
# MCPImpl: num_above=429, num_below=351
# beta_solver, min eigen of left matrix = 0.9406959
# MCPImpl: num_above=407, num_below=373
# beta_solver, min eigen of left matrix = 0.9406959
# MCPImpl: num_above=429, num_below=351
# beta_solver, min eigen of left matrix = 0.9406959
# MCPImpl: num_above=407, num_below=373
# beta_solver, min eigen of left matrix = 0.9406959
# MCPImpl: num_above=429, num_below=351
# beta_solver, min eigen of left matrix = 0.9406959
# MCPImpl: num_above=407, num_below=373
# beta_solver, min eigen of left matrix = 0.9406959
# MCPImpl: num_above=429, num_below=351
# kmeans center = [[-1.60318683  3.86238852 -2.06195441 -3.53473766  1.45414674 -4.95593087]
#  [ 1.50063537 -3.67578719  2.18912687  3.80102627 -1.5483492   5.0403972 ]] and inertia = 91.71774447455277
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = (0.9441756-0.0012065495j)
# MCPImpl: num_above=407, num_below=373
# beta_solver, min eigen of left matrix = (0.9441756-0.0012065495j)
# MCPImpl: num_above=455, num_below=325
# beta_solver, min eigen of left matrix = (0.9441756-0.0012065495j)
# MCPImpl: num_above=419, num_below=361
# beta_solver, min eigen of left matrix = (0.9441756-0.0012065495j)
# MCPImpl: num_above=455, num_below=325
# beta_solver, min eigen of left matrix = (0.9441756-0.0012065495j)
# MCPImpl: num_above=419, num_below=361
# beta_solver, min eigen of left matrix = (0.9441756-0.0012065495j)
# MCPImpl: num_above=457, num_below=323
# beta_solver, min eigen of left matrix = (0.9441756-0.0012065495j)
# MCPImpl: num_above=421, num_below=359
# beta_solver, min eigen of left matrix = (0.9441756-0.0012065495j)
# MCPImpl: num_above=456, num_below=324
# beta_solver, min eigen of left matrix = (0.9441756-0.0012065495j)
# MCPImpl: num_above=423, num_below=357
# beta_solver, min eigen of left matrix = (0.9441756-0.0012065495j)
# MCPImpl: num_above=456, num_below=324
# kmeans center = [[-1.53409089  4.05703904 -2.06159331 -3.75736809  1.68970467 -5.01596046]
#  [ 1.34805986 -3.8323439   1.96375625  4.07853885 -1.41983961  5.00101581]] and inertia = 108.2695177860553
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = 0.9455186
# MCPImpl: num_above=406, num_below=374
# beta_solver, min eigen of left matrix = 0.9455186
# MCPImpl: num_above=435, num_below=345
# beta_solver, min eigen of left matrix = 0.9455186
# MCPImpl: num_above=415, num_below=365
# beta_solver, min eigen of left matrix = 0.9455186
# MCPImpl: num_above=435, num_below=345
# beta_solver, min eigen of left matrix = 0.9455186
# MCPImpl: num_above=413, num_below=367
# beta_solver, min eigen of left matrix = 0.9455186
# MCPImpl: num_above=434, num_below=346
# beta_solver, min eigen of left matrix = 0.9455186
# MCPImpl: num_above=416, num_below=364
# beta_solver, min eigen of left matrix = 0.9455186
# MCPImpl: num_above=434, num_below=346
# beta_solver, min eigen of left matrix = 0.9455186
# MCPImpl: num_above=416, num_below=364
# beta_solver, min eigen of left matrix = 0.9455186
# MCPImpl: num_above=435, num_below=345
# kmeans center = [[-1.61409444  3.97698785 -2.16847812 -3.52214889  1.44106328 -4.94282687]
#  [ 1.55440169 -3.44586403  2.43202991  4.00313685 -1.73302253  5.26707204]] and inertia = 97.63915980526261
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = 0.9257688
# MCPImpl: num_above=403, num_below=377
# beta_solver, min eigen of left matrix = 0.9257688
# MCPImpl: num_above=422, num_below=358
# beta_solver, min eigen of left matrix = 0.9257688
# MCPImpl: num_above=406, num_below=374
# beta_solver, min eigen of left matrix = 0.9257688
# MCPImpl: num_above=422, num_below=358
# beta_solver, min eigen of left matrix = 0.9257688
# MCPImpl: num_above=406, num_below=374
# beta_solver, min eigen of left matrix = 0.9257688
# MCPImpl: num_above=422, num_below=358
# beta_solver, min eigen of left matrix = 0.9257688
# MCPImpl: num_above=406, num_below=374
# beta_solver, min eigen of left matrix = 0.9257688
# MCPImpl: num_above=422, num_below=358
# beta_solver, min eigen of left matrix = 0.9257688
# MCPImpl: num_above=406, num_below=374
# beta_solver, min eigen of left matrix = 0.9257688
# MCPImpl: num_above=423, num_below=357
# kmeans center = [[-1.79241163  3.80140376 -2.30080143 -3.47749691  1.36394487 -5.17684852]
#  [ 1.5578045  -3.78554522  2.17215146  3.87708333 -1.51422877  4.96752952]] and inertia = 84.32096774160378
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = (0.9427545+0j)
# MCPImpl: num_above=406, num_below=374
# beta_solver, min eigen of left matrix = (0.9427545+0j)
# MCPImpl: num_above=445, num_below=335
# beta_solver, min eigen of left matrix = (0.9427545+0j)
# MCPImpl: num_above=412, num_below=368
# beta_solver, min eigen of left matrix = (0.9427545+0j)
# MCPImpl: num_above=446, num_below=334
# beta_solver, min eigen of left matrix = (0.9427545+0j)
# MCPImpl: num_above=415, num_below=365
# beta_solver, min eigen of left matrix = (0.9427545+0j)
# MCPImpl: num_above=445, num_below=335
# beta_solver, min eigen of left matrix = (0.9427545+0j)
# MCPImpl: num_above=416, num_below=364
# beta_solver, min eigen of left matrix = (0.9427545+0j)
# MCPImpl: num_above=446, num_below=334
# beta_solver, min eigen of left matrix = (0.9427545+0j)
# MCPImpl: num_above=415, num_below=365
# beta_solver, min eigen of left matrix = (0.9427545+0j)
# MCPImpl: num_above=445, num_below=335
# kmeans center = [[-1.63721978  3.89057578 -2.32212945 -3.85420373  1.60979665 -5.24891369]
#  [ 1.62182783 -3.52242164  1.85302685  3.81004436 -1.72184896  4.84537617]] and inertia = 104.58578291241949
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = (0.9406297+0j)
# MCPImpl: num_above=405, num_below=375
# beta_solver, min eigen of left matrix = (0.9406297+0j)
# MCPImpl: num_above=421, num_below=359
# beta_solver, min eigen of left matrix = (0.9406297+0j)
# MCPImpl: num_above=411, num_below=369
# beta_solver, min eigen of left matrix = (0.9406297+0j)
# MCPImpl: num_above=421, num_below=359
# beta_solver, min eigen of left matrix = (0.9406297+0j)
# MCPImpl: num_above=411, num_below=369
# beta_solver, min eigen of left matrix = (0.9406297+0j)
# MCPImpl: num_above=422, num_below=358
# beta_solver, min eigen of left matrix = (0.9406297+0j)
# MCPImpl: num_above=411, num_below=369
# beta_solver, min eigen of left matrix = (0.9406297+0j)
# MCPImpl: num_above=421, num_below=359
# beta_solver, min eigen of left matrix = (0.9406297+0j)
# MCPImpl: num_above=411, num_below=369
# beta_solver, min eigen of left matrix = (0.9406297+0j)
# MCPImpl: num_above=422, num_below=358
# kmeans center = [[-1.71080622  3.7928843  -2.36045869 -3.75404425  1.53869336 -5.23380537]
#  [ 1.69844209 -3.80029547  2.19351078  3.51124204 -1.59304739  5.08160077]] and inertia = 87.80505034120695
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = (0.944007+0j)
# MCPImpl: num_above=413, num_below=367
# beta_solver, min eigen of left matrix = (0.944007+0j)
# MCPImpl: num_above=449, num_below=331
# beta_solver, min eigen of left matrix = (0.944007+0j)
# MCPImpl: num_above=418, num_below=362
# beta_solver, min eigen of left matrix = (0.944007+0j)
# MCPImpl: num_above=447, num_below=333
# beta_solver, min eigen of left matrix = (0.944007+0j)
# MCPImpl: num_above=419, num_below=361
# beta_solver, min eigen of left matrix = (0.944007+0j)
# MCPImpl: num_above=446, num_below=334
# beta_solver, min eigen of left matrix = (0.944007+0j)
# MCPImpl: num_above=421, num_below=359
# beta_solver, min eigen of left matrix = (0.944007+0j)
# MCPImpl: num_above=446, num_below=334
# beta_solver, min eigen of left matrix = (0.944007+0j)
# MCPImpl: num_above=420, num_below=360
# beta_solver, min eigen of left matrix = (0.944007+0j)
# MCPImpl: num_above=446, num_below=334
# kmeans center = [[-1.59682941  3.92459267 -2.18049598 -3.77322981  1.58936333 -5.30319751]
#  [ 1.60228278 -3.82846021  2.28120681  3.80730929 -1.71421529  5.23747284]] and inertia = 114.63707393164641
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = (0.9446115-0.00058239844j)
# MCPImpl: num_above=400, num_below=380
# beta_solver, min eigen of left matrix = (0.9446115-0.00058239844j)
# MCPImpl: num_above=404, num_below=376
# beta_solver, min eigen of left matrix = (0.9446115-0.00058239844j)
# MCPImpl: num_above=401, num_below=379
# beta_solver, min eigen of left matrix = (0.9446115-0.00058239844j)
# MCPImpl: num_above=404, num_below=376
# beta_solver, min eigen of left matrix = (0.9446115-0.00058239844j)
# MCPImpl: num_above=401, num_below=379
# beta_solver, min eigen of left matrix = (0.9446115-0.00058239844j)
# MCPImpl: num_above=404, num_below=376
# beta_solver, min eigen of left matrix = (0.9446115-0.00058239844j)
# MCPImpl: num_above=401, num_below=379
# beta_solver, min eigen of left matrix = (0.9446115-0.00058239844j)
# MCPImpl: num_above=404, num_below=376
# beta_solver, min eigen of left matrix = (0.9446115-0.00058239844j)
# MCPImpl: num_above=401, num_below=379
# beta_solver, min eigen of left matrix = (0.9446115-0.00058239844j)
# MCPImpl: num_above=404, num_below=376
# kmeans center = [[-1.46604028  3.6432298  -2.37131341 -3.8106496   1.7735672  -5.22191179]
#  [ 1.68910378 -3.89539418  2.11527065  3.82513449 -1.60909244  5.17772953]] and inertia = 70.48491889771347
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = (0.9261977+0j)
# MCPImpl: num_above=401, num_below=379
# beta_solver, min eigen of left matrix = (0.9261977+0j)
# MCPImpl: num_above=430, num_below=350
# beta_solver, min eigen of left matrix = (0.9261977+0j)
# MCPImpl: num_above=405, num_below=375
# beta_solver, min eigen of left matrix = (0.9261977+0j)
# MCPImpl: num_above=431, num_below=349
# beta_solver, min eigen of left matrix = (0.9261977+0j)
# MCPImpl: num_above=405, num_below=375
# beta_solver, min eigen of left matrix = (0.9261977+0j)
# MCPImpl: num_above=431, num_below=349
# beta_solver, min eigen of left matrix = (0.9261977+0j)
# MCPImpl: num_above=408, num_below=372
# beta_solver, min eigen of left matrix = (0.9261977+0j)
# MCPImpl: num_above=431, num_below=349
# beta_solver, min eigen of left matrix = (0.9261977+0j)
# MCPImpl: num_above=407, num_below=373
# beta_solver, min eigen of left matrix = (0.9261977+0j)
# MCPImpl: num_above=431, num_below=349
# kmeans center = [[-1.68942196  3.70728144 -1.69337314 -3.73181184  1.639556   -4.76229157]
#  [ 1.59384834 -4.01390547  1.95868499  3.94595503 -1.62048278  4.82646749]] and inertia = 89.62272392224608
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = 0.9376974
# MCPImpl: num_above=401, num_below=379
# beta_solver, min eigen of left matrix = 0.9376974
# MCPImpl: num_above=422, num_below=358
# beta_solver, min eigen of left matrix = 0.9376974
# MCPImpl: num_above=403, num_below=377
# beta_solver, min eigen of left matrix = 0.9376974
# MCPImpl: num_above=422, num_below=358
# beta_solver, min eigen of left matrix = 0.9376974
# MCPImpl: num_above=404, num_below=376
# beta_solver, min eigen of left matrix = 0.9376974
# MCPImpl: num_above=422, num_below=358
# beta_solver, min eigen of left matrix = 0.9376974
# MCPImpl: num_above=404, num_below=376
# beta_solver, min eigen of left matrix = 0.9376974
# MCPImpl: num_above=422, num_below=358
# beta_solver, min eigen of left matrix = 0.9376974
# MCPImpl: num_above=404, num_below=376
# beta_solver, min eigen of left matrix = 0.9376974
# MCPImpl: num_above=422, num_below=358
# kmeans center = [[-1.52119773  3.5336707  -2.25337881 -4.07100324  1.7376338  -5.28005784]
#  [ 1.52241717 -3.92728143  1.82508833  3.83620313 -1.72867374  4.90992747]] and inertia = 84.85077332585578
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = (0.9409348+0j)
# MCPImpl: num_above=408, num_below=372
# beta_solver, min eigen of left matrix = (0.9409348+0j)
# MCPImpl: num_above=441, num_below=339
# beta_solver, min eigen of left matrix = (0.9409348+0j)
# MCPImpl: num_above=410, num_below=370
# beta_solver, min eigen of left matrix = (0.9409348+0j)
# MCPImpl: num_above=440, num_below=340
# beta_solver, min eigen of left matrix = (0.9409348+0j)
# MCPImpl: num_above=413, num_below=367
# beta_solver, min eigen of left matrix = (0.9409348+0j)
# MCPImpl: num_above=440, num_below=340
# beta_solver, min eigen of left matrix = (0.9409348+0j)
# MCPImpl: num_above=413, num_below=367
# beta_solver, min eigen of left matrix = (0.9409348+0j)
# MCPImpl: num_above=440, num_below=340
# beta_solver, min eigen of left matrix = (0.9409348+0j)
# MCPImpl: num_above=414, num_below=366
# beta_solver, min eigen of left matrix = (0.9409348+0j)
# MCPImpl: num_above=440, num_below=340
# kmeans center = [[-1.97652867  4.11025466 -2.12556383 -3.47070622  1.66573957 -5.03093402]
#  [ 1.87922755 -4.0432232   1.98693952  3.97608433 -1.65101989  4.97617132]] and inertia = 103.96414865726611
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = (0.93320656+0j)
# MCPImpl: num_above=425, num_below=355
# beta_solver, min eigen of left matrix = (0.93320656+0j)
# MCPImpl: num_above=485, num_below=295
# beta_solver, min eigen of left matrix = (0.93320656+0j)
# MCPImpl: num_above=444, num_below=336
# beta_solver, min eigen of left matrix = (0.93320656+0j)
# MCPImpl: num_above=485, num_below=295
# beta_solver, min eigen of left matrix = (0.93320656+0j)
# MCPImpl: num_above=446, num_below=334
# beta_solver, min eigen of left matrix = (0.93320656+0j)
# MCPImpl: num_above=485, num_below=295
# beta_solver, min eigen of left matrix = (0.93320656+0j)
# MCPImpl: num_above=446, num_below=334
# beta_solver, min eigen of left matrix = (0.93320656+0j)
# MCPImpl: num_above=484, num_below=296
# beta_solver, min eigen of left matrix = (0.93320656+0j)
# MCPImpl: num_above=447, num_below=333
# beta_solver, min eigen of left matrix = (0.93320656+0j)
# MCPImpl: num_above=484, num_below=296
# kmeans center = [[-1.63198612  4.14824776 -1.9636666  -3.74698063  1.61314401 -5.02399029]
#  [ 1.51107106 -3.62038741  1.96274245  3.78459771 -1.47067452  4.71562832]] and inertia = 141.75660298175774
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = (0.9491355-0.0018096713j)
# MCPImpl: num_above=400, num_below=380
# beta_solver, min eigen of left matrix = (0.9491355-0.0018096713j)
# MCPImpl: num_above=409, num_below=371
# beta_solver, min eigen of left matrix = (0.9491355-0.0018096713j)
# MCPImpl: num_above=400, num_below=380
# beta_solver, min eigen of left matrix = (0.9491355-0.0018096713j)
# MCPImpl: num_above=409, num_below=371
# beta_solver, min eigen of left matrix = (0.9491355-0.0018096713j)
# MCPImpl: num_above=400, num_below=380
# beta_solver, min eigen of left matrix = (0.9491355-0.0018096713j)
# MCPImpl: num_above=409, num_below=371
# beta_solver, min eigen of left matrix = (0.9491355-0.0018096713j)
# MCPImpl: num_above=400, num_below=380
# beta_solver, min eigen of left matrix = (0.9491355-0.0018096713j)
# MCPImpl: num_above=409, num_below=371
# beta_solver, min eigen of left matrix = (0.9491355-0.0018096713j)
# MCPImpl: num_above=400, num_below=380
# beta_solver, min eigen of left matrix = (0.9491355-0.0018096713j)
# MCPImpl: num_above=409, num_below=371
# kmeans center = [[-1.3675831   3.70575887 -2.30617032 -3.83893637  1.47100536 -5.14864893]
#  [ 1.55696137 -3.56558858  2.05524678  3.80330637 -1.63199399  4.72336956]] and inertia = 69.75432074164263
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = (0.94361573+0j)
# MCPImpl: num_above=400, num_below=380
# beta_solver, min eigen of left matrix = (0.94361573+0j)
# MCPImpl: num_above=416, num_below=364
# beta_solver, min eigen of left matrix = (0.94361573+0j)
# MCPImpl: num_above=404, num_below=376
# beta_solver, min eigen of left matrix = (0.94361573+0j)
# MCPImpl: num_above=416, num_below=364
# beta_solver, min eigen of left matrix = (0.94361573+0j)
# MCPImpl: num_above=405, num_below=375
# beta_solver, min eigen of left matrix = (0.94361573+0j)
# MCPImpl: num_above=416, num_below=364
# beta_solver, min eigen of left matrix = (0.94361573+0j)
# MCPImpl: num_above=404, num_below=376
# beta_solver, min eigen of left matrix = (0.94361573+0j)
# MCPImpl: num_above=416, num_below=364
# beta_solver, min eigen of left matrix = (0.94361573+0j)
# MCPImpl: num_above=406, num_below=374
# beta_solver, min eigen of left matrix = (0.94361573+0j)
# MCPImpl: num_above=416, num_below=364
# kmeans center = [[-1.78955274  3.75784311 -2.15136562 -3.64551657  1.59913417 -5.14268671]
#  [ 1.7510283  -3.81925499  2.28645946  3.63007376 -1.61546624  5.14527053]] and inertia = 77.44238556853577
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = (0.94922024+0j)
# MCPImpl: num_above=400, num_below=380
# beta_solver, min eigen of left matrix = (0.94922024+0j)
# MCPImpl: num_above=413, num_below=367
# beta_solver, min eigen of left matrix = (0.94922024+0j)
# MCPImpl: num_above=406, num_below=374
# beta_solver, min eigen of left matrix = (0.94922024+0j)
# MCPImpl: num_above=413, num_below=367
# beta_solver, min eigen of left matrix = (0.94922024+0j)
# MCPImpl: num_above=407, num_below=373
# beta_solver, min eigen of left matrix = (0.94922024+0j)
# MCPImpl: num_above=413, num_below=367
# beta_solver, min eigen of left matrix = (0.94922024+0j)
# MCPImpl: num_above=408, num_below=372
# beta_solver, min eigen of left matrix = (0.94922024+0j)
# MCPImpl: num_above=413, num_below=367
# beta_solver, min eigen of left matrix = (0.94922024+0j)
# MCPImpl: num_above=408, num_below=372
# beta_solver, min eigen of left matrix = (0.94922024+0j)
# MCPImpl: num_above=413, num_below=367
# kmeans center = [[-1.61803034  3.58222068 -2.0972051  -3.80559366  1.55864819 -4.90906229]
#  [ 1.49100298 -3.75595547  2.39189064  3.91787838 -1.68056434  5.35542025]] and inertia = 80.23012549446123
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = (0.93709207-0.000565137j)
# MCPImpl: num_above=406, num_below=374
# beta_solver, min eigen of left matrix = (0.93709207-0.000565137j)
# MCPImpl: num_above=451, num_below=329
# beta_solver, min eigen of left matrix = (0.93709207-0.000565137j)
# MCPImpl: num_above=425, num_below=355
# beta_solver, min eigen of left matrix = (0.93709207-0.000565137j)
# MCPImpl: num_above=457, num_below=323
# beta_solver, min eigen of left matrix = (0.93709207-0.000565137j)
# MCPImpl: num_above=426, num_below=354
# beta_solver, min eigen of left matrix = (0.93709207-0.000565137j)
# MCPImpl: num_above=456, num_below=324
# beta_solver, min eigen of left matrix = (0.93709207-0.000565137j)
# MCPImpl: num_above=426, num_below=354
# beta_solver, min eigen of left matrix = (0.93709207-0.000565137j)
# MCPImpl: num_above=456, num_below=324
# beta_solver, min eigen of left matrix = (0.93709207-0.000565137j)
# MCPImpl: num_above=428, num_below=352
# beta_solver, min eigen of left matrix = (0.93709207-0.000565137j)
# MCPImpl: num_above=455, num_below=325
# kmeans center = [[-1.90655812  3.72461754 -1.78535073 -3.72864416  1.61943925 -4.82875695]
#  [ 1.54886163 -3.63300663  2.26043159  4.13138934 -1.61341165  5.36862557]] and inertia = 116.024486339159
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = (0.9467583+0j)
# MCPImpl: num_above=427, num_below=353
# beta_solver, min eigen of left matrix = (0.9467583+0j)
# MCPImpl: num_above=479, num_below=301
# beta_solver, min eigen of left matrix = (0.9467583+0j)
# MCPImpl: num_above=447, num_below=333
# beta_solver, min eigen of left matrix = (0.9467583+0j)
# MCPImpl: num_above=477, num_below=303
# beta_solver, min eigen of left matrix = (0.9467583+0j)
# MCPImpl: num_above=448, num_below=332
# beta_solver, min eigen of left matrix = (0.9467583+0j)
# MCPImpl: num_above=476, num_below=304
# beta_solver, min eigen of left matrix = (0.9467583+0j)
# MCPImpl: num_above=450, num_below=330
# beta_solver, min eigen of left matrix = (0.9467583+0j)
# MCPImpl: num_above=475, num_below=305
# beta_solver, min eigen of left matrix = (0.9467583+0j)
# MCPImpl: num_above=453, num_below=327
# beta_solver, min eigen of left matrix = (0.9467583+0j)
# MCPImpl: num_above=475, num_below=305
# kmeans center = [[-1.52647422  3.75420984 -1.99537938 -3.7826251   1.48581338 -5.04649328]
#  [ 1.64285402 -3.72452241  2.10016773  3.67043146 -1.50308072  5.19231741]] and inertia = 145.51790646576524
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = (0.9441015+0j)
# MCPImpl: num_above=404, num_below=376
# beta_solver, min eigen of left matrix = (0.9441015+0j)
# MCPImpl: num_above=436, num_below=344
# beta_solver, min eigen of left matrix = (0.9441015+0j)
# MCPImpl: num_above=409, num_below=371
# beta_solver, min eigen of left matrix = (0.9441015+0j)
# MCPImpl: num_above=437, num_below=343
# beta_solver, min eigen of left matrix = (0.9441015+0j)
# MCPImpl: num_above=409, num_below=371
# beta_solver, min eigen of left matrix = (0.9441015+0j)
# MCPImpl: num_above=437, num_below=343
# beta_solver, min eigen of left matrix = (0.9441015+0j)
# MCPImpl: num_above=409, num_below=371
# beta_solver, min eigen of left matrix = (0.9441015+0j)
# MCPImpl: num_above=437, num_below=343
# beta_solver, min eigen of left matrix = (0.9441015+0j)
# MCPImpl: num_above=408, num_below=372
# beta_solver, min eigen of left matrix = (0.9441015+0j)
# MCPImpl: num_above=437, num_below=343
# kmeans center = [[-1.51679919  3.77593639 -2.334765   -3.75324718  1.53696782 -5.37432217]
#  [ 1.47402263 -3.85023508  2.13342165  3.9317856  -1.64347453  5.06133604]] and inertia = 95.22620273369992
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = 0.9417894
# MCPImpl: num_above=401, num_below=379
# beta_solver, min eigen of left matrix = 0.9417894
# MCPImpl: num_above=421, num_below=359
# beta_solver, min eigen of left matrix = 0.9417894
# MCPImpl: num_above=405, num_below=375
# beta_solver, min eigen of left matrix = 0.9417894
# MCPImpl: num_above=421, num_below=359
# beta_solver, min eigen of left matrix = 0.9417894
# MCPImpl: num_above=406, num_below=374
# beta_solver, min eigen of left matrix = 0.9417894
# MCPImpl: num_above=420, num_below=360
# beta_solver, min eigen of left matrix = 0.9417894
# MCPImpl: num_above=406, num_below=374
# beta_solver, min eigen of left matrix = 0.9417894
# MCPImpl: num_above=421, num_below=359
# beta_solver, min eigen of left matrix = 0.9417894
# MCPImpl: num_above=407, num_below=373
# beta_solver, min eigen of left matrix = 0.9417894
# MCPImpl: num_above=420, num_below=360
# kmeans center = [[-1.38911141  3.59650011 -2.09709062 -3.58785748  1.69770576 -5.09795405]
#  [ 1.45318644 -3.60559593  2.13905339  3.95953865 -1.65528611  5.15791395]] and inertia = 81.52710321226431
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = (0.9425933+0j)
# MCPImpl: num_above=403, num_below=377
# beta_solver, min eigen of left matrix = (0.9425933+0j)
# MCPImpl: num_above=435, num_below=345
# beta_solver, min eigen of left matrix = (0.9425933+0j)
# MCPImpl: num_above=406, num_below=374
# beta_solver, min eigen of left matrix = (0.9425933+0j)
# MCPImpl: num_above=435, num_below=345
# beta_solver, min eigen of left matrix = (0.9425933+0j)
# MCPImpl: num_above=409, num_below=371
# beta_solver, min eigen of left matrix = (0.9425933+0j)
# MCPImpl: num_above=435, num_below=345
# beta_solver, min eigen of left matrix = (0.9425933+0j)
# MCPImpl: num_above=407, num_below=373
# beta_solver, min eigen of left matrix = (0.9425933+0j)
# MCPImpl: num_above=436, num_below=344
# beta_solver, min eigen of left matrix = (0.9425933+0j)
# MCPImpl: num_above=408, num_below=372
# beta_solver, min eigen of left matrix = (0.9425933+0j)
# MCPImpl: num_above=435, num_below=345
# kmeans center = [[-1.45691024  4.0246252  -2.02697341 -3.73670862  1.50020486 -4.98510999]
#  [ 1.67990454 -3.75652293  1.95757726  3.72610366 -1.52210621  5.03516493]] and inertia = 87.49197661023373
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = (0.93880135-0.0005455291j)
# MCPImpl: num_above=405, num_below=375
# beta_solver, min eigen of left matrix = (0.93880135-0.0005455291j)
# MCPImpl: num_above=432, num_below=348
# beta_solver, min eigen of left matrix = (0.93880135-0.0005455291j)
# MCPImpl: num_above=410, num_below=370
# beta_solver, min eigen of left matrix = (0.93880135-0.0005455291j)
# MCPImpl: num_above=433, num_below=347
# beta_solver, min eigen of left matrix = (0.93880135-0.0005455291j)
# MCPImpl: num_above=411, num_below=369
# beta_solver, min eigen of left matrix = (0.93880135-0.0005455291j)
# MCPImpl: num_above=432, num_below=348
# beta_solver, min eigen of left matrix = (0.93880135-0.0005455291j)
# MCPImpl: num_above=413, num_below=367
# beta_solver, min eigen of left matrix = (0.93880135-0.0005455291j)
# MCPImpl: num_above=433, num_below=347
# beta_solver, min eigen of left matrix = (0.93880135-0.0005455291j)
# MCPImpl: num_above=412, num_below=368
# beta_solver, min eigen of left matrix = (0.93880135-0.0005455291j)
# MCPImpl: num_above=432, num_below=348
# kmeans center = [[-1.71727983  3.51694808 -1.90466576 -4.08410101  1.69413774 -5.18973103]
#  [ 1.56530928 -3.41623769  1.94265065  3.84118992 -1.54599224  4.91125809]] and inertia = 99.60798888960412
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = (0.94156986+0j)
# MCPImpl: num_above=401, num_below=379
# beta_solver, min eigen of left matrix = (0.94156986+0j)
# MCPImpl: num_above=412, num_below=368
# beta_solver, min eigen of left matrix = (0.94156986+0j)
# MCPImpl: num_above=402, num_below=378
# beta_solver, min eigen of left matrix = (0.94156986+0j)
# MCPImpl: num_above=412, num_below=368
# beta_solver, min eigen of left matrix = (0.94156986+0j)
# MCPImpl: num_above=403, num_below=377
# beta_solver, min eigen of left matrix = (0.94156986+0j)
# MCPImpl: num_above=412, num_below=368
# beta_solver, min eigen of left matrix = (0.94156986+0j)
# MCPImpl: num_above=402, num_below=378
# beta_solver, min eigen of left matrix = (0.94156986+0j)
# MCPImpl: num_above=412, num_below=368
# beta_solver, min eigen of left matrix = (0.94156986+0j)
# MCPImpl: num_above=402, num_below=378
# beta_solver, min eigen of left matrix = (0.94156986+0j)
# MCPImpl: num_above=412, num_below=368
# kmeans center = [[-1.69350678  3.74175413 -2.17671705 -3.57755706  1.77094529 -5.37499342]
#  [ 1.49274366 -3.72219502  2.33885391  3.70206469 -1.61439641  4.93200122]] and inertia = 77.61155993912901
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = (0.9421557+0j)
# MCPImpl: num_above=402, num_below=378
# beta_solver, min eigen of left matrix = (0.9421557+0j)
# MCPImpl: num_above=411, num_below=369
# beta_solver, min eigen of left matrix = (0.9421557+0j)
# MCPImpl: num_above=405, num_below=375
# beta_solver, min eigen of left matrix = (0.9421557+0j)
# MCPImpl: num_above=411, num_below=369
# beta_solver, min eigen of left matrix = (0.9421557+0j)
# MCPImpl: num_above=406, num_below=374
# beta_solver, min eigen of left matrix = (0.9421557+0j)
# MCPImpl: num_above=411, num_below=369
# beta_solver, min eigen of left matrix = (0.9421557+0j)
# MCPImpl: num_above=405, num_below=375
# beta_solver, min eigen of left matrix = (0.9421557+0j)
# MCPImpl: num_above=412, num_below=368
# beta_solver, min eigen of left matrix = (0.9421557+0j)
# MCPImpl: num_above=405, num_below=375
# beta_solver, min eigen of left matrix = (0.9421557+0j)
# MCPImpl: num_above=411, num_below=369
# kmeans center = [[-1.52508989  3.8832631  -2.49137116 -3.69086911  1.6341569  -5.4796181 ]
#  [ 1.48917271 -3.68320613  2.01552871  3.91733482 -1.4842401   5.03379673]] and inertia = 78.85146067969197
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = (0.943487-0.0046315743j)
# MCPImpl: num_above=405, num_below=375
# beta_solver, min eigen of left matrix = (0.943487-0.0046315743j)
# MCPImpl: num_above=437, num_below=343
# beta_solver, min eigen of left matrix = (0.943487-0.0046315743j)
# MCPImpl: num_above=412, num_below=368
# beta_solver, min eigen of left matrix = (0.943487-0.0046315743j)
# MCPImpl: num_above=438, num_below=342
# beta_solver, min eigen of left matrix = (0.943487-0.0046315743j)
# MCPImpl: num_above=415, num_below=365
# beta_solver, min eigen of left matrix = (0.943487-0.0046315743j)
# MCPImpl: num_above=438, num_below=342
# beta_solver, min eigen of left matrix = (0.943487-0.0046315743j)
# MCPImpl: num_above=414, num_below=366
# beta_solver, min eigen of left matrix = (0.943487-0.0046315743j)
# MCPImpl: num_above=438, num_below=342
# beta_solver, min eigen of left matrix = (0.943487-0.0046315743j)
# MCPImpl: num_above=416, num_below=364
# beta_solver, min eigen of left matrix = (0.943487-0.0046315743j)
# MCPImpl: num_above=438, num_below=342
# kmeans center = [[-1.78484982  3.8861658  -2.10922544 -3.67357231  1.50815502 -4.94668348]
#  [ 1.62499572 -3.80853391  1.89752331  4.14188814 -1.64156081  5.11513095]] and inertia = 103.17459872436305
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = (0.93537194+0j)
# MCPImpl: num_above=400, num_below=380
# beta_solver, min eigen of left matrix = (0.93537194+0j)
# MCPImpl: num_above=418, num_below=362
# beta_solver, min eigen of left matrix = (0.93537194+0j)
# MCPImpl: num_above=400, num_below=380
# beta_solver, min eigen of left matrix = (0.93537194+0j)
# MCPImpl: num_above=418, num_below=362
# beta_solver, min eigen of left matrix = (0.93537194+0j)
# MCPImpl: num_above=400, num_below=380
# beta_solver, min eigen of left matrix = (0.93537194+0j)
# MCPImpl: num_above=417, num_below=363
# beta_solver, min eigen of left matrix = (0.93537194+0j)
# MCPImpl: num_above=400, num_below=380
# beta_solver, min eigen of left matrix = (0.93537194+0j)
# MCPImpl: num_above=418, num_below=362
# beta_solver, min eigen of left matrix = (0.93537194+0j)
# MCPImpl: num_above=400, num_below=380
# beta_solver, min eigen of left matrix = (0.93537194+0j)
# MCPImpl: num_above=418, num_below=362
# kmeans center = [[-1.4681924   3.70128669 -2.09065538 -3.88139616  1.52559487 -5.18587956]
#  [ 1.48457479 -3.44374096  2.42557583  3.67187307 -1.70319049  4.93591382]] and inertia = 79.61285432877669
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = (0.9377173+0j)
# MCPImpl: num_above=411, num_below=369
# beta_solver, min eigen of left matrix = (0.9377173+0j)
# MCPImpl: num_above=445, num_below=335
# beta_solver, min eigen of left matrix = (0.9377173+0j)
# ...
# beta_solver, min eigen of left matrix = (0.94143313-0.0014806793j)
# MCPImpl: num_above=430, num_below=350
# beta_solver, min eigen of left matrix = (0.94143313-0.0014806793j)
# MCPImpl: num_above=406, num_below=374
# beta_solver, min eigen of left matrix = (0.94143313-0.0014806793j)
# MCPImpl: num_above=431, num_below=349
# beta_solver, min eigen of left matrix = (0.94143313-0.0014806793j)
# MCPImpl: num_above=408, num_below=372
# beta_solver, min eigen of left matrix = (0.94143313-0.0014806793j)
# MCPImpl: num_above=431, num_below=349
# beta_solver, min eigen of left matrix = (0.94143313-0.0014806793j)
# MCPImpl: num_above=408, num_below=372
# beta_solver, min eigen of left matrix = (0.94143313-0.0014806793j)
# MCPImpl: num_above=431, num_below=349
# beta_solver, min eigen of left matrix = (0.94143313-0.0014806793j)
# MCPImpl: num_above=409, num_below=371
# beta_solver, min eigen of left matrix = (0.94143313-0.0014806793j)
# MCPImpl: num_above=431, num_below=349
# kmeans center = [[-1.50283427  3.82731721 -1.98892175 -3.8557657   1.63459654 -4.88165389]
#  [ 1.60755664 -3.84479412  2.08102688  3.47235079 -1.49582356  5.23258972]] and inertia = 98.29719794432705
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = (0.9458678-0.001239369j)
# MCPImpl: num_above=402, num_below=378
# beta_solver, min eigen of left matrix = (0.9458678-0.001239369j)
# MCPImpl: num_above=424, num_below=356
# beta_solver, min eigen of left matrix = (0.9458678-0.001239369j)
# MCPImpl: num_above=404, num_below=376
# beta_solver, min eigen of left matrix = (0.9458678-0.001239369j)
# MCPImpl: num_above=424, num_below=356
# beta_solver, min eigen of left matrix = (0.9458678-0.001239369j)
# MCPImpl: num_above=405, num_below=375
# beta_solver, min eigen of left matrix = (0.9458678-0.001239369j)
# MCPImpl: num_above=424, num_below=356
# beta_solver, min eigen of left matrix = (0.9458678-0.001239369j)
# MCPImpl: num_above=405, num_below=375
# beta_solver, min eigen of left matrix = (0.9458678-0.001239369j)
# MCPImpl: num_above=424, num_below=356
# beta_solver, min eigen of left matrix = (0.9458678-0.001239369j)
# MCPImpl: num_above=405, num_below=375
# beta_solver, min eigen of left matrix = (0.9458678-0.001239369j)
# MCPImpl: num_above=425, num_below=355
# kmeans center = [[-1.51504448  3.86391259 -2.24575928 -3.6292727   1.51817491 -5.1955652 ]
#  [ 1.45952211 -3.77574293  2.21913631  3.74171748 -1.38644435  5.22667086]] and inertia = 86.05566072386685
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = (0.9478343+0j)
# MCPImpl: num_above=400, num_below=380
# beta_solver, min eigen of left matrix = (0.9478343+0j)
# MCPImpl: num_above=408, num_below=372
# beta_solver, min eigen of left matrix = (0.9478343+0j)
# MCPImpl: num_above=403, num_below=377
# beta_solver, min eigen of left matrix = (0.9478343+0j)
# MCPImpl: num_above=408, num_below=372
# beta_solver, min eigen of left matrix = (0.9478343+0j)
# MCPImpl: num_above=407, num_below=373
# beta_solver, min eigen of left matrix = (0.9478343+0j)
# MCPImpl: num_above=408, num_below=372
# beta_solver, min eigen of left matrix = (0.9478343+0j)
# MCPImpl: num_above=406, num_below=374
# beta_solver, min eigen of left matrix = (0.9478343+0j)
# MCPImpl: num_above=408, num_below=372
# beta_solver, min eigen of left matrix = (0.9478343+0j)
# MCPImpl: num_above=408, num_below=372
# beta_solver, min eigen of left matrix = (0.9478343+0j)
# MCPImpl: num_above=409, num_below=371
# kmeans center = [[-1.57687658  3.62511348 -1.92384717 -4.08776408  1.62173451 -5.07445574]
#  [ 1.63717002 -3.67115727  2.18784576  3.54493435 -1.59714829  5.0916117 ]] and inertia = 74.89678415505736
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = 0.94273424
# MCPImpl: num_above=401, num_below=379
# beta_solver, min eigen of left matrix = 0.94273424
# MCPImpl: num_above=429, num_below=351
# beta_solver, min eigen of left matrix = 0.94273424
# MCPImpl: num_above=404, num_below=376
# beta_solver, min eigen of left matrix = 0.94273424
# MCPImpl: num_above=430, num_below=350
# beta_solver, min eigen of left matrix = 0.94273424
# MCPImpl: num_above=405, num_below=375
# beta_solver, min eigen of left matrix = 0.94273424
# MCPImpl: num_above=430, num_below=350
# beta_solver, min eigen of left matrix = 0.94273424
# MCPImpl: num_above=409, num_below=371
# beta_solver, min eigen of left matrix = 0.94273424
# MCPImpl: num_above=430, num_below=350
# beta_solver, min eigen of left matrix = 0.94273424
# MCPImpl: num_above=407, num_below=373
# beta_solver, min eigen of left matrix = 0.94273424
# MCPImpl: num_above=430, num_below=350
# kmeans center = [[-1.66544328  3.34662907 -2.24186152 -3.91950692  1.73761539 -4.98212601]
#  [ 1.51005856 -3.8992125   2.27901415  3.72092215 -1.55475892  5.1093885 ]] and inertia = 91.41237032049351
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = 0.9429063
# MCPImpl: num_above=400, num_below=380
# beta_solver, min eigen of left matrix = 0.9429063
# MCPImpl: num_above=416, num_below=364
# beta_solver, min eigen of left matrix = 0.9429063
# MCPImpl: num_above=401, num_below=379
# beta_solver, min eigen of left matrix = 0.9429063
# MCPImpl: num_above=416, num_below=364
# beta_solver, min eigen of left matrix = 0.9429063
# MCPImpl: num_above=400, num_below=380
# beta_solver, min eigen of left matrix = 0.9429063
# MCPImpl: num_above=417, num_below=363
# beta_solver, min eigen of left matrix = 0.9429063
# MCPImpl: num_above=401, num_below=379
# beta_solver, min eigen of left matrix = 0.9429063
# MCPImpl: num_above=416, num_below=364
# beta_solver, min eigen of left matrix = 0.9429063
# MCPImpl: num_above=402, num_below=378
# beta_solver, min eigen of left matrix = 0.9429063
# MCPImpl: num_above=416, num_below=364
# kmeans center = [[-1.61980784  4.05279321 -2.15058805 -3.86354361  1.52203807 -4.94231545]
#  [ 1.38968002 -3.98189659  2.06981564  4.07092675 -1.52425496  5.09993255]] and inertia = 77.90574292175462
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = (0.94638556-0.0010816486j)
# MCPImpl: num_above=406, num_below=374
# beta_solver, min eigen of left matrix = (0.94638556-0.0010816486j)
# MCPImpl: num_above=430, num_below=350
# beta_solver, min eigen of left matrix = (0.94638556-0.0010816486j)
# MCPImpl: num_above=410, num_below=370
# beta_solver, min eigen of left matrix = (0.94638556-0.0010816486j)
# MCPImpl: num_above=430, num_below=350
# beta_solver, min eigen of left matrix = (0.94638556-0.0010816486j)
# MCPImpl: num_above=413, num_below=367
# beta_solver, min eigen of left matrix = (0.94638556-0.0010816486j)
# MCPImpl: num_above=430, num_below=350
# beta_solver, min eigen of left matrix = (0.94638556-0.0010816486j)
# MCPImpl: num_above=413, num_below=367
# beta_solver, min eigen of left matrix = (0.94638556-0.0010816486j)
# MCPImpl: num_above=430, num_below=350
# beta_solver, min eigen of left matrix = (0.94638556-0.0010816486j)
# MCPImpl: num_above=415, num_below=365
# beta_solver, min eigen of left matrix = (0.94638556-0.0010816486j)
# MCPImpl: num_above=430, num_below=350
# kmeans center = [[-1.70292638  3.66545975 -1.87881759 -3.57020717  1.67531689 -5.03402724]
#  [ 1.73449978 -3.88711293  2.22710082  3.8506013  -1.65129301  5.35731715]] and inertia = 91.41814327247425
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = 0.94176704
# MCPImpl: num_above=409, num_below=371
# beta_solver, min eigen of left matrix = 0.94176704
# MCPImpl: num_above=439, num_below=341
# beta_solver, min eigen of left matrix = 0.94176704
# MCPImpl: num_above=414, num_below=366
# beta_solver, min eigen of left matrix = 0.94176704
# MCPImpl: num_above=439, num_below=341
# beta_solver, min eigen of left matrix = 0.94176704
# MCPImpl: num_above=415, num_below=365
# beta_solver, min eigen of left matrix = 0.94176704
# MCPImpl: num_above=439, num_below=341
# beta_solver, min eigen of left matrix = 0.94176704
# MCPImpl: num_above=415, num_below=365
# beta_solver, min eigen of left matrix = 0.94176704
# MCPImpl: num_above=438, num_below=342
# beta_solver, min eigen of left matrix = 0.94176704
# MCPImpl: num_above=415, num_below=365
# beta_solver, min eigen of left matrix = 0.94176704
# MCPImpl: num_above=438, num_below=342
# kmeans center = [[-1.33326238  3.80810728 -2.18001146 -3.77817869  1.7070992  -5.09806177]
#  [ 1.3465124  -3.80425278  2.05863902  3.87164334 -1.57762059  4.98543054]] and inertia = 104.52893998133698
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = (0.93208444+0j)
# MCPImpl: num_above=447, num_below=333
# beta_solver, min eigen of left matrix = (0.93208444+0j)
# MCPImpl: num_above=513, num_below=267
# beta_solver, min eigen of left matrix = (0.93208444+0j)
# MCPImpl: num_above=458, num_below=322
# beta_solver, min eigen of left matrix = (0.93208444+0j)
# MCPImpl: num_above=515, num_below=265
# beta_solver, min eigen of left matrix = (0.93208444+0j)
# MCPImpl: num_above=464, num_below=316
# beta_solver, min eigen of left matrix = (0.93208444+0j)
# MCPImpl: num_above=515, num_below=265
# beta_solver, min eigen of left matrix = (0.93208444+0j)
# MCPImpl: num_above=463, num_below=317
# beta_solver, min eigen of left matrix = (0.93208444+0j)
# MCPImpl: num_above=515, num_below=265
# beta_solver, min eigen of left matrix = (0.93208444+0j)
# MCPImpl: num_above=467, num_below=313
# beta_solver, min eigen of left matrix = (0.93208444+0j)
# MCPImpl: num_above=515, num_below=265
# kmeans center = [[-1.41884343  4.01087278 -1.85151641 -3.91967385  1.58424636 -5.10302063]
#  [ 1.52261318 -3.62650004  2.16173436  4.5068785  -1.49704768  5.21280109]] and inertia = 193.539185292291
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = 0.935442
# MCPImpl: num_above=400, num_below=380
# beta_solver, min eigen of left matrix = 0.935442
# MCPImpl: num_above=415, num_below=365
# beta_solver, min eigen of left matrix = 0.935442
# MCPImpl: num_above=404, num_below=376
# beta_solver, min eigen of left matrix = 0.935442
# MCPImpl: num_above=415, num_below=365
# beta_solver, min eigen of left matrix = 0.935442
# MCPImpl: num_above=404, num_below=376
# beta_solver, min eigen of left matrix = 0.935442
# MCPImpl: num_above=415, num_below=365
# beta_solver, min eigen of left matrix = 0.935442
# MCPImpl: num_above=406, num_below=374
# beta_solver, min eigen of left matrix = 0.935442
# MCPImpl: num_above=415, num_below=365
# beta_solver, min eigen of left matrix = 0.935442
# MCPImpl: num_above=406, num_below=374
# beta_solver, min eigen of left matrix = 0.935442
# MCPImpl: num_above=415, num_below=365
# kmeans center = [[-1.48522587  3.63943103 -2.49116293 -3.66439707  1.56502627 -5.51350488]
#  [ 1.59122132 -3.42589272  2.18819978  3.67836644 -1.70558292  5.03451155]] and inertia = 82.54064471207514
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = 0.9392324
# MCPImpl: num_above=416, num_below=364
# beta_solver, min eigen of left matrix = 0.9392324
# MCPImpl: num_above=466, num_below=314
# beta_solver, min eigen of left matrix = 0.9392324
# MCPImpl: num_above=422, num_below=358
# beta_solver, min eigen of left matrix = 0.9392324
# MCPImpl: num_above=467, num_below=313
# beta_solver, min eigen of left matrix = 0.9392324
# MCPImpl: num_above=426, num_below=354
# beta_solver, min eigen of left matrix = 0.9392324
# MCPImpl: num_above=467, num_below=313
# beta_solver, min eigen of left matrix = 0.9392324
# MCPImpl: num_above=424, num_below=356
# beta_solver, min eigen of left matrix = 0.9392324
# MCPImpl: num_above=467, num_below=313
# beta_solver, min eigen of left matrix = 0.9392324
# MCPImpl: num_above=425, num_below=355
# beta_solver, min eigen of left matrix = 0.9392324
# MCPImpl: num_above=467, num_below=313
# kmeans center = [[-1.5866235   3.49543915 -2.19188685 -4.10574328  1.60784715 -5.28459889]
#  [ 1.43786881 -3.74272722  1.89879092  3.98706554 -1.48961393  5.01289727]] and inertia = 120.48718421909444
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = 0.9353993
# MCPImpl: num_above=402, num_below=378
# beta_solver, min eigen of left matrix = 0.9353993
# MCPImpl: num_above=454, num_below=326
# beta_solver, min eigen of left matrix = 0.9353993
# MCPImpl: num_above=412, num_below=368
# beta_solver, min eigen of left matrix = 0.9353993
# MCPImpl: num_above=452, num_below=328
# beta_solver, min eigen of left matrix = 0.9353993
# MCPImpl: num_above=418, num_below=362
# beta_solver, min eigen of left matrix = 0.9353993
# MCPImpl: num_above=453, num_below=327
# beta_solver, min eigen of left matrix = 0.9353993
# MCPImpl: num_above=416, num_below=364
# beta_solver, min eigen of left matrix = 0.9353993
# MCPImpl: num_above=452, num_below=328
# beta_solver, min eigen of left matrix = 0.9353993
# MCPImpl: num_above=418, num_below=362
# beta_solver, min eigen of left matrix = 0.9353993
# MCPImpl: num_above=453, num_below=327
# kmeans center = [[-1.71116801  3.72381828 -2.12374549 -3.64644951  1.3955004  -5.02863201]
#  [ 1.46826414 -3.9110089   2.29841226  3.61514036 -1.47503541  5.04279616]] and inertia = 109.49622642434966
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# new_labels.length=1200 matches number of records
# beta_solver, min eigen of left matrix = (0.9407234+0j)
# MCPImpl: num_above=402, num_below=378
# beta_solver, min eigen of left matrix = (0.9407234+0j)
# MCPImpl: num_above=447, num_below=333
# beta_solver, min eigen of left matrix = (0.9407234+0j)
# MCPImpl: num_above=407, num_below=373
# beta_solver, min eigen of left matrix = (0.9407234+0j)
# MCPImpl: num_above=449, num_below=331
# beta_solver, min eigen of left matrix = (0.9407234+0j)
# MCPImpl: num_above=410, num_below=370
# beta_solver, min eigen of left matrix = (0.9407234+0j)
# MCPImpl: num_above=450, num_below=330
# beta_solver, min eigen of left matrix = (0.9407234+0j)
# MCPImpl: num_above=409, num_below=371
# beta_solver, min eigen of left matrix = (0.9407234+0j)
# MCPImpl: num_above=449, num_below=331
# beta_solver, min eigen of left matrix = (0.9407234+0j)
# MCPImpl: num_above=411, num_below=369
# beta_solver, min eigen of left matrix = (0.9407234+0j)
# MCPImpl: num_above=449, num_below=331
# kmeans center = [[-1.42632384  3.97192811 -2.20683353 -3.93949684  1.5568264  -5.22998609]
#  [ 1.5092912  -3.5972806   2.1815326   3.6498307  -1.60502627  5.17757616]] and inertia = 107.16322547894602
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=1200 matches number of records

# %%
beta_learned_list[0].betas
# Out:
# [array([-1.3389812,  3.8575597, -2.521086 , -3.8335528,  1.555515 ,
#         -5.3094077], dtype=float32),
#  array([ 1.5471345, -3.911604 ,  2.4589884,  3.580307 , -1.401705 ,
#          5.114128 ], dtype=float32)]

# %%
mu_learned_list = []
sigma_learned_list = []
z_score_learned_list = []
mu_ng_list = []
sigma_ng_list = []
z_score_ng_list = []

for beta_learned, beta_ng in zip(beta_learned_list, beta_ng_list):
    v_mus, v_sigmas = compute_V_estimate(u_truth, beta_learned)
    z_score_learned = [
        (mu - truth) / sigma for mu, truth, sigma in zip(v_mus, v_truth, v_sigmas)
    ]
    mu_learned_list.append(v_mus)
    sigma_learned_list.append(v_sigmas)
    z_score_learned_list.append(z_score_learned)

    ngv_mus, ngv_sigmas = compute_V_estimate(u_truth, beta_ng)
    z_score_ng = [
        (mu - truth) / sigma
        for mu, truth, sigma in zip(
            ngv_mus * len(v_truth), v_truth, ngv_sigmas * len(v_truth)
        )
    ]
    mu_ng_list.append(ngv_mus)
    sigma_ng_list.append(ngv_sigmas)
    z_score_ng_list.append(z_score_ng)

# %% [markdown]
# # Reports that average over two groups

# %%
z_score_learned = np.array(z_score_learned_list)
z_score_ng = np.array(z_score_ng_list)
Z_THRESHOLD = 1.96
learned_in_threshold = np.abs(z_score_learned) < Z_THRESHOLD
ng_in_threshold = np.abs(z_score_ng) < Z_THRESHOLD
learned_in_threshold_perc = learned_in_threshold.sum() / learned_in_threshold.size
ng_in_threshold_perc = ng_in_threshold.sum() / ng_in_threshold.size
print(
    "learned_in_threshold_perc=",
    learned_in_threshold_perc,
    ", ng_in_threshold_perc=",
    ng_in_threshold_perc,
)
if SAVE_RESULT:
    with open(RESULT_FILE, "wb") as f:
        pickle.dump(
            dict(
                mu_learned_list=mu_learned_list,
                sigma_learned_list=sigma_learned_list,
                z_score_learned=z_score_learned,
                mu_ng_list=mu_ng_list,
                sigma_ng_list=sigma_ng_list,
                z_score_ng=z_score_ng,
                beta_learned_list=beta_learned_list,
                beta_ng_list=beta_ng_list,
            ),
            f,
        )
# Out:
# learned_in_threshold_perc= 0.98 , ng_in_threshold_perc= 0.0

# %%
ac_acl = 2*Z_THRESHOLD*np.mean(sigma_learned_list)
ac_mse = np.mean( (mu_learned_list - v_truth)**2 )

mv_acl = 2*Z_THRESHOLD*np.mean(sigma_ng_list)
mv_mse = np.mean( (mu_ng_list - v_truth)**2 )

# %%
print("ACPE results: (average over groups)")
print(f"ACL: {ac_acl}") 
print(f"MSE: {ac_mse}")
print(f"ECP: {learned_in_threshold_perc}")


print("MVPE results: (average over groups)")
print(f"ACL: {mv_acl}") 
print(f"MSE: {mv_mse}")
print(f"ECP: {ng_in_threshold_perc}")
# Out:
# ACPE results: (average over groups)
# ACL: 0.6494026877066001
# MSE: 0.020591571927070618
# ECP: 0.98
# MVPE results: (average over groups)
# ACL: 0.991223332284434
# MSE: 12.988564491271973
# ECP: 0.0

# %% [markdown]
# # Reports that seperate two groups

# %%
z_score_learned = np.array(z_score_learned_list)
z_score_ng = np.array(z_score_ng_list)
Z_THRESHOLD = 1.96
learned_in_threshold = np.abs(z_score_learned) < Z_THRESHOLD
ng_in_threshold = np.abs(z_score_ng) < Z_THRESHOLD

learned_in_threshold_perc = np.sum(learned_in_threshold, axis=0) / learned_in_threshold.shape[0]
ng_in_threshold_perc = np.sum(ng_in_threshold, axis=0) / ng_in_threshold.shape[0]

print(
    "learned_in_threshold_perc=",
    learned_in_threshold_perc,
    ", ng_in_threshold_perc=",
    ng_in_threshold_perc,
)

if SAVE_RESULT:
    with open(RESULT_FILE, "wb") as f:
        pickle.dump(
            dict(
                mu_learned_list=mu_learned_list,
                sigma_learned_list=sigma_learned_list,
                z_score_learned=z_score_learned,
                mu_ng_list=mu_ng_list,
                sigma_ng_list=sigma_ng_list,
                z_score_ng=z_score_ng,
                beta_learned_list=beta_learned_list,
                beta_ng_list=beta_ng_list,
            ),
            f,
        )
# Out:
# learned_in_threshold_perc= [0.97 0.99] , ng_in_threshold_perc= [0. 0.]

# %%
ac_acl = 2*Z_THRESHOLD*np.mean(sigma_learned_list, axis=0)
ac_mse = np.mean((mu_learned_list - v_truth)**2, axis=0)

mv_acl = 2*Z_THRESHOLD*np.mean(sigma_ng_list, axis=0)
mv_mse = np.mean( (mu_ng_list - v_truth)**2, axis=0 )

# %%
print("ACPE results: Group1, Group 2")
print(f"MSE: {ac_mse}")
print(f"ACL: {ac_acl}") 
print(f"ECP: {learned_in_threshold_perc}")

print("===")
print("MVPE results: ")
print(f"MSE: {mv_mse}")
print(f"ACL: {mv_acl}") 
print(f"ECP: {ng_in_threshold_perc}")
# Out:
# ACPE results: Group1, Group 2
# MSE: [0.01998241 0.02120073]
# ACL: [0.64936136 0.64944401]
# ECP: [0.97 0.99]
# ===
# MVPE results:
# MSE: [12.82583  13.151297]
# ACL: [0.99122333]
# ECP: [0. 0.]
