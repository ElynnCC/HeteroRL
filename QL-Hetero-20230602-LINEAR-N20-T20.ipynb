# %%
import copy
import pickle
from datetime import datetime as dtdt

import attrs
import numpy as np

from hetero.config import DTYPE, AlgoConfig, DataGenConfig, GroupingConfig
from hetero.datagen import generate_data_from_config
from hetero.policies import AlternativePolicy
from hetero.tasks import (
    beta_estimate_from,
    beta_estimate_from_e2e_learning,
    beta_estimate_from_nongrouped,
    compute_UV_truths,
    compute_V_estimate,
)

group_reward_coeff = np.array(
    [
        [-2.68, 2.68],
        [2.68, -2.68],
    ],
    dtype=DTYPE,
)

action_reward_coeff = [-2.89, 2.89]

data_config_init = dict(
    num_trajectories=20,
    num_time_steps=20,
    group_reward_coeff_override=group_reward_coeff,
    action_reward_coeff=action_reward_coeff,
    num_burnin_steps=100,
    basis_expansion_method="NONE",
    add_intercept_column=True,
)

FEATURE_TYPE = "NONE"

# First time runner: set COMPUTE_TRUTH = True
# Change the flag to False after generated the truth file.
COMPUTE_TRUTH = True # False
# Change the truth file name if settings are changed.
TRUTH_FILE = f"hetero/data/{FEATURE_TYPE}_truth_20230528_2.68_2.89.pkl"
print("truth file name =", TRUTH_FILE)

time_tag = dtdt.now().strftime("%Y%m%d_%H-%M-%S")
tag = f'N={data_config_init["num_trajectories"]}_T={data_config_init["num_time_steps"]}_{time_tag}'
RESULT_FILE = f"hetero/data/{FEATURE_TYPE}_result_20230528_2.68_2.89_{tag}.pkl"
print("result file name =", RESULT_FILE)

SAVE_RESULT = True
if not SAVE_RESULT:
    print("Result will NOT be saved, only use this for experimental runs!!!")

NUM_EXPERIMENTS = 100
# Out:
# truth file name = hetero/data/NONE_truth_20230528_1.68_2.89.pkl
# result file name = hetero/data/NONE_result_20230528_1.68_2.89_N=20_T=20_20230602_11-01-17.pkl

# %% [markdown]
# =====================================================================================================
# # Algorithm
#
# - Set configure below.

# %%
algo_config = AlgoConfig(
    max_num_iters=10,
    gam=2.7,
    lam=1.6,
    rho=2.0,
    should_remove_outlier=True,
    outlier_lower_perc=2,
    outlier_upper_perc=98,
    nu_coeff=1e-5,
    delta_coeff=1e-5,
    use_group_wise_regression_init=True,
)

pi_eval = AlternativePolicy(2)

grouping_config = GroupingConfig()

# %%
if COMPUTE_TRUTH:
    truth_data_config_init = copy.copy(data_config_init)
    truth_data_config_init.pop("num_trajectories")
    us, vs = compute_UV_truths(
        truth_data_config_init,
        algo_config.discount,
        pi_eval,
        num_repeats=10,
        num_trajectories=1000,
    )  # For best results, use num_repeats=10
    u_truth = us.mean(axis=0)
    v_truth = vs.mean(axis=0)

    with open(TRUTH_FILE, "wb") as f:
        pickle.dump(
            dict(
                u_truth=u_truth,
                v_truth=v_truth,
                data_config_dict=truth_data_config_init,
                algo_config_dict=attrs.asdict(algo_config),
            ),
            f,
        )
else:
    with open(TRUTH_FILE, "rb") as f:
        loaded = pickle.load(f)
        u_truth = loaded["u_truth"]
        v_truth = loaded["v_truth"]

# %%
beta_ng_list = []
beta_learned_list = []

for i in range(NUM_EXPERIMENTS):
    data_config = DataGenConfig(seed=7531 * (i + 1), **data_config_init)
    data = generate_data_from_config(data_config)
    beta_ng_list.append(
        beta_estimate_from_nongrouped(data, pi_eval, algo_config.discount)
    )
    beta_learned_list.append(
        beta_estimate_from_e2e_learning(data, algo_config, grouping_config, pi_eval)
    )
# Out:
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = (0.93860525+0j)
# MCPImpl: num_above=460, num_below=320
# beta_solver, min eigen of left matrix = (0.93860525+0j)
# MCPImpl: num_above=555, num_below=225
# beta_solver, min eigen of left matrix = (0.93860525+0j)
# MCPImpl: num_above=475, num_below=305
# beta_solver, min eigen of left matrix = (0.93860525+0j)
# MCPImpl: num_above=554, num_below=226
# beta_solver, min eigen of left matrix = (0.93860525+0j)
# MCPImpl: num_above=479, num_below=301
# beta_solver, min eigen of left matrix = (0.93860525+0j)
# MCPImpl: num_above=558, num_below=222
# beta_solver, min eigen of left matrix = (0.93860525+0j)
# MCPImpl: num_above=485, num_below=295
# beta_solver, min eigen of left matrix = (0.93860525+0j)
# MCPImpl: num_above=558, num_below=222
# beta_solver, min eigen of left matrix = (0.93860525+0j)
# MCPImpl: num_above=483, num_below=297
# beta_solver, min eigen of left matrix = (0.93860525+0j)
# MCPImpl: num_above=557, num_below=223
# kmeans center = [[-1.35812687  4.4564298  -2.1709573  -3.78633964  1.47214896 -5.22268751]
#  [ 1.34699587 -3.74099862  2.49922884  3.63176701 -1.51762963  5.39611625]] and inertia = 227.10288494209792
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = 0.92996776
# MCPImpl: num_above=515, num_below=265
# beta_solver, min eigen of left matrix = 0.92996776
# MCPImpl: num_above=638, num_below=142
# beta_solver, min eigen of left matrix = 0.92996776
# MCPImpl: num_above=534, num_below=246
# beta_solver, min eigen of left matrix = 0.92996776
# MCPImpl: num_above=630, num_below=150
# beta_solver, min eigen of left matrix = 0.92996776
# MCPImpl: num_above=538, num_below=242
# beta_solver, min eigen of left matrix = 0.92996776
# MCPImpl: num_above=632, num_below=148
# beta_solver, min eigen of left matrix = 0.92996776
# MCPImpl: num_above=539, num_below=241
# beta_solver, min eigen of left matrix = 0.92996776
# MCPImpl: num_above=632, num_below=148
# beta_solver, min eigen of left matrix = 0.92996776
# MCPImpl: num_above=539, num_below=241
# beta_solver, min eigen of left matrix = 0.92996776
# MCPImpl: num_above=632, num_below=148
# kmeans center = [[-1.71996203  4.22662451 -1.29967654 -3.66414417  1.51966691 -4.7038606 ]
#  [ 1.66383611 -4.13048351  1.72602193  3.25256873 -1.5006847   5.07938144]] and inertia = 360.38663224568944
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = 0.9456502
# MCPImpl: num_above=466, num_below=314
# beta_solver, min eigen of left matrix = 0.9456502
# MCPImpl: num_above=525, num_below=255
# beta_solver, min eigen of left matrix = 0.9456502
# MCPImpl: num_above=477, num_below=303
# beta_solver, min eigen of left matrix = 0.9456502
# MCPImpl: num_above=528, num_below=252
# beta_solver, min eigen of left matrix = 0.9456502
# MCPImpl: num_above=480, num_below=300
# beta_solver, min eigen of left matrix = 0.9456502
# MCPImpl: num_above=526, num_below=254
# beta_solver, min eigen of left matrix = 0.9456502
# MCPImpl: num_above=478, num_below=302
# beta_solver, min eigen of left matrix = 0.9456502
# MCPImpl: num_above=525, num_below=255
# beta_solver, min eigen of left matrix = 0.9456502
# MCPImpl: num_above=477, num_below=303
# beta_solver, min eigen of left matrix = 0.9456502
# MCPImpl: num_above=526, num_below=254
# kmeans center = [[-1.45263254  3.86655195 -2.19015051 -3.89905406  1.63915604 -5.1150904 ]
#  [ 1.51396077 -3.67058123  1.90500109  3.72217188 -1.37892146  4.7865417 ]] and inertia = 213.24266871939443
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = (0.95646703+0j)
# MCPImpl: num_above=433, num_below=347
# beta_solver, min eigen of left matrix = (0.95646703+0j)
# MCPImpl: num_above=507, num_below=273
# beta_solver, min eigen of left matrix = (0.95646703+0j)
# MCPImpl: num_above=439, num_below=341
# beta_solver, min eigen of left matrix = (0.95646703+0j)
# MCPImpl: num_above=508, num_below=272
# beta_solver, min eigen of left matrix = (0.95646703+0j)
# MCPImpl: num_above=444, num_below=336
# beta_solver, min eigen of left matrix = (0.95646703+0j)
# MCPImpl: num_above=509, num_below=271
# beta_solver, min eigen of left matrix = (0.95646703+0j)
# MCPImpl: num_above=443, num_below=337
# beta_solver, min eigen of left matrix = (0.95646703+0j)
# MCPImpl: num_above=509, num_below=271
# beta_solver, min eigen of left matrix = (0.95646703+0j)
# MCPImpl: num_above=446, num_below=334
# beta_solver, min eigen of left matrix = (0.95646703+0j)
# MCPImpl: num_above=509, num_below=271
# kmeans center = [[-1.57300026  3.76978384 -2.13969802 -3.6925278   1.47369423 -5.04820514]
#  [ 1.51574072 -3.49103729  2.45544261  4.03223483 -1.77433633  5.3175333 ]] and inertia = 158.66097863200997
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = (0.9409654-0.006758022j)
# MCPImpl: num_above=442, num_below=338
# beta_solver, min eigen of left matrix = (0.9409654-0.006758022j)
# MCPImpl: num_above=544, num_below=236
# beta_solver, min eigen of left matrix = (0.9409654-0.006758022j)
# MCPImpl: num_above=461, num_below=319
# beta_solver, min eigen of left matrix = (0.9409654-0.006758022j)
# MCPImpl: num_above=548, num_below=232
# beta_solver, min eigen of left matrix = (0.9409654-0.006758022j)
# MCPImpl: num_above=465, num_below=315
# beta_solver, min eigen of left matrix = (0.9409654-0.006758022j)
# MCPImpl: num_above=543, num_below=237
# beta_solver, min eigen of left matrix = (0.9409654-0.006758022j)
# MCPImpl: num_above=465, num_below=315
# beta_solver, min eigen of left matrix = (0.9409654-0.006758022j)
# MCPImpl: num_above=546, num_below=234
# beta_solver, min eigen of left matrix = (0.9409654-0.006758022j)
# MCPImpl: num_above=468, num_below=312
# beta_solver, min eigen of left matrix = (0.9409654-0.006758022j)
# MCPImpl: num_above=546, num_below=234
# kmeans center = [[-1.34693959  3.85299873 -2.07112572 -3.7647823   1.72309875 -4.99994944]
#  [ 1.57888032 -3.48633991  1.8235808   3.87830435 -1.66916337  5.08542312]] and inertia = 192.9683264197653
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = 0.9440757
# MCPImpl: num_above=462, num_below=318
# beta_solver, min eigen of left matrix = 0.9440757
# MCPImpl: num_above=569, num_below=211
# beta_solver, min eigen of left matrix = 0.9440757
# MCPImpl: num_above=482, num_below=298
# beta_solver, min eigen of left matrix = 0.9440757
# MCPImpl: num_above=573, num_below=207
# beta_solver, min eigen of left matrix = 0.9440757
# MCPImpl: num_above=486, num_below=294
# beta_solver, min eigen of left matrix = 0.9440757
# MCPImpl: num_above=574, num_below=206
# beta_solver, min eigen of left matrix = 0.9440757
# MCPImpl: num_above=487, num_below=293
# beta_solver, min eigen of left matrix = 0.9440757
# MCPImpl: num_above=574, num_below=206
# beta_solver, min eigen of left matrix = 0.9440757
# MCPImpl: num_above=487, num_below=293
# beta_solver, min eigen of left matrix = 0.9440757
# MCPImpl: num_above=574, num_below=206
# kmeans center = [[-1.71281373  3.7858537  -2.00092211 -3.89151321  1.66665171 -5.00542292]
#  [ 1.77833721 -3.73881409  2.25776501  3.91603175 -1.6396541   5.03953305]] and inertia = 226.2675795988091
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = (0.9386925+0j)
# MCPImpl: num_above=433, num_below=347
# beta_solver, min eigen of left matrix = (0.9386925+0j)
# MCPImpl: num_above=532, num_below=248
# beta_solver, min eigen of left matrix = (0.9386925+0j)
# MCPImpl: num_above=447, num_below=333
# beta_solver, min eigen of left matrix = (0.9386925+0j)
# MCPImpl: num_above=529, num_below=251
# beta_solver, min eigen of left matrix = (0.9386925+0j)
# MCPImpl: num_above=454, num_below=326
# beta_solver, min eigen of left matrix = (0.9386925+0j)
# MCPImpl: num_above=532, num_below=248
# beta_solver, min eigen of left matrix = (0.9386925+0j)
# MCPImpl: num_above=455, num_below=325
# beta_solver, min eigen of left matrix = (0.9386925+0j)
# MCPImpl: num_above=531, num_below=249
# beta_solver, min eigen of left matrix = (0.9386925+0j)
# MCPImpl: num_above=453, num_below=327
# beta_solver, min eigen of left matrix = (0.9386925+0j)
# MCPImpl: num_above=530, num_below=250
# kmeans center = [[-2.0358754   4.1755745  -1.85032682 -3.69846283  1.62026552 -5.38579308]
#  [ 1.50930918 -3.44859172  2.48496573  3.79255522 -1.44484964  5.24390853]] and inertia = 174.45410271859566
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = (0.93816674+0j)
# MCPImpl: num_above=477, num_below=303
# beta_solver, min eigen of left matrix = (0.93816674+0j)
# MCPImpl: num_above=580, num_below=200
# beta_solver, min eigen of left matrix = (0.93816674+0j)
# MCPImpl: num_above=503, num_below=277
# beta_solver, min eigen of left matrix = (0.93816674+0j)
# MCPImpl: num_above=579, num_below=201
# beta_solver, min eigen of left matrix = (0.93816674+0j)
# MCPImpl: num_above=512, num_below=268
# beta_solver, min eigen of left matrix = (0.93816674+0j)
# MCPImpl: num_above=578, num_below=202
# beta_solver, min eigen of left matrix = (0.93816674+0j)
# MCPImpl: num_above=509, num_below=271
# beta_solver, min eigen of left matrix = (0.93816674+0j)
# MCPImpl: num_above=578, num_below=202
# beta_solver, min eigen of left matrix = (0.93816674+0j)
# MCPImpl: num_above=512, num_below=268
# beta_solver, min eigen of left matrix = (0.93816674+0j)
# MCPImpl: num_above=578, num_below=202
# kmeans center = [[-1.43584259  3.72894785 -1.85565927 -3.5654543   1.38056812 -4.91587934]
#  [ 1.66387142 -4.26982543  2.0355076   4.11937503 -1.4916646   4.92038972]] and inertia = 266.0599095695149
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = (0.9470041+0j)
# MCPImpl: num_above=416, num_below=364
# beta_solver, min eigen of left matrix = (0.9470041+0j)
# MCPImpl: num_above=486, num_below=294
# beta_solver, min eigen of left matrix = (0.9470041+0j)
# MCPImpl: num_above=429, num_below=351
# beta_solver, min eigen of left matrix = (0.9470041+0j)
# MCPImpl: num_above=484, num_below=296
# beta_solver, min eigen of left matrix = (0.9470041+0j)
# MCPImpl: num_above=432, num_below=348
# beta_solver, min eigen of left matrix = (0.9470041+0j)
# MCPImpl: num_above=484, num_below=296
# beta_solver, min eigen of left matrix = (0.9470041+0j)
# MCPImpl: num_above=432, num_below=348
# beta_solver, min eigen of left matrix = (0.9470041+0j)
# MCPImpl: num_above=484, num_below=296
# beta_solver, min eigen of left matrix = (0.9470041+0j)
# MCPImpl: num_above=434, num_below=346
# beta_solver, min eigen of left matrix = (0.9470041+0j)
# MCPImpl: num_above=484, num_below=296
# kmeans center = [[-1.33144746  3.53544906 -2.57018655 -3.60193469  1.63927989 -5.21878392]
#  [ 1.60512378 -3.64800209  2.10486513  4.00073808 -1.88865549  5.13650498]] and inertia = 142.58748431752832
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = 0.942273
# MCPImpl: num_above=482, num_below=298
# beta_solver, min eigen of left matrix = 0.942273
# MCPImpl: num_above=583, num_below=197
# beta_solver, min eigen of left matrix = 0.942273
# MCPImpl: num_above=503, num_below=277
# beta_solver, min eigen of left matrix = 0.942273
# MCPImpl: num_above=581, num_below=199
# beta_solver, min eigen of left matrix = 0.942273
# MCPImpl: num_above=505, num_below=275
# beta_solver, min eigen of left matrix = 0.942273
# MCPImpl: num_above=580, num_below=200
# beta_solver, min eigen of left matrix = 0.942273
# MCPImpl: num_above=504, num_below=276
# beta_solver, min eigen of left matrix = 0.942273
# MCPImpl: num_above=581, num_below=199
# beta_solver, min eigen of left matrix = 0.942273
# MCPImpl: num_above=507, num_below=273
# beta_solver, min eigen of left matrix = 0.942273
# MCPImpl: num_above=580, num_below=200
# kmeans center = [[-1.31059648  3.99192487 -2.05918699 -4.19672935  1.72223904 -5.20102757]
#  [ 1.56221754 -3.81249456  1.96780759  3.80074038 -1.60145821  5.253501  ]] and inertia = 239.3685127764973
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = (0.9411357+0j)
# MCPImpl: num_above=535, num_below=245
# beta_solver, min eigen of left matrix = (0.9411357+0j)
# MCPImpl: num_above=600, num_below=180
# beta_solver, min eigen of left matrix = (0.9411357+0j)
# MCPImpl: num_above=545, num_below=235
# beta_solver, min eigen of left matrix = (0.9411357+0j)
# MCPImpl: num_above=598, num_below=182
# beta_solver, min eigen of left matrix = (0.9411357+0j)
# MCPImpl: num_above=548, num_below=232
# beta_solver, min eigen of left matrix = (0.9411357+0j)
# MCPImpl: num_above=599, num_below=181
# beta_solver, min eigen of left matrix = (0.9411357+0j)
# MCPImpl: num_above=548, num_below=232
# beta_solver, min eigen of left matrix = (0.9411357+0j)
# MCPImpl: num_above=599, num_below=181
# beta_solver, min eigen of left matrix = (0.9411357+0j)
# MCPImpl: num_above=548, num_below=232
# beta_solver, min eigen of left matrix = (0.9411357+0j)
# MCPImpl: num_above=599, num_below=181
# kmeans center = [[-1.55335048  4.48644755 -1.82486681 -4.07165503  1.49709811 -4.957993  ]
#  [ 1.26373446 -4.21160234  1.80230076  3.62603766 -1.46081869  5.07112739]] and inertia = 340.2404881987703
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = (0.93834645+0j)
# MCPImpl: num_above=500, num_below=280
# beta_solver, min eigen of left matrix = (0.93834645+0j)
# MCPImpl: num_above=602, num_below=178
# beta_solver, min eigen of left matrix = (0.93834645+0j)
# MCPImpl: num_above=532, num_below=248
# beta_solver, min eigen of left matrix = (0.93834645+0j)
# MCPImpl: num_above=600, num_below=180
# beta_solver, min eigen of left matrix = (0.93834645+0j)
# MCPImpl: num_above=537, num_below=243
# beta_solver, min eigen of left matrix = (0.93834645+0j)
# MCPImpl: num_above=599, num_below=181
# beta_solver, min eigen of left matrix = (0.93834645+0j)
# MCPImpl: num_above=536, num_below=244
# beta_solver, min eigen of left matrix = (0.93834645+0j)
# MCPImpl: num_above=599, num_below=181
# beta_solver, min eigen of left matrix = (0.93834645+0j)
# MCPImpl: num_above=535, num_below=245
# beta_solver, min eigen of left matrix = (0.93834645+0j)
# MCPImpl: num_above=600, num_below=180
# kmeans center = [[-1.48460994  4.39178685 -2.29815474 -3.84303803  1.50850274 -5.30967411]
#  [ 1.73999017 -4.11480622  1.93166268  4.11496589 -1.36189376  4.77133938]] and inertia = 301.2233139260773
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = (0.9306005+0j)
# MCPImpl: num_above=465, num_below=315
# beta_solver, min eigen of left matrix = (0.9306005+0j)
# MCPImpl: num_above=550, num_below=230
# beta_solver, min eigen of left matrix = (0.9306005+0j)
# MCPImpl: num_above=484, num_below=296
# beta_solver, min eigen of left matrix = (0.9306005+0j)
# MCPImpl: num_above=548, num_below=232
# beta_solver, min eigen of left matrix = (0.9306005+0j)
# MCPImpl: num_above=486, num_below=294
# beta_solver, min eigen of left matrix = (0.9306005+0j)
# MCPImpl: num_above=547, num_below=233
# beta_solver, min eigen of left matrix = (0.9306005+0j)
# MCPImpl: num_above=492, num_below=288
# beta_solver, min eigen of left matrix = (0.9306005+0j)
# MCPImpl: num_above=548, num_below=232
# beta_solver, min eigen of left matrix = (0.9306005+0j)
# MCPImpl: num_above=489, num_below=291
# beta_solver, min eigen of left matrix = (0.9306005+0j)
# MCPImpl: num_above=547, num_below=233
# kmeans center = [[-1.7636872   3.94582288 -2.10430029 -3.413082    1.56089002 -5.23767376]
#  [ 1.51891405 -3.54491323  2.39928081  3.64454725 -1.48341785  5.27314174]] and inertia = 223.0977887838717
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = (0.9077001+0j)
# MCPImpl: num_above=452, num_below=328
# beta_solver, min eigen of left matrix = (0.9077001+0j)
# MCPImpl: num_above=522, num_below=258
# beta_solver, min eigen of left matrix = (0.9077001+0j)
# MCPImpl: num_above=471, num_below=309
# beta_solver, min eigen of left matrix = (0.9077001+0j)
# MCPImpl: num_above=523, num_below=257
# beta_solver, min eigen of left matrix = (0.9077001+0j)
# MCPImpl: num_above=477, num_below=303
# beta_solver, min eigen of left matrix = (0.9077001+0j)
# MCPImpl: num_above=523, num_below=257
# beta_solver, min eigen of left matrix = (0.9077001+0j)
# MCPImpl: num_above=480, num_below=300
# beta_solver, min eigen of left matrix = (0.9077001+0j)
# MCPImpl: num_above=523, num_below=257
# beta_solver, min eigen of left matrix = (0.9077001+0j)
# MCPImpl: num_above=476, num_below=304
# beta_solver, min eigen of left matrix = (0.9077001+0j)
# MCPImpl: num_above=524, num_below=256
# kmeans center = [[-1.68466755  4.13379773 -2.2474648  -3.91116788  1.57241722 -5.28211031]
#  [ 1.65384956 -3.66948782  1.72396618  3.93928153 -1.57396809  4.79854511]] and inertia = 193.79259157468886
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = (0.9376931+0j)
# MCPImpl: num_above=432, num_below=348
# beta_solver, min eigen of left matrix = (0.9376931+0j)
# MCPImpl: num_above=521, num_below=259
# beta_solver, min eigen of left matrix = (0.9376931+0j)
# MCPImpl: num_above=460, num_below=320
# beta_solver, min eigen of left matrix = (0.9376931+0j)
# MCPImpl: num_above=526, num_below=254
# beta_solver, min eigen of left matrix = (0.9376931+0j)
# MCPImpl: num_above=467, num_below=313
# beta_solver, min eigen of left matrix = (0.9376931+0j)
# MCPImpl: num_above=523, num_below=257
# beta_solver, min eigen of left matrix = (0.9376931+0j)
# MCPImpl: num_above=469, num_below=311
# beta_solver, min eigen of left matrix = (0.9376931+0j)
# MCPImpl: num_above=522, num_below=258
# beta_solver, min eigen of left matrix = (0.9376931+0j)
# MCPImpl: num_above=466, num_below=314
# beta_solver, min eigen of left matrix = (0.9376931+0j)
# MCPImpl: num_above=523, num_below=257
# kmeans center = [[-1.69753475  3.27858804 -2.24800727 -3.62480884  1.77722095 -5.07625676]
#  [ 1.86325826 -3.74617734  2.41906615  3.66566876 -1.66222866  5.35410972]] and inertia = 185.94374086047497
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = (0.9443182-0.0036000672j)
# MCPImpl: num_above=480, num_below=300
# beta_solver, min eigen of left matrix = (0.9443182-0.0036000672j)
# MCPImpl: num_above=564, num_below=216
# beta_solver, min eigen of left matrix = (0.9443182-0.0036000672j)
# MCPImpl: num_above=496, num_below=284
# beta_solver, min eigen of left matrix = (0.9443182-0.0036000672j)
# MCPImpl: num_above=563, num_below=217
# beta_solver, min eigen of left matrix = (0.9443182-0.0036000672j)
# MCPImpl: num_above=503, num_below=277
# beta_solver, min eigen of left matrix = (0.9443182-0.0036000672j)
# MCPImpl: num_above=564, num_below=216
# beta_solver, min eigen of left matrix = (0.9443182-0.0036000672j)
# MCPImpl: num_above=506, num_below=274
# beta_solver, min eigen of left matrix = (0.9443182-0.0036000672j)
# MCPImpl: num_above=563, num_below=217
# beta_solver, min eigen of left matrix = (0.9443182-0.0036000672j)
# MCPImpl: num_above=504, num_below=276
# beta_solver, min eigen of left matrix = (0.9443182-0.0036000672j)
# MCPImpl: num_above=563, num_below=217
# kmeans center = [[-1.51098077  4.2510214  -2.15130052 -3.80537878  1.75499994 -5.10452949]
#  [ 1.15605956 -4.1984912   2.11667516  3.75516209 -1.6186298   4.98008022]] and inertia = 234.93994018344873
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = (0.94291574+0j)
# MCPImpl: num_above=478, num_below=302
# beta_solver, min eigen of left matrix = (0.94291574+0j)
# MCPImpl: num_above=571, num_below=209
# beta_solver, min eigen of left matrix = (0.94291574+0j)
# MCPImpl: num_above=493, num_below=287
# beta_solver, min eigen of left matrix = (0.94291574+0j)
# MCPImpl: num_above=570, num_below=210
# beta_solver, min eigen of left matrix = (0.94291574+0j)
# MCPImpl: num_above=502, num_below=278
# beta_solver, min eigen of left matrix = (0.94291574+0j)
# MCPImpl: num_above=569, num_below=211
# beta_solver, min eigen of left matrix = (0.94291574+0j)
# MCPImpl: num_above=498, num_below=282
# beta_solver, min eigen of left matrix = (0.94291574+0j)
# MCPImpl: num_above=568, num_below=212
# beta_solver, min eigen of left matrix = (0.94291574+0j)
# MCPImpl: num_above=502, num_below=278
# beta_solver, min eigen of left matrix = (0.94291574+0j)
# MCPImpl: num_above=569, num_below=211
# kmeans center = [[-1.53671157  3.8535607  -2.51887162 -3.71782955  1.49669173 -5.30111572]
#  [ 1.4650799  -4.35836129  1.84126836  3.9270594  -1.50470076  4.84133084]] and inertia = 266.94793371630465
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = (0.9449475-0.0011367484j)
# MCPImpl: num_above=442, num_below=338
# beta_solver, min eigen of left matrix = (0.9449475-0.0011367484j)
# MCPImpl: num_above=541, num_below=239
# beta_solver, min eigen of left matrix = (0.9449475-0.0011367484j)
# MCPImpl: num_above=459, num_below=321
# beta_solver, min eigen of left matrix = (0.9449475-0.0011367484j)
# MCPImpl: num_above=539, num_below=241
# beta_solver, min eigen of left matrix = (0.9449475-0.0011367484j)
# MCPImpl: num_above=463, num_below=317
# beta_solver, min eigen of left matrix = (0.9449475-0.0011367484j)
# MCPImpl: num_above=539, num_below=241
# beta_solver, min eigen of left matrix = (0.9449475-0.0011367484j)
# MCPImpl: num_above=464, num_below=316
# beta_solver, min eigen of left matrix = (0.9449475-0.0011367484j)
# MCPImpl: num_above=539, num_below=241
# beta_solver, min eigen of left matrix = (0.9449475-0.0011367484j)
# MCPImpl: num_above=467, num_below=313
# beta_solver, min eigen of left matrix = (0.9449475-0.0011367484j)
# MCPImpl: num_above=539, num_below=241
# kmeans center = [[-1.43727351  3.54233303 -2.10665638 -3.95873345  1.47690808 -4.90212415]
#  [ 1.41556282 -3.99229117  1.85030282  3.73382462 -1.51982517  5.30585804]] and inertia = 186.41503340022314
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = (0.9410065-0.0006797022j)
# MCPImpl: num_above=435, num_below=345
# beta_solver, min eigen of left matrix = (0.9410065-0.0006797022j)
# MCPImpl: num_above=527, num_below=253
# beta_solver, min eigen of left matrix = (0.9410065-0.0006797022j)
# MCPImpl: num_above=457, num_below=323
# beta_solver, min eigen of left matrix = (0.9410065-0.0006797022j)
# MCPImpl: num_above=528, num_below=252
# beta_solver, min eigen of left matrix = (0.9410065-0.0006797022j)
# MCPImpl: num_above=462, num_below=318
# beta_solver, min eigen of left matrix = (0.9410065-0.0006797022j)
# MCPImpl: num_above=527, num_below=253
# beta_solver, min eigen of left matrix = (0.9410065-0.0006797022j)
# MCPImpl: num_above=464, num_below=316
# beta_solver, min eigen of left matrix = (0.9410065-0.0006797022j)
# MCPImpl: num_above=528, num_below=252
# beta_solver, min eigen of left matrix = (0.9410065-0.0006797022j)
# MCPImpl: num_above=465, num_below=315
# beta_solver, min eigen of left matrix = (0.9410065-0.0006797022j)
# MCPImpl: num_above=528, num_below=252
# kmeans center = [[-1.7574388   3.68425817 -1.75004617 -4.00736738  1.5805909  -4.73805651]
#  [ 1.78348551 -3.74360616  2.18416348  3.49530914 -1.53643466  5.13000523]] and inertia = 190.9848175886838
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = (0.94086593+0j)
# MCPImpl: num_above=454, num_below=326
# beta_solver, min eigen of left matrix = (0.94086593+0j)
# MCPImpl: num_above=558, num_below=222
# beta_solver, min eigen of left matrix = (0.94086593+0j)
# MCPImpl: num_above=467, num_below=313
# beta_solver, min eigen of left matrix = (0.94086593+0j)
# MCPImpl: num_above=560, num_below=220
# beta_solver, min eigen of left matrix = (0.94086593+0j)
# MCPImpl: num_above=472, num_below=308
# beta_solver, min eigen of left matrix = (0.94086593+0j)
# MCPImpl: num_above=560, num_below=220
# beta_solver, min eigen of left matrix = (0.94086593+0j)
# MCPImpl: num_above=477, num_below=303
# beta_solver, min eigen of left matrix = (0.94086593+0j)
# MCPImpl: num_above=561, num_below=219
# beta_solver, min eigen of left matrix = (0.94086593+0j)
# MCPImpl: num_above=476, num_below=304
# beta_solver, min eigen of left matrix = (0.94086593+0j)
# MCPImpl: num_above=560, num_below=220
# kmeans center = [[-1.58680974  3.55956505 -2.26218951 -3.38632643  1.55320339 -5.15446844]
#  [ 1.49040327 -4.04777057  1.47522484  3.81418087 -1.3301701   4.76252292]] and inertia = 210.94121077177311
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = 0.9411023
# MCPImpl: num_above=438, num_below=342
# beta_solver, min eigen of left matrix = 0.9411023
# MCPImpl: num_above=530, num_below=250
# beta_solver, min eigen of left matrix = 0.9411023
# MCPImpl: num_above=454, num_below=326
# beta_solver, min eigen of left matrix = 0.9411023
# MCPImpl: num_above=530, num_below=250
# beta_solver, min eigen of left matrix = 0.9411023
# MCPImpl: num_above=458, num_below=322
# beta_solver, min eigen of left matrix = 0.9411023
# MCPImpl: num_above=529, num_below=251
# beta_solver, min eigen of left matrix = 0.9411023
# MCPImpl: num_above=461, num_below=319
# beta_solver, min eigen of left matrix = 0.9411023
# MCPImpl: num_above=529, num_below=251
# beta_solver, min eigen of left matrix = 0.9411023
# MCPImpl: num_above=461, num_below=319
# beta_solver, min eigen of left matrix = 0.9411023
# MCPImpl: num_above=529, num_below=251
# kmeans center = [[-1.68300429  3.60642998 -2.20072507 -3.71414647  1.6237106  -5.19253556]
#  [ 1.81766555 -3.81517523  1.97999655  3.58455448 -1.54843378  5.23846118]] and inertia = 185.83013093702914
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = 0.91153836
# MCPImpl: num_above=495, num_below=285
# beta_solver, min eigen of left matrix = 0.91153836
# MCPImpl: num_above=591, num_below=189
# beta_solver, min eigen of left matrix = 0.91153836
# MCPImpl: num_above=524, num_below=256
# beta_solver, min eigen of left matrix = 0.91153836
# MCPImpl: num_above=594, num_below=186
# beta_solver, min eigen of left matrix = 0.91153836
# MCPImpl: num_above=527, num_below=253
# beta_solver, min eigen of left matrix = 0.91153836
# MCPImpl: num_above=594, num_below=186
# beta_solver, min eigen of left matrix = 0.91153836
# MCPImpl: num_above=527, num_below=253
# beta_solver, min eigen of left matrix = 0.91153836
# MCPImpl: num_above=594, num_below=186
# beta_solver, min eigen of left matrix = 0.91153836
# MCPImpl: num_above=531, num_below=249
# beta_solver, min eigen of left matrix = 0.91153836
# MCPImpl: num_above=594, num_below=186
# kmeans center = [[-1.50736445  3.82475296 -2.0481169  -4.34544     1.52258419 -5.40148772]
#  [ 1.54590551 -3.52491326  1.62473172  4.05659016 -1.54978654  5.26276757]] and inertia = 356.71106840606575
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = (0.9458803-0.0042140414j)
# MCPImpl: num_above=428, num_below=352
# beta_solver, min eigen of left matrix = (0.9458803-0.0042140414j)
# MCPImpl: num_above=514, num_below=266
# beta_solver, min eigen of left matrix = (0.9458803-0.0042140414j)
# MCPImpl: num_above=441, num_below=339
# beta_solver, min eigen of left matrix = (0.9458803-0.0042140414j)
# MCPImpl: num_above=510, num_below=270
# beta_solver, min eigen of left matrix = (0.9458803-0.0042140414j)
# MCPImpl: num_above=444, num_below=336
# beta_solver, min eigen of left matrix = (0.9458803-0.0042140414j)
# MCPImpl: num_above=512, num_below=268
# beta_solver, min eigen of left matrix = (0.9458803-0.0042140414j)
# MCPImpl: num_above=448, num_below=332
# beta_solver, min eigen of left matrix = (0.9458803-0.0042140414j)
# MCPImpl: num_above=512, num_below=268
# beta_solver, min eigen of left matrix = (0.9458803-0.0042140414j)
# MCPImpl: num_above=449, num_below=331
# beta_solver, min eigen of left matrix = (0.9458803-0.0042140414j)
# MCPImpl: num_above=512, num_below=268
# kmeans center = [[-1.6438112   3.39854974 -2.20406053 -3.68603432  1.62038934 -4.96002462]
#  [ 1.71203032 -3.62828847  1.77383537  3.68991299 -1.50297256  4.73008255]] and inertia = 162.34295884807696
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = 0.9361485
# MCPImpl: num_above=429, num_below=351
# beta_solver, min eigen of left matrix = 0.9361485
# MCPImpl: num_above=516, num_below=264
# beta_solver, min eigen of left matrix = 0.9361485
# MCPImpl: num_above=439, num_below=341
# beta_solver, min eigen of left matrix = 0.9361485
# MCPImpl: num_above=513, num_below=267
# beta_solver, min eigen of left matrix = 0.9361485
# MCPImpl: num_above=444, num_below=336
# beta_solver, min eigen of left matrix = 0.9361485
# MCPImpl: num_above=516, num_below=264
# beta_solver, min eigen of left matrix = 0.9361485
# MCPImpl: num_above=448, num_below=332
# beta_solver, min eigen of left matrix = 0.9361485
# MCPImpl: num_above=512, num_below=268
# beta_solver, min eigen of left matrix = 0.9361485
# MCPImpl: num_above=450, num_below=330
# beta_solver, min eigen of left matrix = 0.9361485
# MCPImpl: num_above=514, num_below=266
# kmeans center = [[-1.67723461  4.20497555 -2.67211009 -3.41334712  1.70292041 -5.37125405]
#  [ 1.60564372 -3.57010813  2.22082832  3.57572461 -1.74872711  5.0950541 ]] and inertia = 161.85738706232678
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = (0.94397646+0j)
# MCPImpl: num_above=452, num_below=328
# beta_solver, min eigen of left matrix = (0.94397646+0j)
# MCPImpl: num_above=571, num_below=209
# beta_solver, min eigen of left matrix = (0.94397646+0j)
# MCPImpl: num_above=476, num_below=304
# beta_solver, min eigen of left matrix = (0.94397646+0j)
# MCPImpl: num_above=566, num_below=214
# beta_solver, min eigen of left matrix = (0.94397646+0j)
# MCPImpl: num_above=479, num_below=301
# beta_solver, min eigen of left matrix = (0.94397646+0j)
# MCPImpl: num_above=566, num_below=214
# beta_solver, min eigen of left matrix = (0.94397646+0j)
# MCPImpl: num_above=477, num_below=303
# beta_solver, min eigen of left matrix = (0.94397646+0j)
# MCPImpl: num_above=565, num_below=215
# beta_solver, min eigen of left matrix = (0.94397646+0j)
# MCPImpl: num_above=478, num_below=302
# beta_solver, min eigen of left matrix = (0.94397646+0j)
# MCPImpl: num_above=565, num_below=215
# kmeans center = [[-1.56205965  3.70277958 -1.59383635 -3.75034469  1.80750133 -4.55892147]
#  [ 1.49291686 -3.32347283  2.43575087  3.63504583 -1.72228199  5.19372757]] and inertia = 208.83460600491614
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = 0.93428254
# MCPImpl: num_above=443, num_below=337
# beta_solver, min eigen of left matrix = 0.93428254
# MCPImpl: num_above=522, num_below=258
# beta_solver, min eigen of left matrix = 0.93428254
# MCPImpl: num_above=461, num_below=319
# beta_solver, min eigen of left matrix = 0.93428254
# MCPImpl: num_above=524, num_below=256
# beta_solver, min eigen of left matrix = 0.93428254
# MCPImpl: num_above=464, num_below=316
# beta_solver, min eigen of left matrix = 0.93428254
# MCPImpl: num_above=524, num_below=256
# beta_solver, min eigen of left matrix = 0.93428254
# MCPImpl: num_above=464, num_below=316
# beta_solver, min eigen of left matrix = 0.93428254
# MCPImpl: num_above=524, num_below=256
# beta_solver, min eigen of left matrix = 0.93428254
# MCPImpl: num_above=463, num_below=317
# beta_solver, min eigen of left matrix = 0.93428254
# MCPImpl: num_above=524, num_below=256
# kmeans center = [[-1.72244128  3.40746114 -2.34660755 -3.71316162  1.75290404 -5.3872859 ]
#  [ 1.65697328 -3.9478065   1.99102149  3.63242336 -1.58688987  5.17505225]] and inertia = 186.03789610011899
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = (0.94068336+0j)
# MCPImpl: num_above=472, num_below=308
# beta_solver, min eigen of left matrix = (0.94068336+0j)
# MCPImpl: num_above=552, num_below=228
# beta_solver, min eigen of left matrix = (0.94068336+0j)
# MCPImpl: num_above=490, num_below=290
# beta_solver, min eigen of left matrix = (0.94068336+0j)
# MCPImpl: num_above=547, num_below=233
# beta_solver, min eigen of left matrix = (0.94068336+0j)
# MCPImpl: num_above=492, num_below=288
# beta_solver, min eigen of left matrix = (0.94068336+0j)
# MCPImpl: num_above=546, num_below=234
# beta_solver, min eigen of left matrix = (0.94068336+0j)
# MCPImpl: num_above=493, num_below=287
# beta_solver, min eigen of left matrix = (0.94068336+0j)
# MCPImpl: num_above=548, num_below=232
# beta_solver, min eigen of left matrix = (0.94068336+0j)
# MCPImpl: num_above=491, num_below=289
# beta_solver, min eigen of left matrix = (0.94068336+0j)
# MCPImpl: num_above=546, num_below=234
# kmeans center = [[-1.49532676  4.26440355 -1.44473379 -3.905927    1.27795908 -4.61208863]
#  [ 1.58200713 -3.78223564  2.00228128  3.77419599 -1.76563723  4.90612084]] and inertia = 297.3575188898713
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = (0.94464195+0j)
# MCPImpl: num_above=496, num_below=284
# beta_solver, min eigen of left matrix = (0.94464195+0j)
# MCPImpl: num_above=581, num_below=199
# beta_solver, min eigen of left matrix = (0.94464195+0j)
# MCPImpl: num_above=524, num_below=256
# beta_solver, min eigen of left matrix = (0.94464195+0j)
# MCPImpl: num_above=577, num_below=203
# beta_solver, min eigen of left matrix = (0.94464195+0j)
# MCPImpl: num_above=525, num_below=255
# beta_solver, min eigen of left matrix = (0.94464195+0j)
# MCPImpl: num_above=579, num_below=201
# beta_solver, min eigen of left matrix = (0.94464195+0j)
# MCPImpl: num_above=527, num_below=253
# beta_solver, min eigen of left matrix = (0.94464195+0j)
# MCPImpl: num_above=579, num_below=201
# beta_solver, min eigen of left matrix = (0.94464195+0j)
# MCPImpl: num_above=528, num_below=252
# beta_solver, min eigen of left matrix = (0.94464195+0j)
# MCPImpl: num_above=579, num_below=201
# kmeans center = [[-1.33711513  4.78246735 -2.01613545 -4.04949896  1.37105599 -5.51020811]
#  [ 1.70011047 -3.77157888  1.79622283  4.09390349 -1.42245753  4.87326646]] and inertia = 401.23381770319486
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = (0.9352099+0j)
# MCPImpl: num_above=425, num_below=355
# beta_solver, min eigen of left matrix = (0.9352099+0j)
# MCPImpl: num_above=515, num_below=265
# beta_solver, min eigen of left matrix = (0.9352099+0j)
# MCPImpl: num_above=432, num_below=348
# beta_solver, min eigen of left matrix = (0.9352099+0j)
# MCPImpl: num_above=516, num_below=264
# beta_solver, min eigen of left matrix = (0.9352099+0j)
# MCPImpl: num_above=438, num_below=342
# beta_solver, min eigen of left matrix = (0.9352099+0j)
# MCPImpl: num_above=513, num_below=267
# beta_solver, min eigen of left matrix = (0.9352099+0j)
# MCPImpl: num_above=436, num_below=344
# beta_solver, min eigen of left matrix = (0.9352099+0j)
# MCPImpl: num_above=513, num_below=267
# beta_solver, min eigen of left matrix = (0.9352099+0j)
# MCPImpl: num_above=438, num_below=342
# beta_solver, min eigen of left matrix = (0.9352099+0j)
# MCPImpl: num_above=513, num_below=267
# kmeans center = [[-1.46534094  4.44842804 -1.47452817 -3.86681143  1.46846589 -4.56649277]
#  [ 1.78375233 -3.59298027  2.34478209  3.57402387 -1.5140922   5.2268011 ]] and inertia = 161.38844380556608
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = 0.9456811
# MCPImpl: num_above=436, num_below=344
# beta_solver, min eigen of left matrix = 0.9456811
# MCPImpl: num_above=510, num_below=270
# beta_solver, min eigen of left matrix = 0.9456811
# MCPImpl: num_above=439, num_below=341
# beta_solver, min eigen of left matrix = 0.9456811
# MCPImpl: num_above=511, num_below=269
# beta_solver, min eigen of left matrix = 0.9456811
# MCPImpl: num_above=442, num_below=338
# beta_solver, min eigen of left matrix = 0.9456811
# MCPImpl: num_above=511, num_below=269
# beta_solver, min eigen of left matrix = 0.9456811
# MCPImpl: num_above=442, num_below=338
# beta_solver, min eigen of left matrix = 0.9456811
# MCPImpl: num_above=511, num_below=269
# beta_solver, min eigen of left matrix = 0.9456811
# MCPImpl: num_above=443, num_below=337
# beta_solver, min eigen of left matrix = 0.9456811
# MCPImpl: num_above=510, num_below=270
# kmeans center = [[-1.63652288  3.58296203 -1.81405457 -3.93182363  1.85916957 -4.89174504]
#  [ 1.63003744 -3.63410569  2.15191508  3.99556501 -1.61322015  5.11348732]] and inertia = 170.45368280869064
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = 0.93259
# MCPImpl: num_above=499, num_below=281
# beta_solver, min eigen of left matrix = 0.93259
# MCPImpl: num_above=579, num_below=201
# beta_solver, min eigen of left matrix = 0.93259
# MCPImpl: num_above=519, num_below=261
# beta_solver, min eigen of left matrix = 0.93259
# MCPImpl: num_above=576, num_below=204
# beta_solver, min eigen of left matrix = 0.93259
# MCPImpl: num_above=520, num_below=260
# beta_solver, min eigen of left matrix = 0.93259
# MCPImpl: num_above=576, num_below=204
# beta_solver, min eigen of left matrix = 0.93259
# MCPImpl: num_above=523, num_below=257
# beta_solver, min eigen of left matrix = 0.93259
# MCPImpl: num_above=576, num_below=204
# beta_solver, min eigen of left matrix = 0.93259
# MCPImpl: num_above=523, num_below=257
# beta_solver, min eigen of left matrix = 0.93259
# MCPImpl: num_above=576, num_below=204
# kmeans center = [[-1.54036913  3.81541132 -2.41753462 -3.13867276  1.79037107 -4.99420078]
#  [ 1.44793395 -3.66313477  1.792185    3.89851388 -1.51126746  4.64698497]] and inertia = 356.10722802883686
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = 0.9374779
# MCPImpl: num_above=462, num_below=318
# beta_solver, min eigen of left matrix = 0.9374779
# MCPImpl: num_above=538, num_below=242
# beta_solver, min eigen of left matrix = 0.9374779
# MCPImpl: num_above=487, num_below=293
# beta_solver, min eigen of left matrix = 0.9374779
# MCPImpl: num_above=537, num_below=243
# beta_solver, min eigen of left matrix = 0.9374779
# MCPImpl: num_above=491, num_below=289
# beta_solver, min eigen of left matrix = 0.9374779
# MCPImpl: num_above=535, num_below=245
# beta_solver, min eigen of left matrix = 0.9374779
# MCPImpl: num_above=492, num_below=288
# beta_solver, min eigen of left matrix = 0.9374779
# MCPImpl: num_above=536, num_below=244
# beta_solver, min eigen of left matrix = 0.9374779
# MCPImpl: num_above=493, num_below=287
# beta_solver, min eigen of left matrix = 0.9374779
# MCPImpl: num_above=536, num_below=244
# kmeans center = [[-1.31999855  3.88001028 -2.19390679 -4.02529765  1.55594188 -5.38565215]
#  [ 1.4838259  -3.43617896  2.13373362  3.74667622 -1.71465786  5.09563879]] and inertia = 209.83422092128671
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = 0.93532014
# MCPImpl: num_above=456, num_below=324
# beta_solver, min eigen of left matrix = 0.93532014
# MCPImpl: num_above=560, num_below=220
# beta_solver, min eigen of left matrix = 0.93532014
# MCPImpl: num_above=469, num_below=311
# beta_solver, min eigen of left matrix = 0.93532014
# MCPImpl: num_above=556, num_below=224
# beta_solver, min eigen of left matrix = 0.93532014
# MCPImpl: num_above=475, num_below=305
# beta_solver, min eigen of left matrix = 0.93532014
# MCPImpl: num_above=558, num_below=222
# beta_solver, min eigen of left matrix = 0.93532014
# MCPImpl: num_above=487, num_below=293
# beta_solver, min eigen of left matrix = 0.93532014
# MCPImpl: num_above=571, num_below=209
# beta_solver, min eigen of left matrix = 0.93532014
# MCPImpl: num_above=494, num_below=286
# beta_solver, min eigen of left matrix = 0.93532014
# MCPImpl: num_above=581, num_below=199
# kmeans center = [[-1.49073128  3.54871023 -2.3517366  -4.16757901  1.72477863 -4.86899686]
#  [ 1.94331455 -4.06511577  1.84573508  4.25553938 -1.45068642  5.16847707]] and inertia = 437.8817101035595
# Label mismatch = 1
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = (0.9164378+0j)
# MCPImpl: num_above=409, num_below=371
# beta_solver, min eigen of left matrix = (0.9164378+0j)
# MCPImpl: num_above=472, num_below=308
# beta_solver, min eigen of left matrix = (0.9164378+0j)
# MCPImpl: num_above=420, num_below=360
# beta_solver, min eigen of left matrix = (0.9164378+0j)
# MCPImpl: num_above=473, num_below=307
# beta_solver, min eigen of left matrix = (0.9164378+0j)
# MCPImpl: num_above=422, num_below=358
# beta_solver, min eigen of left matrix = (0.9164378+0j)
# MCPImpl: num_above=474, num_below=306
# beta_solver, min eigen of left matrix = (0.9164378+0j)
# MCPImpl: num_above=425, num_below=355
# beta_solver, min eigen of left matrix = (0.9164378+0j)
# MCPImpl: num_above=475, num_below=305
# beta_solver, min eigen of left matrix = (0.9164378+0j)
# MCPImpl: num_above=426, num_below=354
# beta_solver, min eigen of left matrix = (0.9164378+0j)
# MCPImpl: num_above=475, num_below=305
# kmeans center = [[-1.43088043  3.62996267 -1.94455531 -3.88936876  1.37952016 -5.03609006]
#  [ 1.58982815 -3.54842006  1.89813338  3.47210795 -1.55520321  4.71860052]] and inertia = 128.6775458597274
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = (0.94642526+0j)
# MCPImpl: num_above=455, num_below=325
# beta_solver, min eigen of left matrix = (0.94642526+0j)
# MCPImpl: num_above=566, num_below=214
# beta_solver, min eigen of left matrix = (0.94642526+0j)
# MCPImpl: num_above=474, num_below=306
# beta_solver, min eigen of left matrix = (0.94642526+0j)
# MCPImpl: num_above=560, num_below=220
# beta_solver, min eigen of left matrix = (0.94642526+0j)
# MCPImpl: num_above=474, num_below=306
# beta_solver, min eigen of left matrix = (0.94642526+0j)
# MCPImpl: num_above=559, num_below=221
# beta_solver, min eigen of left matrix = (0.94642526+0j)
# MCPImpl: num_above=476, num_below=304
# beta_solver, min eigen of left matrix = (0.94642526+0j)
# MCPImpl: num_above=559, num_below=221
# beta_solver, min eigen of left matrix = (0.94642526+0j)
# MCPImpl: num_above=474, num_below=306
# beta_solver, min eigen of left matrix = (0.94642526+0j)
# MCPImpl: num_above=559, num_below=221
# kmeans center = [[-1.37383935  3.91883539 -2.59882571 -3.9164888   1.89948657 -5.56280573]
#  [ 1.47716849 -3.34195125  2.15165469  4.04304238 -1.87157007  5.2944496 ]] and inertia = 203.1969560418776
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = (0.94989246+0j)
# MCPImpl: num_above=453, num_below=327
# beta_solver, min eigen of left matrix = (0.94989246+0j)
# MCPImpl: num_above=552, num_below=228
# beta_solver, min eigen of left matrix = (0.94989246+0j)
# MCPImpl: num_above=464, num_below=316
# beta_solver, min eigen of left matrix = (0.94989246+0j)
# MCPImpl: num_above=556, num_below=224
# beta_solver, min eigen of left matrix = (0.94989246+0j)
# MCPImpl: num_above=471, num_below=309
# beta_solver, min eigen of left matrix = (0.94989246+0j)
# MCPImpl: num_above=555, num_below=225
# beta_solver, min eigen of left matrix = (0.94989246+0j)
# MCPImpl: num_above=472, num_below=308
# beta_solver, min eigen of left matrix = (0.94989246+0j)
# MCPImpl: num_above=555, num_below=225
# beta_solver, min eigen of left matrix = (0.94989246+0j)
# MCPImpl: num_above=473, num_below=307
# beta_solver, min eigen of left matrix = (0.94989246+0j)
# MCPImpl: num_above=555, num_below=225
# ...
# MCPImpl: num_above=438, num_below=342
# beta_solver, min eigen of left matrix = (0.9439122+0j)
# MCPImpl: num_above=520, num_below=260
# beta_solver, min eigen of left matrix = (0.9439122+0j)
# MCPImpl: num_above=455, num_below=325
# beta_solver, min eigen of left matrix = (0.9439122+0j)
# MCPImpl: num_above=518, num_below=262
# beta_solver, min eigen of left matrix = (0.9439122+0j)
# MCPImpl: num_above=466, num_below=314
# beta_solver, min eigen of left matrix = (0.9439122+0j)
# MCPImpl: num_above=520, num_below=260
# beta_solver, min eigen of left matrix = (0.9439122+0j)
# MCPImpl: num_above=468, num_below=312
# beta_solver, min eigen of left matrix = (0.9439122+0j)
# MCPImpl: num_above=525, num_below=255
# beta_solver, min eigen of left matrix = (0.9439122+0j)
# MCPImpl: num_above=474, num_below=306
# beta_solver, min eigen of left matrix = (0.9439122+0j)
# MCPImpl: num_above=528, num_below=252
# kmeans center = [[-1.72191032  4.35114625 -1.81850063 -3.55835915  1.42459004 -4.71927665]
#  [ 1.10219215 -3.24966624  1.9098904   3.64623458 -1.4518702   4.9189262 ]] and inertia = 213.52569054684562
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = (0.9303064+0j)
# MCPImpl: num_above=453, num_below=327
# beta_solver, min eigen of left matrix = (0.9303064+0j)
# MCPImpl: num_above=555, num_below=225
# beta_solver, min eigen of left matrix = (0.9303064+0j)
# MCPImpl: num_above=472, num_below=308
# beta_solver, min eigen of left matrix = (0.9303064+0j)
# MCPImpl: num_above=564, num_below=216
# beta_solver, min eigen of left matrix = (0.9303064+0j)
# MCPImpl: num_above=480, num_below=300
# beta_solver, min eigen of left matrix = (0.9303064+0j)
# MCPImpl: num_above=565, num_below=215
# beta_solver, min eigen of left matrix = (0.9303064+0j)
# MCPImpl: num_above=484, num_below=296
# beta_solver, min eigen of left matrix = (0.9303064+0j)
# MCPImpl: num_above=564, num_below=216
# beta_solver, min eigen of left matrix = (0.9303064+0j)
# MCPImpl: num_above=487, num_below=293
# beta_solver, min eigen of left matrix = (0.9303064+0j)
# MCPImpl: num_above=564, num_below=216
# kmeans center = [[-1.75758737  3.22374081 -2.2315413  -3.72978842  1.66476354 -5.05990622]
#  [ 1.67973402 -3.30324293  1.9826599   3.96096737 -1.54972483  5.32410794]] and inertia = 233.21768511834614
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = (0.94709396-0.004296325j)
# MCPImpl: num_above=470, num_below=310
# beta_solver, min eigen of left matrix = (0.94709396-0.004296325j)
# MCPImpl: num_above=562, num_below=218
# beta_solver, min eigen of left matrix = (0.94709396-0.004296325j)
# MCPImpl: num_above=490, num_below=290
# beta_solver, min eigen of left matrix = (0.94709396-0.004296325j)
# MCPImpl: num_above=561, num_below=219
# beta_solver, min eigen of left matrix = (0.94709396-0.004296325j)
# MCPImpl: num_above=494, num_below=286
# beta_solver, min eigen of left matrix = (0.94709396-0.004296325j)
# MCPImpl: num_above=561, num_below=219
# beta_solver, min eigen of left matrix = (0.94709396-0.004296325j)
# MCPImpl: num_above=493, num_below=287
# beta_solver, min eigen of left matrix = (0.94709396-0.004296325j)
# MCPImpl: num_above=561, num_below=219
# beta_solver, min eigen of left matrix = (0.94709396-0.004296325j)
# MCPImpl: num_above=494, num_below=286
# beta_solver, min eigen of left matrix = (0.94709396-0.004296325j)
# MCPImpl: num_above=561, num_below=219
# kmeans center = [[-1.6813083   3.86745908 -2.43204545 -4.08219315  1.66583979 -5.38606299]
#  [ 1.52600778 -4.14329465  1.62684107  3.65225195 -1.64647436  4.59605205]] and inertia = 274.26063822510247
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = (0.94991314-0.003865603j)
# MCPImpl: num_above=440, num_below=340
# beta_solver, min eigen of left matrix = (0.94991314-0.003865603j)
# MCPImpl: num_above=510, num_below=270
# beta_solver, min eigen of left matrix = (0.94991314-0.003865603j)
# MCPImpl: num_above=458, num_below=322
# beta_solver, min eigen of left matrix = (0.94991314-0.003865603j)
# MCPImpl: num_above=508, num_below=272
# beta_solver, min eigen of left matrix = (0.94991314-0.003865603j)
# MCPImpl: num_above=465, num_below=315
# beta_solver, min eigen of left matrix = (0.94991314-0.003865603j)
# MCPImpl: num_above=507, num_below=273
# beta_solver, min eigen of left matrix = (0.94991314-0.003865603j)
# MCPImpl: num_above=466, num_below=314
# beta_solver, min eigen of left matrix = (0.94991314-0.003865603j)
# MCPImpl: num_above=507, num_below=273
# beta_solver, min eigen of left matrix = (0.94991314-0.003865603j)
# MCPImpl: num_above=465, num_below=315
# beta_solver, min eigen of left matrix = (0.94991314-0.003865603j)
# MCPImpl: num_above=507, num_below=273
# kmeans center = [[-1.55413272  3.65211535 -2.34448185 -3.69572326  1.48117075 -4.92799244]
#  [ 1.71451528 -3.82319117  2.28972579  4.03203672 -1.74541756  5.33245108]] and inertia = 180.2922536709779
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = 0.93783987
# MCPImpl: num_above=468, num_below=312
# beta_solver, min eigen of left matrix = 0.93783987
# MCPImpl: num_above=566, num_below=214
# beta_solver, min eigen of left matrix = 0.93783987
# MCPImpl: num_above=497, num_below=283
# beta_solver, min eigen of left matrix = 0.93783987
# MCPImpl: num_above=559, num_below=221
# beta_solver, min eigen of left matrix = 0.93783987
# MCPImpl: num_above=500, num_below=280
# beta_solver, min eigen of left matrix = 0.93783987
# MCPImpl: num_above=559, num_below=221
# beta_solver, min eigen of left matrix = 0.93783987
# MCPImpl: num_above=499, num_below=281
# beta_solver, min eigen of left matrix = 0.93783987
# MCPImpl: num_above=558, num_below=222
# beta_solver, min eigen of left matrix = 0.93783987
# MCPImpl: num_above=500, num_below=280
# beta_solver, min eigen of left matrix = 0.93783987
# MCPImpl: num_above=558, num_below=222
# kmeans center = [[-1.5846678   4.13866173 -1.95370086 -4.26556458  1.5962576  -5.12668956]
#  [ 1.83887097 -4.06053093  2.07393847  4.20390949 -1.34632143  5.13589292]] and inertia = 224.50502300650243
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = (0.9351534+0j)
# MCPImpl: num_above=455, num_below=325
# beta_solver, min eigen of left matrix = (0.9351534+0j)
# MCPImpl: num_above=566, num_below=214
# beta_solver, min eigen of left matrix = (0.9351534+0j)
# MCPImpl: num_above=473, num_below=307
# beta_solver, min eigen of left matrix = (0.9351534+0j)
# MCPImpl: num_above=563, num_below=217
# beta_solver, min eigen of left matrix = (0.9351534+0j)
# MCPImpl: num_above=477, num_below=303
# beta_solver, min eigen of left matrix = (0.9351534+0j)
# MCPImpl: num_above=563, num_below=217
# beta_solver, min eigen of left matrix = (0.9351534+0j)
# MCPImpl: num_above=480, num_below=300
# beta_solver, min eigen of left matrix = (0.9351534+0j)
# MCPImpl: num_above=561, num_below=219
# beta_solver, min eigen of left matrix = (0.9351534+0j)
# MCPImpl: num_above=480, num_below=300
# beta_solver, min eigen of left matrix = (0.9351534+0j)
# MCPImpl: num_above=561, num_below=219
# kmeans center = [[-1.51468873  3.78647175 -1.80657111 -3.95439464  1.46381997 -4.95888245]
#  [ 1.78693139 -3.87155666  2.13593483  3.78853041 -1.6687549   5.12538345]] and inertia = 272.1628463239727
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = 0.9257352
# MCPImpl: num_above=495, num_below=285
# beta_solver, min eigen of left matrix = 0.9257352
# MCPImpl: num_above=610, num_below=170
# beta_solver, min eigen of left matrix = 0.9257352
# MCPImpl: num_above=520, num_below=260
# beta_solver, min eigen of left matrix = 0.9257352
# MCPImpl: num_above=605, num_below=175
# beta_solver, min eigen of left matrix = 0.9257352
# MCPImpl: num_above=529, num_below=251
# beta_solver, min eigen of left matrix = 0.9257352
# MCPImpl: num_above=603, num_below=177
# beta_solver, min eigen of left matrix = 0.9257352
# MCPImpl: num_above=529, num_below=251
# beta_solver, min eigen of left matrix = 0.9257352
# MCPImpl: num_above=601, num_below=179
# beta_solver, min eigen of left matrix = 0.9257352
# MCPImpl: num_above=529, num_below=251
# beta_solver, min eigen of left matrix = 0.9257352
# MCPImpl: num_above=601, num_below=179
# kmeans center = [[-1.71127725  3.37878141 -2.65011683 -3.68807948  1.90181591 -5.65956113]
#  [ 1.64411067 -3.67050529  1.97507815  4.10509107 -1.90410865  5.14583818]] and inertia = 295.2740558727107
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = (0.937416+0j)
# MCPImpl: num_above=454, num_below=326
# beta_solver, min eigen of left matrix = (0.937416+0j)
# MCPImpl: num_above=555, num_below=225
# beta_solver, min eigen of left matrix = (0.937416+0j)
# MCPImpl: num_above=477, num_below=303
# beta_solver, min eigen of left matrix = (0.937416+0j)
# MCPImpl: num_above=549, num_below=231
# beta_solver, min eigen of left matrix = (0.937416+0j)
# MCPImpl: num_above=479, num_below=301
# beta_solver, min eigen of left matrix = (0.937416+0j)
# MCPImpl: num_above=550, num_below=230
# beta_solver, min eigen of left matrix = (0.937416+0j)
# MCPImpl: num_above=481, num_below=299
# beta_solver, min eigen of left matrix = (0.937416+0j)
# MCPImpl: num_above=550, num_below=230
# beta_solver, min eigen of left matrix = (0.937416+0j)
# MCPImpl: num_above=481, num_below=299
# beta_solver, min eigen of left matrix = (0.937416+0j)
# MCPImpl: num_above=550, num_below=230
# kmeans center = [[-1.60995267  3.52027208 -2.03971176 -3.61779664  1.67990897 -5.19401004]
#  [ 1.82057515 -3.74032232  2.10619897  3.77427425 -1.62687795  4.81304636]] and inertia = 210.7352551761818
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = (0.93687075+0j)
# MCPImpl: num_above=460, num_below=320
# beta_solver, min eigen of left matrix = (0.93687075+0j)
# MCPImpl: num_above=579, num_below=201
# beta_solver, min eigen of left matrix = (0.93687075+0j)
# MCPImpl: num_above=498, num_below=282
# beta_solver, min eigen of left matrix = (0.93687075+0j)
# MCPImpl: num_above=576, num_below=204
# beta_solver, min eigen of left matrix = (0.93687075+0j)
# MCPImpl: num_above=505, num_below=275
# beta_solver, min eigen of left matrix = (0.93687075+0j)
# MCPImpl: num_above=580, num_below=200
# beta_solver, min eigen of left matrix = (0.93687075+0j)
# MCPImpl: num_above=507, num_below=273
# beta_solver, min eigen of left matrix = (0.93687075+0j)
# MCPImpl: num_above=579, num_below=201
# beta_solver, min eigen of left matrix = (0.93687075+0j)
# MCPImpl: num_above=509, num_below=271
# beta_solver, min eigen of left matrix = (0.93687075+0j)
# MCPImpl: num_above=579, num_below=201
# kmeans center = [[-1.47126721  3.73746245 -2.35943101 -3.97120788  1.70850966 -4.83093583]
#  [ 1.68934089 -3.39625683  2.06217669  4.06149252 -1.36770018  5.06857069]] and inertia = 257.0443392282142
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = 0.9405586
# MCPImpl: num_above=449, num_below=331
# beta_solver, min eigen of left matrix = 0.9405586
# MCPImpl: num_above=540, num_below=240
# beta_solver, min eigen of left matrix = 0.9405586
# MCPImpl: num_above=472, num_below=308
# beta_solver, min eigen of left matrix = 0.9405586
# MCPImpl: num_above=537, num_below=243
# beta_solver, min eigen of left matrix = 0.9405586
# MCPImpl: num_above=476, num_below=304
# beta_solver, min eigen of left matrix = 0.9405586
# MCPImpl: num_above=539, num_below=241
# beta_solver, min eigen of left matrix = 0.9405586
# MCPImpl: num_above=476, num_below=304
# beta_solver, min eigen of left matrix = 0.9405586
# MCPImpl: num_above=538, num_below=242
# beta_solver, min eigen of left matrix = 0.9405586
# MCPImpl: num_above=480, num_below=300
# beta_solver, min eigen of left matrix = 0.9405586
# MCPImpl: num_above=539, num_below=241
# kmeans center = [[-1.53083945  3.48708928 -1.62728444 -3.9996207   1.68705919 -4.88397519]
#  [ 1.75269867 -4.08477476  2.01290516  3.84837483 -1.53184019  4.97520526]] and inertia = 207.74383435351714
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = 0.94044805
# MCPImpl: num_above=471, num_below=309
# beta_solver, min eigen of left matrix = 0.94044805
# MCPImpl: num_above=589, num_below=191
# beta_solver, min eigen of left matrix = 0.94044805
# MCPImpl: num_above=494, num_below=286
# beta_solver, min eigen of left matrix = 0.94044805
# MCPImpl: num_above=586, num_below=194
# beta_solver, min eigen of left matrix = 0.94044805
# MCPImpl: num_above=500, num_below=280
# beta_solver, min eigen of left matrix = 0.94044805
# MCPImpl: num_above=585, num_below=195
# beta_solver, min eigen of left matrix = 0.94044805
# MCPImpl: num_above=500, num_below=280
# beta_solver, min eigen of left matrix = 0.94044805
# MCPImpl: num_above=586, num_below=194
# beta_solver, min eigen of left matrix = 0.94044805
# MCPImpl: num_above=498, num_below=282
# beta_solver, min eigen of left matrix = 0.94044805
# MCPImpl: num_above=586, num_below=194
# kmeans center = [[-1.28785126  4.21357783 -1.9695371  -3.87475365  1.79316078 -5.05204785]
#  [ 1.05679302 -4.02242069  2.22162889  3.57242596 -1.13662794  5.17954208]] and inertia = 264.26358382222213
# Label mismatch = 0
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# new_labels.length=800 matches number of records
# beta_solver, min eigen of left matrix = (0.8951819+0j)
# MCPImpl: num_above=462, num_below=318
# beta_solver, min eigen of left matrix = (0.8951819+0j)
# MCPImpl: num_above=547, num_below=233
# beta_solver, min eigen of left matrix = (0.8951819+0j)
# MCPImpl: num_above=484, num_below=296
# beta_solver, min eigen of left matrix = (0.8951819+0j)
# MCPImpl: num_above=547, num_below=233
# beta_solver, min eigen of left matrix = (0.8951819+0j)
# MCPImpl: num_above=499, num_below=281
# beta_solver, min eigen of left matrix = (0.8951819+0j)
# MCPImpl: num_above=550, num_below=230
# beta_solver, min eigen of left matrix = (0.8951819+0j)
# MCPImpl: num_above=503, num_below=277
# beta_solver, min eigen of left matrix = (0.8951819+0j)
# MCPImpl: num_above=551, num_below=229
# beta_solver, min eigen of left matrix = (0.8951819+0j)
# MCPImpl: num_above=502, num_below=278
# beta_solver, min eigen of left matrix = (0.8951819+0j)
# MCPImpl: num_above=553, num_below=227
# kmeans center = [[-1.37406175  3.58848315 -2.17208394 -3.72632009  1.75354347 -5.23196891]
#  [ 2.45785277 -2.37584755  3.24669031  3.29080177 -2.43074789  5.50182905]] and inertia = 1625.3012069635352
# Label mismatch = 1
# new_labels.length=40 matches num_unique_labels
# new_labels.length=800 matches number of records

# %%
beta_learned_list[0].betas
# Out:
# [array([-1.4556423,  4.090999 , -2.28717  , -4.066601 ,  1.411059 ,
#         -5.2927995], dtype=float32),
#  array([ 1.2268863, -3.8711095,  2.4759016,  3.9264438, -1.504575 ,
#          5.364038 ], dtype=float32)]

# %%
mu_learned_list = []
sigma_learned_list = []
z_score_learned_list = []
mu_ng_list = []
sigma_ng_list = []
z_score_ng_list = []

for beta_learned, beta_ng in zip(beta_learned_list, beta_ng_list):
    v_mus, v_sigmas = compute_V_estimate(u_truth, beta_learned)
    z_score_learned = [
        (mu - truth) / sigma for mu, truth, sigma in zip(v_mus, v_truth, v_sigmas)
    ]
    mu_learned_list.append(v_mus)
    sigma_learned_list.append(v_sigmas)
    z_score_learned_list.append(z_score_learned)

    ngv_mus, ngv_sigmas = compute_V_estimate(u_truth, beta_ng)
    z_score_ng = [
        (mu - truth) / sigma
        for mu, truth, sigma in zip(
            ngv_mus * len(v_truth), v_truth, ngv_sigmas * len(v_truth)
        )
    ]
    mu_ng_list.append(ngv_mus)
    sigma_ng_list.append(ngv_sigmas)
    z_score_ng_list.append(z_score_ng)

# %% [markdown]
# # Reports that average over two groups

# %%
z_score_learned = np.array(z_score_learned_list)
z_score_ng = np.array(z_score_ng_list)
Z_THRESHOLD = 1.96
learned_in_threshold = np.abs(z_score_learned) < Z_THRESHOLD
ng_in_threshold = np.abs(z_score_ng) < Z_THRESHOLD
learned_in_threshold_perc = leanred_in_threshold.sum() / leanred_in_threshold.size
ng_in_threshold_perc = ng_in_threshold.sum() / ng_in_threshold.size
print(
    "learned_in_threshold_perc=",
    learned_in_threshold_perc,
    ", ng_in_threshold_perc=",
    ng_in_threshold_perc,
)
if SAVE_RESULT:
    with open(RESULT_FILE, "wb") as f:
        pickle.dump(
            dict(
                mu_learned_list=mu_learned_list,
                sigma_learned_list=sigma_learned_list,
                z_score_learned=z_score_learned,
                mu_ng_list=mu_ng_list,
                sigma_ng_list=sigma_ng_list,
                z_score_ng=z_score_ng,
                beta_learned_list=beta_learned_list,
                beta_ng_list=beta_ng_list,
            ),
            f,
        )
# Out:
# learned_in_threshold_perc= 0.97 , ng_in_threshold_perc= 0.0

# %%
ac_acl = 2*Z_THRESHOLD*np.mean(sigma_learned_list)
ac_mse = np.mean( (mu_learned_list - v_truth)**2 )

mv_acl = 2*Z_THRESHOLD*np.mean(sigma_ng_list)
mv_mse = np.mean( (mu_ng_list - v_truth)**2 )

# %%
print("ACPE results: (average over groups)")
print(f"ACL: {ac_acl}") 
print(f"MSE: {ac_mse}")
print(f"ECP: {learned_in_threshold_perc}")


print("MVPE results: (average over groups)")
print(f"ACL: {mv_acl}") 
print(f"MSE: {mv_mse}")
print(f"ECP: {ng_in_threshold_perc}")
# Out:
# ACPE results:
# ACL: 0.8017043736565425
# MSE: 0.0373266376554966
# ECP: 0.97
# MVPE results:
# ACL: 1.219222704607102
# MSE: 13.000341415405273
# ECP: 0.0

# %% [markdown]
# # Reports that seperate two groups

# %%
z_score_learned = np.array(z_score_learned_list)
z_score_ng = np.array(z_score_ng_list)
Z_THRESHOLD = 1.96
learned_in_threshold = np.abs(z_score_learned) < Z_THRESHOLD
ng_in_threshold = np.abs(z_score_ng) < Z_THRESHOLD

learned_in_threshold_perc = np.sum(learned_in_threshold, axis=0) / learned_in_threshold.shape[0]
ng_in_threshold_perc = np.sum(ng_in_threshold, axis=0) / ng_in_threshold.shape[0]

print(
    "learned_in_threshold_perc=",
    learned_in_threshold_perc,
    ", ng_in_threshold_perc=",
    ng_in_threshold_perc,
)

if SAVE_RESULT:
    with open(RESULT_FILE, "wb") as f:
        pickle.dump(
            dict(
                mu_learned_list=mu_learned_list,
                sigma_learned_list=sigma_learned_list,
                z_score_learned=z_score_learned,
                mu_ng_list=mu_ng_list,
                sigma_ng_list=sigma_ng_list,
                z_score_ng=z_score_ng,
                beta_learned_list=beta_learned_list,
                beta_ng_list=beta_ng_list,
            ),
            f,
        )
# Out:
# learned_in_threshold_perc= [0.97 0.97] , ng_in_threshold_perc= [0. 0.]

# %%
ac_acl = 2*Z_THRESHOLD*np.mean(sigma_learned_list, axis=0)
ac_mse = np.mean((mu_learned_list - v_truth)**2, axis=0)

mv_acl = 2*Z_THRESHOLD*np.mean(sigma_ng_list, axis=0)
mv_mse = np.mean( (mu_ng_list - v_truth)**2, axis=0 )

# %%
print("ACPE results: Group1, Group 2")
print(f"MSE: {ac_mse}")
print(f"ACL: {ac_acl}") 
print(f"ECP: {learned_in_threshold_perc}")

print("===")
print("MVPE results: ")
print(f"MSE: {mv_mse}")
print(f"ACL: {mv_acl}") 
print(f"ECP: {ng_in_threshold_perc}")
# Out:
# ACPE results: Group1, Group 2
# MSE: [0.03912388 0.03552939]
# ACL: [0.80288801 0.80052074]
# ECP: [0.97 0.97]
# ===
# MVPE results:
# MSE: [12.811908 13.188772]
# ACL: [1.2192227]
# ECP: [0. 0.]
