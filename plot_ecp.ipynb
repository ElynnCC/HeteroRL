# %% [markdown]
# # Plot Empirical

# %% [markdown]
# - Results are obtained from the following .ipynb
#
#   - QL-Hetero-20230602-LINEAR-N20-T20
#   - QL-Hetero-20230602-LINEAR-N20-T30
#   - QL-Hetero-20230602-LINEAR-N20-T40
#   - QL-Hetero-20230602-LINEAR-N50-T20
#   - QL-Hetero-20230602-LINEAR-N50-T30
#   - QL-Hetero-20230602-LINEAR-N50-T40
#   - QL-Hetero-20230602-LINEAR-N100-T20
#   - QL-Hetero-20230602-LINEAR-N100-T30
#   - QL-Hetero-20230602-LINEAR-N100-T40
#
#   - QL-Hetero-20230602-LEGENDRE-N20-T20
#   - QL-Hetero-20230602-LEGENDRE-N20-T30
#   - QL-Hetero-20230602-LEGENDRE-N20-T40
#   - QL-Hetero-20230602-LEGENDRE-N50-T20
#   - QL-Hetero-20230602-LEGENDRE-N50-T30
#   - QL-Hetero-20230602-LEGENDRE-N50-T40
#   - QL-Hetero-20230602-LEGENDRE-N100-T20
#   - QL-Hetero-20230602-LEGENDRE-N100-T30
#   - QL-Hetero-20230602-LEGENDRE-N100-T40

# %% [markdown]
# # Linear

# %%
import matplotlib.pyplot as plt

# LINEAR
# In[8]:


from matplotlib.pyplot import figure
figure(num=None, dpi=80, facecolor='w', edgecolor='k')

plt.scatter([400, 600, 800], [0.97, 0.97, 0.96], marker = 'o', label = 'ACPE N = 20')
plt.scatter([1000, 1500, 2000], [0.99, 0.97, 0.99], marker = 'o', label = 'ACPE N = 50')
plt.scatter([2000, 3000, 4000], [0.97, 0.92, 0.95], marker = 'o', label = 'ACPE N = 100')

plt.scatter([400, 600, 800], [0.0, 0.0, 0.0], marker = 'x', label = 'MVPE N = 20')
plt.scatter([500, 1500, 2000], [0.0, 0.0, 0.0], marker = 'x', label = 'MVPE N = 50')
plt.scatter([2000, 3000, 4000], [0.0, 0.0, 0.0], marker = 'x', label = 'MVPE N = 100')

plt.hlines(y = 0.95, xmin = 0, xmax = 4000, linestyles = 'dashed')

plt.title('ECPs for Group 1')

plt.xlabel('N*T')

plt.ylabel('ECP')

plt.legend(loc = 'best')
plt.savefig(f'results/ecp_grp1_linear.pdf', bbox_inches='tight')


# In[7]:


figure(num=None, dpi=80, facecolor='w', edgecolor='k')

plt.scatter([400, 600, 800], [0.97, 0.99, 0.96], marker = 'o', label = 'ACPE N = 20')
plt.scatter([1000, 1500, 2000], [0.97, 0.98, 0.95], marker = 'o', label = 'ACPE N = 50')
plt.scatter([2000, 3000, 4000], [0.96, 0.96, 0.95], marker = 'o', label = 'ACPE N = 100')

plt.scatter([400, 600, 800], [0.0, 0.0, 0.0], marker = 'x', label = 'MVPE N = 20')
plt.scatter([500, 1500, 2000], [0.0, 0.0, 0.0], marker = 'x', label = 'MVPE N = 50')
plt.scatter([2000, 3000, 4000], [0.0, 0.0, 0.0], marker = 'x', label = 'MVPE N = 100')

plt.hlines(y = 0.95, xmin = 0, xmax = 4000, linestyles = 'dashed')

plt.title('ECPs for Group 2')

plt.xlabel('N*T')

plt.ylabel('ECP')

plt.legend(loc = 'best')
plt.savefig(f'results/ecp_grp2_linear.pdf', bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

fig, axes = plt.subplots(1,2,figsize=(8,3),sharey=True,layout='tight',
                         facecolor='w', edgecolor='k')

### Group 1
axes[0].scatter([400, 600, 800], [0.97, 0.97, 0.96], marker = 'o', label = 'ACPE N = 20')
axes[0].scatter([1000, 1500, 2000], [0.99, 0.97, 0.99], marker = 'o', label = 'ACPE N = 50')
axes[0].scatter([2000, 3000, 4000], [0.97, 0.92, 0.95], marker = 'o', label = 'ACPE N = 100')

axes[0].scatter([400, 600, 800], [0.0, 0.0, 0.0], marker = 'x', label = 'MVPE N = 20')
axes[0].scatter([500, 1500, 2000], [0.0, 0.0, 0.0], marker = 'x', label = 'MVPE N = 50')
axes[0].scatter([2000, 3000, 4000], [0.0, 0.0, 0.0], marker = 'x', label = 'MVPE N = 100')

axes[0].hlines(y = 0.95, xmin = 0, xmax = 4000, linestyles = 'dashed')

axes[0].set_title('(a) ECPs for Group 1')
axes[0].set_xlabel('N*T')
axes[0].set_ylabel('ECP')
axes[0].legend(loc = 'best')

### Group 2
axes[1].scatter([400, 600, 800], [0.97, 0.99, 0.96], marker = 'o', label = 'ACPE N = 20')
axes[1].scatter([1000, 1500, 2000], [0.97, 0.98, 0.95], marker = 'o', label = 'ACPE N = 50')
axes[1].scatter([2000, 3000, 4000], [0.96, 0.96, 0.95], marker = 'o', label = 'ACPE N = 100')

axes[1].scatter([400, 600, 800], [0.0, 0.0, 0.0], marker = 'x', label = 'MVPE N = 20')
axes[1].scatter([500, 1500, 2000], [0.0, 0.0, 0.0], marker = 'x', label = 'MVPE N = 50')
axes[1].scatter([2000, 3000, 4000], [0.0, 0.0, 0.0], marker = 'x', label = 'MVPE N = 100')

axes[1].hlines(y = 0.95, xmin = 0, xmax = 4000, linestyles = 'dashed')

axes[1].set_title('(b) ECPs for Group 2')
axes[1].set_xlabel('N*T')
axes[1].set_ylabel('ECP')
axes[1].legend(loc = 'best')

fig.savefig(f'results/linear_ecp.pdf', bbox_inches='tight')

# %% [markdown]
# # Legendre

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

fig, axes = plt.subplots(1,2,figsize=(8,3),sharey=True,layout='tight',
                         facecolor='w', edgecolor='k')

### Group 1
axes[0].scatter([400, 600, 800], [0.97, 0.95, 0.94], marker = 'o', label = 'ACPE N = 20')
axes[0].scatter([1000, 1500, 2000], [0.97, 0.91, 0.92], marker = 'o', label = 'ACPE N = 50')
axes[0].scatter([2000, 3000, 4000], [0.96, 0.9, 0.95], marker = 'o', label = 'ACPE N = 100')

axes[0].scatter([400, 600, 800], [0.0, 0.0, 0.0], marker = 'x', label = 'MVPE N = 20')
axes[0].scatter([500, 1500, 2000], [0.0, 0.0, 0.0], marker = 'x', label = 'MVPE N = 50')
axes[0].scatter([2000, 3000, 4000], [0.0, 0.0, 0.0], marker = 'x', label = 'MVPE N = 100')

axes[0].hlines(y = 0.95, xmin = 0, xmax = 4000, linestyles = 'dashed')

axes[0].set_title('(a) ECPs for Group 1')
axes[0].set_xlabel('N*T')
axes[0].set_ylabel('ECP')
axes[0].legend(loc = 'best')

### Group 2
axes[1].scatter([400, 600, 800], [0.95, 0.97, 0.96], marker = 'o', label = 'ACPE N = 20')
axes[1].scatter([1000, 1500, 2000], [0.98, 0.96, 0.95], marker = 'o', label = 'ACPE N = 50')
axes[1].scatter([2000, 3000, 4000], [0.96, 0.97, 0.95], marker = 'o', label = 'ACPE N = 100')

axes[1].scatter([400, 600, 800], [0.0, 0.0, 0.0], marker = 'x', label = 'MVPE N = 20')
axes[1].scatter([500, 1500, 2000], [0.0, 0.0, 0.0], marker = 'x', label = 'MVPE N = 50')
axes[1].scatter([2000, 3000, 4000], [0.0, 0.0, 0.0], marker = 'x', label = 'MVPE N = 100')

axes[1].hlines(y = 0.95, xmin = 0, xmax = 4000, linestyles = 'dashed')

axes[1].set_title('(b) ECPs for Group 2')
axes[1].set_xlabel('N*T')
axes[1].set_ylabel('ECP')
axes[1].legend(loc = 'best')

fig.savefig(f'results/legendre_ecp.pdf', bbox_inches='tight')
